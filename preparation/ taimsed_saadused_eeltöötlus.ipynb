# %% [markdown]
# # 0. lingid ja importimine

# %% [markdown]
# https://github.com/estnltk/estnltk/blob/main/tutorials/wordnet/wordnet.ipynb -- wordneti õpetus
#
# https://wordties.nors.ku.dk/wordties-estwn/w/full/343136-taimekahjur // http://prog.keeleressursid.ee/estwnvis/?word=taim&sense=1 -- wordnet visuaalne
#
# https://github.com/estnltk/estnltk/blob/main/tutorials/nlp_pipeline/B_morphology/00_tables_of_morphological_categories.ipynb -- morf. kategooriad
#
# https://arhiiv.eki.ee/litsents/idkaart/dl.cgi?D=psv -- põhisõnavara sõnastik

# %%
from google.colab import drive

drive.mount('/content/drive')

import os
os.chdir('/content/drive/My Drive/Colab Notebooks/baka')
# Out:
# Mounted at /content/drive

# %%
# !pip install estnltk==1.7.3
import estnltk
from estnltk.wordnet import Wordnet
from estnltk import Text
# Out:
# Collecting estnltk==1.7.3
#   Downloading estnltk-1.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Collecting estnltk-core>=1.7.3 (from estnltk==1.7.3)
#   Downloading estnltk_core-1.7.4-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: nltk>=3.4.1 in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (3.9.1)
# Requirement already satisfied: regex>=2015.07.19 in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (2024.11.6)
# Collecting python-crfsuite>=0.8.3 (from estnltk==1.7.3)
#   Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.3 kB)
# Collecting cached-property>=1.2.0 (from estnltk==1.7.3)
#   Downloading cached_property-2.0.1-py3-none-any.whl.metadata (10 kB)
# Collecting bs4 (from estnltk==1.7.3)
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: html5lib in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (1.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (5.3.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (3.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (3.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (4.67.1)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (7.34.0)
# Collecting conllu (from estnltk==1.7.3)
#   Downloading conllu-6.0.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from estnltk==1.7.3) (2.2.2)
# Collecting pyahocorasick (from estnltk==1.7.3)
#   Downloading pyahocorasick-2.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from estnltk-core>=1.7.3->estnltk==1.7.3) (24.2)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk>=3.4.1->estnltk==1.7.3) (8.1.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk>=3.4.1->estnltk==1.7.3) (1.4.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from bs4->estnltk==1.7.3) (4.13.3)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.11/dist-packages (from html5lib->estnltk==1.7.3) (1.17.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.11/dist-packages (from html5lib->estnltk==1.7.3) (0.5.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (75.1.0)
# Collecting jedi>=0.16 (from ipython->estnltk==1.7.3)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (3.0.50)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (2.18.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->estnltk==1.7.3) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (2.0.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->estnltk==1.7.3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->estnltk==1.7.3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->estnltk==1.7.3) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->estnltk==1.7.3) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->estnltk==1.7.3) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->estnltk==1.7.3) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->estnltk==1.7.3) (2025.1.31)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->estnltk==1.7.3) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->estnltk==1.7.3) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->estnltk==1.7.3) (0.2.13)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4->estnltk==1.7.3) (2.6)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->bs4->estnltk==1.7.3) (4.12.2)
# Downloading estnltk-1.7.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (70.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.8/70.8 MB 10.0 MB/s eta 0:00:00
# Downloading cached_property-2.0.1-py3-none-any.whl (7.4 kB)
# Downloading estnltk_core-1.7.4-py3-none-any.whl (235 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.8/235.8 kB 14.2 MB/s eta 0:00:00
# Downloading python_crfsuite-0.9.11-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 34.7 MB/s eta 0:00:00
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Downloading conllu-6.0.0-py3-none-any.whl (16 kB)
# Downloading pyahocorasick-2.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.3/118.3 kB 7.0 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 32.9 MB/s eta 0:00:00
# Installing collected packages: python-crfsuite, pyahocorasick, jedi, conllu, cached-property, bs4, estnltk-core, estnltk
# Successfully installed bs4-0.0.2 cached-property-2.0.1 conllu-6.0.0 estnltk-1.7.3 estnltk-core-1.7.4 jedi-0.19.2 pyahocorasick-2.1.0 python-crfsuite-0.9.11

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
wn = Wordnet()
# Out:
# Downloading resources index: 22.6kB [00:00, 18.1MB/s]
# This requires downloading resource 'estwordnet_2023-07-20' (size: 26M). Proceed with downloading? [Y/n] Y
# Downloading estwordnet_2023-07-20: 10.5MB [00:01, 6.03MB/s]
# Unpacked resource into subfolder 'wordnet/estwn-et-2.6.0_2023-07-20/' of the resources dir.

# %% [markdown]
# # 1. Sõnade valimine

# %% [markdown]
# Täpsemalt võiks valida sõnad:
# 1. millel on rohkem kui 6 küsimust
# 2. esinevad põhisõnavarastikus
# 3. leidub vikipeedia leht
#
# Nende punktidega saab kinnitust, et tegu on levinud sõnaga

# %%
# leimane sobilikud loomaga seotud sõnad
list_of_all_suitable_vegetables = []
list_of_taim = []
list_of_taimeosa = []

# %%
# milliseid sõnu me tahame?
sõna_mõiste = wn["söödav vili"] # wn["taimeosa"] #  wn["kultuurtaim"] # wn["vaskulaarne taim"]
for sõna in sõna_mõiste:
  print(sõna.definition, sõna.name)
  print(sõna.closure("hyponym", 1))
# Out:
# taimede viljad, mis on söödavad söödav vili.n.01
# ["Synset('kappar.n.03')", "Synset('aedvili.n.01')", "Synset('granadill.n.01')", "Synset('iva.n.01')", "Synset('kivivili.n.01')", "Synset('mari.n.01')", "Synset('kuivatatud vili.n.01')", "Synset('frukt.n.01')", "Synset('mugulvili.n.01')", "Synset('pähkel.n.01')", "Synset('mugul.n.02')", "Synset('jaanikaun.n.01')", "Synset('mandel.n.01')"]

# %%
taimed = wn["söödav vili"][0].closure("hyponym")

# %%
len(taimed)
# Out:
# 237

# %%
# vaatame taimi millel on ainult üks alamklass -- KUSTUTAME NEED, POLE PRAKTILISED JA SOBIVAD MÄNGU JAOKS

taimed_alamklass = wn["söödav vili"][0].closure("hyponym", 1)
taimed_kustutada = [sõna for sõna in taimed_alamklass if len(sõna.closure("hyponym")) <= 3]

# Kustutame need sõnad taimede hulgast
taimed = [sõna for sõna in taimed if sõna not in taimed_kustutada]

print(f"Kustutatud sõnu: {len(taimed_kustutada)}")
# Out:
# Kustutatud sõnu: 6

# %%
for sõna in taimed:
  list_of_taim.append(sõna.lemmas)

# %%
list_of_taim
# Out:
# [['aedvili'],
#  ['köögivili'],
#  ['baamia', 'okra'],
#  ['suvikõrvits'],
#  ['spagetikõrvits'],
#  ['kabatšokk', 'rullkõrvits', 'zucchini', 'tsukiini'],
#  ['hiina alss', 'vesikastan'],
#  ['piimjuur'],
#  ['aed-piimjuur'],
#  ['salat'],
#  ['rooma salat'],
#  ['jääsalat'],
#  ['lillkapsas'],
#  ['arbuus'],
#  ['juurikad', 'juurvili'],
#  ['bataat', 'maguskartul', 'magus kartul'],
#  ['naeris'],
#  ['maapirn', 'mugulpäevalill', 'topinambur'],
#  ['brüsseli kapsas', 'rooskapsas'],
#  ['peakapsas'],
#  ['kurk'],
#  ['hapukurk'],
#  ['kõrvits'],
#  ['tõrukõrvits'],
#  ['karella', 'kibekurk'],
#  ['muskaatkõrvits'],
#  ['banaankõrvits'],
#  ['kokosell', 'pikk kõrvits'],
#  ['õlikõrvits'],
#  ['keerdkaelaline kõrvits', 'käändkõrvits'],
#  ['patisson', 'taldrikkõrvits'],
#  ['kaunvili'],
#  ['arahhis', 'hiina pähkel', 'maapähkel'],
#  ['hernes'],
#  ['aedhernes'],
#  ['kikerhernes', 'nuut', 'põishernes'],
#  ['uba'],
#  ['must uba'],
#  ['punane uba'],
#  ['soja', 'sojauba'],
#  ['aeduba', 'Türgi uba'],
#  ['adzuki', 'asukiuba'],
#  ['munguba'],
#  ['liimauba'],
#  ['sibul', 'söögisibul'],
#  ['talisibul'],
#  ['pesasibul', 'šalott', 'šalottsibul'],
#  ['punane sibul'],
#  ['tomat'],
#  ['kirsstomat'],
#  ['ploomtomat'],
#  ['lihatomat'],
#  ['porrulauk', 'porrusibul'],
#  ['aedseller', 'seller'],
#  ['juurseller'],
#  ['lehtseller'],
#  ['varsseller'],
#  ['kapsapea', 'kapsas'],
#  ['riivkapsas', 'särvkapsas'],
#  ['punane kapsas'],
#  ['artišokk'],
#  ['baklažaan', 'pommu'],
#  ['lauk'],
#  ['pärlsibul', 'suvi-porrulauk'],
#  ['murulauk'],
#  ['nurmlauk'],
#  ['karulauk'],
#  ['porru', 'porrulauk', 'porrusibul'],
#  ['karulauk'],
#  ['metslauk'],
#  ['rohulauk'],
#  ['melon'],
#  ['kivaano', 'ogamelon'],
#  ['aed-moorputk', 'pastinaak'],
#  ['rabarber'],
#  ['aspar', 'spargel'],
#  ['spinat'],
#  ['paprika', 'paprikakaun'],
#  ['lehtaedvili', 'lehtköögivili'],
#  ['iva', 'seeme'],
#  ['sinepiseeme'],
#  ['kanepiseemned'],
#  ['kõrvitsaseeme'],
#  ['linaseeme', 'linaseemned'],
#  ['seesamiseeme'],
#  ['päevalilleseeme', 'sihvka'],
#  ['moon', 'mooniseeme'],
#  ['piiniaseeme', 'seedermänni pähkel', 'seedermänniseeme'],
#  ['tera', 'teravili', 'teris', 'vili', 'viljatera'],
#  ['kõlutera'],
#  ['tatar', 'tatratera'],
#  ['toortatar'],
#  ['jahvatis'],
#  ['klii', 'kliid'],
#  ['kaerakliid'],
#  ['rukkikliid'],
#  ['nisukliid'],
#  ['vilis'],
#  ['kruubid', 'kruubitangud', 'kruup'],
#  ['nisu', 'nisutera'],
#  ['bulgur'],
#  ['oder', 'odratera'],
#  ['rukis', 'rukkitera'],
#  ['kaer', 'kaeratera'],
#  ['tang'],
#  ['maisitang'],
#  ['odratang'],
#  ['kuskuss'],
#  ['hirsitang', 'hirsitera'],
#  ['mais', 'maisitera'],
#  ['indiaani riis', 'metsik riis', 'Tuskaroora vesiriis', 'vesiriis'],
#  ['linnased', 'maged'],
#  ['kivivili', 'luuvili'],
#  ['loorberimari'],
#  ['hapukirss'],
#  ['aprikoos'],
#  ['mango', 'mangoploom'],
#  ['oliiv'],
#  ['kirss', 'käsper'],
#  ['klaaskirss'],
#  ['kookos', 'kookospähkel'],
#  ['mirabell'],
#  ['murel'],
#  ['mari'],
#  ['joovikas', 'sinikas'],
#  ['astelpaju', 'astelpajumari'],
#  ['sõstar', 'sõstramari'],
#  ['valge sõstar'],
#  ['hõrakmari', 'punane sõstar'],
#  ['must sõstar', 'sitikmari'],
#  ['mage sõstar'],
#  ['vaarikas', 'vaarmari', 'vabarn'],
#  ['metsamari', 'metsmari'],
#  ['aedmari', 'aiamari'],
#  ['aedmurakas', 'pampel'],
#  ['vaarikpampel', 'vampel'],
#  ['kadakamari'],
#  ['tamarillo'],
#  ['kaarel', 'karumurakas', 'murakas'],
#  ['põldmari', 'põldmurakas'],
#  ['mesimurakas', 'soomurakas'],
#  ['karusmari', 'tikerber', 'tikker'],
#  ['maasikas', 'maasikmari'],
#  ['metsmaasikas'],
#  ['aedmaasikas'],
#  ['muulukamari', 'muulukas'],
#  ['pihlakamari', 'pihlakas'],
#  ['viigimari', 'viik'],
#  ['jõhvikas', 'kuremari'],
#  ['alrauni mari', 'lemmemari', 'tuudaimimari'],
#  ['mustikas', 'mustikmari'],
#  ['palukas', 'pohl'],
#  ['kuivatatud vili'],
#  ['rosin'],
#  ['korint'],
#  ['sultana', 'sultanarosin'],
#  ['urjukk'],
#  ['frukt', 'puuvili'],
#  ['küdoonia'],
#  ['karamboola', 'tähtvili'],
#  ['diospüür', 'hurmaa', 'kaki', 'kakiploom'],
#  ['banaan'],
#  ['jahubanaan'],
#  ['ploom'],
#  ['renklood'],
#  ['ubin', 'õun'],
#  ['viss'],
#  ['metsõun'],
#  ['dessertõun', 'lauaõun'],
#  ['tuviõun'],
#  ['säilitusõun'],
#  ['kuldrenett'],
#  ['suislepp'],
#  ['klaar', 'klaarõun', 'valge klaar'],
#  ['taliõun'],
#  ['antoonovka'],
#  ['suviõun'],
#  ['sibulõun'],
#  ['paradiisiõun'],
#  ['sügisõun'],
#  ['renett', 'renettõun'],
#  ['pirn'],
#  ['bergamott'],
#  ['durian'],
#  ['persik', 'virsik'],
#  ['lamevirsik'],
#  ['kreek'],
#  ['ananass'],
#  ['tsitrus', 'tsitruseline', 'tsitrusvili'],
#  ['laim'],
#  ['sõrmlaim'],
#  ['kahvrilaim', 'kombaava'],
#  ['bergamott'],
#  ['pomel', 'pomelo'],
#  ['greip', 'greipfruut', 'kreebu'],
#  ['punagreip', 'verigreip'],
#  ['kinkan', 'kumkvaat', 'kääbusapelsin'],
#  ['tangeriin'],
#  ['sidrun'],
#  ['apelsin'],
#  ['veriapelsin'],
#  ['pomerants'],
#  ['munakinkan', 'nagami'],
#  ['mandariin'],
#  ['klementiin'],
#  ['satsuma'],
#  ['granaat', 'granaatõun'],
#  ['alligaatorpirn', 'avokaado'],
#  ['guajaav'],
#  ['inglite vili', 'papaia'],
#  ['kaktusvili'],
#  ['draakonivili', 'pitaia'],
#  ['kerimoia', 'suhkruõun'],
#  ['kiivi'],
#  ['longan'],
#  ['nektariin'],
#  ['hiina ploom', 'litš', 'litši'],
#  ['litši', 'pulasan', 'rambutan'],
#  ['viinamari'],
#  ['kišmišš'],
#  ['pähkel'],
#  ['areekapähkel', 'beetlipähkel'],
#  ['metspähkel', 'sarapuupähkel'],
#  ['Kreeka pähkel', 'kreeka pähkel'],
#  ['pistaatsia', 'pistaatsiapähkel'],
#  ['akazuupähkel',
#   'India pähkel',
#   'india pähkel',
#   'kašupähkel',
#   'nakar',
#   'nakra'],
#  ['pekaanpähkel'],
#  ['brasiilia pähkel', 'parapähkel'],
#  ['makadaamia', 'makadaamiapähkel'],
#  ['küüslauk', 'noblu'],
#  ['mõrumandel']]

# %%
# Muudame listi üheksainsaks listiks
flattened_taimed = [w for sublist in list_of_taim for w in sublist]

# Ühendame mõlemad listid
all_lemmas = flattened_taimed

# Leiame duplikaadid
duplicates = {lemma for lemma in all_lemmas if all_lemmas.count(lemma) > 1}

print(f"Leitud duplikaadid: {len(duplicates)}")
# Out:
# Leitud duplikaadid: 5

# %%
len(all_lemmas)
# Out:
# 366

# %%
list_of_all_suitable_vegetables = list_of_taim

# %% [markdown]
# ### sõnad ja nende alamsõnad

# %%
from estnltk.vabamorf.morf import synthesize
def correct_word_form(word, vabamorf):
  word = word.split(".")
  word = word[0]
  sõna = ""
  for w in word.split():
    synthesized = synthesize(w, vabamorf)
    if synthesized:
        sõna += synthesized[0] + " "
    else:
        return

  if sõna == "":
    return word
  return sõna.strip()

# %%
# Let's assume wn["loom"] is some category or synset you want to work with
category = wn["söödav vili"][0]  # This is just an example, adjust as needed.

word_info = []

# Iterate over all hyponyms and gather relations
for words in category.closure("hyponym"):
    hyponyms = set()
    word = words.lemmas
            # Lisa alammõisted
    for alammõisted in words.closure("hyponym"):
        hyponyms.add(correct_word_form(alammõisted.name, "sg n"))
    word_info.append([word, hyponyms])

# %%
word_info
# Out:
# [[['kappar', 'kapparimari'], set()],
#  [['aedvili'],
#   {'adzuki',
#    'aed-moorputk',
#    'aed-piimjuur',
#    'aedhernes',
#    'aedseller',
#    'aeduba',
#    'arahhis',
#    'arbuus',
#    'artišokk',
#    'aspar',
#    'baamia',
#    'baklažaan',
#    'banaankõrvits',
#    'bataat',
#    'brüsseli kapsas',
#    'hapukurk',
#    'hernes',
#    'hiina alss',
#    'juurikas',
#    'juurseller',
#    'jääsalat',
#    'kabatšokk',
#    'kapsapea',
#    'karella',
#    'karulauk',
#    'kaunvili',
#    'keerdkaelaline kõrvits',
#    'kikerhernes',
#    'kirsstomat',
#    'kivaano',
#    'kokosell',
#    'kurk',
#    'kõrvits',
#    'köögivili',
#    'lauk',
#    'lehtaedvili',
#    'lehtseller',
#    'lihatomat',
#    'liimauba',
#    'lillkapsas',
#    'maapirn',
#    'melon',
#    'metslauk',
#    'munguba',
#    'murulauk',
#    'muskaatkõrvits',
#    'must uba',
#    'naeris',
#    'nurmlauk',
#    'paprika',
#    'patisson',
#    'peakapsas',
#    'pesasibul',
#    'piimjuur',
#    'ploomtomat',
#    'porru',
#    'porrulauk',
#    'punane kapsas',
#    'punane sibul',
#    'punane uba',
#    'pärlsibul',
#    'rabarber',
#    'riivkapsas',
#    'rohulauk',
#    'rooma salat',
#    'salat',
#    'sibul',
#    'soja',
#    'spagetikõrvits',
#    'spinat',
#    'suvikõrvits',
#    'talisibul',
#    'tomat',
#    'tõrukõrvits',
#    'uba',
#    'varsseller',
#    'õlikõrvits'}],
#  [['köögivili'],
#   {'adzuki',
#    'aed-moorputk',
#    'aed-piimjuur',
#    'aedhernes',
#    'aedseller',
#    'aeduba',
#    'arahhis',
#    'arbuus',
#    'artišokk',
#    'aspar',
#    'baamia',
#    'baklažaan',
#    'banaankõrvits',
#    'bataat',
#    'brüsseli kapsas',
#    'hapukurk',
#    'hernes',
#    'hiina alss',
#    'juurikas',
#    'juurseller',
#    'jääsalat',
#    'kabatšokk',
#    'kapsapea',
#    'karella',
#    'karulauk',
#    'kaunvili',
#    'keerdkaelaline kõrvits',
#    'kikerhernes',
#    'kirsstomat',
#    'kivaano',
#    'kokosell',
#    'kurk',
#    'kõrvits',
#    'lauk',
#    'lehtseller',
#    'lihatomat',
#    'liimauba',
#    'lillkapsas',
#    'maapirn',
#    'melon',
#    'metslauk',
#    'munguba',
#    'murulauk',
#    'muskaatkõrvits',
#    'must uba',
#    'naeris',
#    'nurmlauk',
#    'paprika',
#    'patisson',
#    'peakapsas',
#    'pesasibul',
#    'piimjuur',
#    'ploomtomat',
#    'porru',
#    'porrulauk',
#    'punane kapsas',
#    'punane sibul',
#    'punane uba',
#    'pärlsibul',
#    'rabarber',
#    'riivkapsas',
#    'rohulauk',
#    'rooma salat',
#    'salat',
#    'sibul',
#    'soja',
#    'spagetikõrvits',
#    'spinat',
#    'suvikõrvits',
#    'talisibul',
#    'tomat',
#    'tõrukõrvits',
#    'uba',
#    'varsseller',
#    'õlikõrvits'}],
#  [['baamia', 'okra'], set()],
#  [['suvikõrvits'], {'kabatšokk', 'spagetikõrvits'}],
#  [['spagetikõrvits'], set()],
#  [['kabatšokk', 'rullkõrvits', 'zucchini', 'tsukiini'], set()],
#  [['hiina alss', 'vesikastan'], set()],
#  [['piimjuur'], {'aed-piimjuur'}],
#  [['aed-piimjuur'], set()],
#  [['salat'], {'jääsalat', 'rooma salat'}],
#  [['rooma salat'], set()],
#  [['jääsalat'], set()],
#  [['lillkapsas'], set()],
#  [['arbuus'], set()],
#  [['juurikad', 'juurvili'], {'bataat', 'maapirn', 'naeris'}],
#  [['bataat', 'maguskartul', 'magus kartul'], set()],
#  [['naeris'], set()],
#  [['maapirn', 'mugulpäevalill', 'topinambur'], set()],
#  [['brüsseli kapsas', 'rooskapsas'], set()],
#  [['peakapsas'], set()],
#  [['kurk'], {'hapukurk'}],
#  [['hapukurk'], set()],
#  [['kõrvits'],
#   {'banaankõrvits',
#    'karella',
#    'keerdkaelaline kõrvits',
#    'kokosell',
#    'muskaatkõrvits',
#    'patisson',
#    'tõrukõrvits',
#    'õlikõrvits'}],
#  [['tõrukõrvits'], set()],
#  [['karella', 'kibekurk'], set()],
#  [['muskaatkõrvits'], set()],
#  [['banaankõrvits'], set()],
#  [['kokosell', 'pikk kõrvits'], set()],
#  [['õlikõrvits'], set()],
#  [['keerdkaelaline kõrvits', 'käändkõrvits'], set()],
#  [['patisson', 'taldrikkõrvits'], set()],
#  [['kaunvili'],
#   {'adzuki',
#    'aedhernes',
#    'aeduba',
#    'arahhis',
#    'hernes',
#    'kikerhernes',
#    'liimauba',
#    'munguba',
#    'must uba',
#    'punane uba',
#    'soja',
#    'uba'}],
#  [['arahhis', 'hiina pähkel', 'maapähkel'], set()],
#  [['hernes'], {'aedhernes'}],
#  [['aedhernes'], set()],
#  [['kikerhernes', 'nuut', 'põishernes'], set()],
#  [['uba'],
#   {'adzuki',
#    'aeduba',
#    'liimauba',
#    'munguba',
#    'must uba',
#    'punane uba',
#    'soja'}],
#  [['must uba'], set()],
#  [['punane uba'], set()],
#  [['soja', 'sojauba'], set()],
#  [['aeduba', 'Türgi uba'], {'adzuki', 'liimauba', 'munguba'}],
#  [['adzuki', 'asukiuba'], set()],
#  [['munguba'], set()],
#  [['liimauba'], set()],
#  [['sibul', 'söögisibul'], {'pesasibul', 'punane sibul', 'talisibul'}],
#  [['talisibul'], set()],
#  [['pesasibul', 'šalott', 'šalottsibul'], set()],
#  [['punane sibul'], set()],
#  [['tomat'], {'kirsstomat', 'lihatomat', 'ploomtomat'}],
#  [['kirsstomat'], set()],
#  [['ploomtomat'], set()],
#  [['lihatomat'], set()],
#  [['porrulauk', 'porrusibul'], set()],
#  [['aedseller', 'seller'], {'juurseller', 'lehtseller', 'varsseller'}],
#  [['juurseller'], set()],
#  [['lehtseller'], set()],
#  [['varsseller'], set()],
#  [['kapsapea', 'kapsas'], {'punane kapsas', 'riivkapsas'}],
#  [['riivkapsas', 'särvkapsas'], set()],
#  [['punane kapsas'], set()],
#  [['artišokk'], set()],
#  [['baklažaan', 'pommu'], set()],
#  [['lauk'],
#   {'karulauk',
#    'metslauk',
#    'murulauk',
#    'nurmlauk',
#    'porru',
#    'pärlsibul',
#    'rohulauk'}],
#  [['pärlsibul', 'suvi-porrulauk'], set()],
#  [['murulauk'], set()],
#  [['nurmlauk'], set()],
#  [['karulauk'], set()],
#  [['porru', 'porrulauk', 'porrusibul'], set()],
#  [['karulauk'], set()],
#  [['metslauk'], set()],
#  [['rohulauk'], set()],
#  [['melon'], {'kivaano'}],
#  [['kivaano', 'ogamelon'], set()],
#  [['aed-moorputk', 'pastinaak'], set()],
#  [['rabarber'], set()],
#  [['aspar', 'spargel'], set()],
#  [['spinat'], set()],
#  [['paprika', 'paprikakaun'], set()],
#  [['lehtaedvili', 'lehtköögivili'], set()],
#  [['granadill', 'grenadill'], set()],
#  [['iva', 'seeme'],
#   {None,
#    'bulgur',
#    'hirsitang',
#    'indiaani riis',
#    'jahvatis',
#    'kaer',
#    'kaeraklii',
#    'kanepiseeme',
#    'klii',
#    'kruup',
#    'kuskuss',
#    'kõlutera',
#    'kõrvitsaseeme',
#    'linaseeme',
#    'mais',
#    'maisitang',
#    'moon',
#    'nisu',
#    'nisuklii',
#    'oder',
#    'odratang',
#    'piiniaseeme',
#    'päevalilleseeme',
#    'rukis',
#    'rukkiklii',
#    'seesamiseeme',
#    'sinepiseeme',
#    'tang',
#    'tatar',
#    'tera',
#    'toortatar',
#    'vilis'}],
#  [['sinepiseeme'], set()],
#  [['kanepiseemned'], set()],
#  [['kõrvitsaseeme'], set()],
#  [['linaseeme', 'linaseemned'], set()],
#  [['seesamiseeme'], set()],
#  [['päevalilleseeme', 'sihvka'], set()],
#  [['moon', 'mooniseeme'], set()],
#  [['piiniaseeme', 'seedermänni pähkel', 'seedermänniseeme'], set()],
#  [['tera', 'teravili', 'teris', 'vili', 'viljatera'],
#   {None,
#    'bulgur',
#    'hirsitang',
#    'indiaani riis',
#    'jahvatis',
#    'kaer',
#    'kaeraklii',
#    'klii',
#    'kruup',
#    'kuskuss',
#    'kõlutera',
#    'mais',
#    'maisitang',
#    'nisu',
#    'nisuklii',
#    'oder',
#    'odratang',
#    'rukis',
#    'rukkiklii',
#    'tang',
#    'tatar',
#    'toortatar',
#    'vilis'}],
#  [['kõlutera'], set()],
#  [['tatar', 'tatratera'], {'toortatar'}],
#  [['toortatar'], set()],
#  [['jahvatis'], set()],
#  [['klii', 'kliid'], {'kaeraklii', 'nisuklii', 'rukkiklii'}],
#  [['kaerakliid'], set()],
#  [['rukkikliid'], set()],
#  [['nisukliid'], set()],
#  [['vilis'], set()],
#  [['kruubid', 'kruubitangud', 'kruup'], set()],
#  [['nisu', 'nisutera'], {'bulgur'}],
#  [['bulgur'], set()],
#  [['oder', 'odratera'], set()],
#  [['rukis', 'rukkitera'], set()],
#  [['kaer', 'kaeratera'], set()],
#  [['tang'], {'hirsitang', 'kuskuss', 'maisitang', 'odratang'}],
#  [['maisitang'], set()],
#  [['odratang'], set()],
#  [['kuskuss'], set()],
#  [['hirsitang', 'hirsitera'], set()],
#  [['mais', 'maisitera'], set()],
#  [['indiaani riis', 'metsik riis', 'Tuskaroora vesiriis', 'vesiriis'], set()],
#  [['linnased', 'maged'], set()],
#  [['kivivili', 'luuvili'],
#   {'aprikoos',
#    'hapukirss',
#    'kirss',
#    'klaaskirss',
#    'kookos',
#    'loorberimari',
#    'mango',
#    'mirabell',
#    'murel',
#    'oliiv'}],
#  [['loorberimari'], set()],
#  [['hapukirss'], set()],
#  [['aprikoos'], set()],
#  [['mango', 'mangoploom'], set()],
#  [['oliiv'], set()],
#  [['kirss', 'käsper'], {'klaaskirss'}],
#  [['klaaskirss'], set()],
#  [['kookos', 'kookospähkel'], set()],
#  [['mirabell'], set()],
#  [['murel'], set()],
#  [['mari'],
#   {'aedmaasikas',
#    'aedmari',
#    'aedmurakas',
#    'alrauni mari',
#    'astelpaju',
#    'hõrakmari',
#    'joovikas',
#    'jõhvikas',
#    'kaarel',
#    'kadakamari',
#    'karusmari',
#    'maasikas',
#    'mage sõstar',
#    'mesimurakas',
#    'metsamari',
#    'metsmaasikas',
#    'must sõstar',
#    'mustikas',
#    'muulukamari',
#    'palukas',
#    'pihlakamari',
#    'põldmari',
#    'sõstar',
#    'tamarillo',
#    'vaarikas',
#    'vaarikpampel',
#    'valge sõstar',
#    'viigimari'}],
#  [['joovikas', 'sinikas'], set()],
#  [['astelpaju', 'astelpajumari'], set()],
#  [['sõstar', 'sõstramari'],
#   {'hõrakmari', 'mage sõstar', 'must sõstar', 'valge sõstar'}],
#  [['valge sõstar'], set()],
#  [['hõrakmari', 'punane sõstar'], set()],
#  [['must sõstar', 'sitikmari'], set()],
#  [['mage sõstar'], set()],
#  [['vaarikas', 'vaarmari', 'vabarn'], set()],
#  [['metsamari', 'metsmari'], set()],
#  [['aedmari', 'aiamari'], set()],
#  [['aedmurakas', 'pampel'], set()],
#  [['vaarikpampel', 'vampel'], set()],
#  [['kadakamari'], set()],
#  [['tamarillo'], set()],
#  [['kaarel', 'karumurakas', 'murakas'], {'mesimurakas', 'põldmari'}],
#  [['põldmari', 'põldmurakas'], set()],
#  [['mesimurakas', 'soomurakas'], set()],
#  [['karusmari', 'tikerber', 'tikker'], set()],
#  [['maasikas', 'maasikmari'], {'aedmaasikas', 'metsmaasikas', 'muulukamari'}],
#  [['metsmaasikas'], set()],
#  [['aedmaasikas'], set()],
#  [['muulukamari', 'muulukas'], set()],
#  [['pihlakamari', 'pihlakas'], set()],
#  [['viigimari', 'viik'], set()],
#  [['jõhvikas', 'kuremari'], set()],
#  [['alrauni mari', 'lemmemari', 'tuudaimimari'], set()],
#  [['mustikas', 'mustikmari'], set()],
#  [['palukas', 'pohl'], set()],
#  [['kuivatatud vili'], {'korint', 'rosin', 'sultana', 'urjukk'}],
#  [['rosin'], {'korint', 'sultana'}],
#  [['korint'], set()],
#  [['sultana', 'sultanarosin'], set()],
#  [['urjukk'], set()],
#  [['frukt', 'puuvili'],
#   {'alligaatorpirn',
#    'ananass',
#    'antoonovka',
#    'apelsin',
#    'banaan',
#    'bergamott',
#    'dessertõun',
#    'diospüür',
#    'draakonivili',
#    'durian',
#    'granaat',
#    'greip',
#    'guajaav',
#    'hiina ploom',
#    'inglite vili',
#    'jahubanaan',
#    'kahvrilaim',
#    'kaktusvili',
#    'karamboola',
#    'kerimoia',
#    'kiivi',
#    'kinkan',
#    'kišmišš',
#    'klaar',
#    'klementiin',
#    'kreek',
#    'kuldrenett',
#    'küdoonia',
#    'laim',
#    'lamevirsik',
#    'litši',
#    'longan',
#    'mandariin',
#    'metsõun',
#    'munakinkan',
#    'nektariin',
#    'paradiisiõun',
#    'persik',
#    'pirn',
#    'ploom',
#    'pomel',
#    'pomerants',
#    'punagreip',
#    'renett',
#    'renklood',
#    'satsuma',
#    'sibulõun',
#    'sidrun',
#    'suislepp',
#    'suviõun',
#    'säilitusõun',
#    'sõrmlaim',
#    'sügisõun',
#    'taliõun',
#    'tangeriin',
#    'tsitrus',
#    'tuviõun',
#    'ubin',
#    'veriapelsin',
#    'viinamari',
#    'viss'}],
#  [['küdoonia'], set()],
#  [['karamboola', 'tähtvili'], set()],
#  [['diospüür', 'hurmaa', 'kaki', 'kakiploom'], set()],
#  [['banaan'], {'jahubanaan'}],
#  [['jahubanaan'], set()],
#  [['ploom'], {'renklood'}],
#  [['renklood'], set()],
#  [['ubin', 'õun'],
#   {'antoonovka',
#    'dessertõun',
#    'klaar',
#    'kuldrenett',
#    'metsõun',
#    'paradiisiõun',
#    'renett',
#    'sibulõun',
#    'suislepp',
#    'suviõun',
#    'säilitusõun',
#    'sügisõun',
#    'taliõun',
#    'tuviõun',
#    'viss'}],
#  [['viss'], set()],
#  [['metsõun'], set()],
#  [['dessertõun', 'lauaõun'], set()],
#  [['tuviõun'], set()],
#  [['säilitusõun'], set()],
#  [['kuldrenett'], set()],
#  [['suislepp'], set()],
#  [['klaar', 'klaarõun', 'valge klaar'], set()],
#  [['taliõun'], {'antoonovka'}],
#  [['antoonovka'], set()],
#  [['suviõun'], set()],
#  [['sibulõun'], set()],
#  [['paradiisiõun'], set()],
#  [['sügisõun'], {'renett'}],
#  [['renett', 'renettõun'], set()],
#  [['pirn'], {'bergamott'}],
#  [['bergamott'], set()],
#  [['durian'], set()],
#  [['persik', 'virsik'], {'lamevirsik'}],
#  [['lamevirsik'], set()],
#  [['kreek'], set()],
#  [['ananass'], set()],
#  [['tsitrus', 'tsitruseline', 'tsitrusvili'],
#   {'apelsin',
#    'bergamott',
#    'greip',
#    'kahvrilaim',
#    'kinkan',
#    'klementiin',
#    'laim',
#    'mandariin',
#    'munakinkan',
#    'pomel',
#    'pomerants',
#    'punagreip',
#    'satsuma',
#    'sidrun',
#    'sõrmlaim',
#    'tangeriin',
#    'veriapelsin'}],
#  [['laim'], {'kahvrilaim', 'sõrmlaim'}],
#  [['sõrmlaim'], set()],
#  [['kahvrilaim', 'kombaava'], set()],
#  [['bergamott'], set()],
#  [['pomel', 'pomelo'], set()],
#  [['greip', 'greipfruut', 'kreebu'], {'punagreip'}],
#  [['punagreip', 'verigreip'], set()],
#  [['kinkan', 'kumkvaat', 'kääbusapelsin'], set()],
#  [['tangeriin'], set()],
#  [['sidrun'], set()],
#  [['apelsin'], {'veriapelsin'}],
#  [['veriapelsin'], set()],
#  [['pomerants'], set()],
#  [['munakinkan', 'nagami'], set()],
#  [['mandariin'], {'klementiin', 'satsuma'}],
#  [['klementiin'], set()],
#  [['satsuma'], set()],
#  [['granaat', 'granaatõun'], set()],
#  [['alligaatorpirn', 'avokaado'], set()],
#  [['guajaav'], set()],
#  [['inglite vili', 'papaia'], set()],
#  [['kaktusvili'], set()],
#  [['draakonivili', 'pitaia'], set()],
#  [['kerimoia', 'suhkruõun'], set()],
#  [['kiivi'], set()],
#  [['longan'], set()],
#  [['nektariin'], set()],
#  [['hiina ploom', 'litš', 'litši'], set()],
#  [['litši', 'pulasan', 'rambutan'], set()],
#  [['viinamari'], {'kišmišš'}],
#  [['kišmišš'], set()],
#  [['mugulvili'], set()],
#  [['pähkel'],
#   {'Kreeka pähkel',
#    'akazuupähkel',
#    'areekapähkel',
#    'brasiilia pähkel',
#    'makadaamia',
#    'metspähkel',
#    'pekaanpähkel',
#    'pistaatsia'}],
#  [['areekapähkel', 'beetlipähkel'], set()],
#  [['metspähkel', 'sarapuupähkel'], set()],
#  [['Kreeka pähkel', 'kreeka pähkel'], set()],
#  [['pistaatsia', 'pistaatsiapähkel'], set()],
#  [['akazuupähkel',
#    'India pähkel',
#    'india pähkel',
#    'kašupähkel',
#    'nakar',
#    'nakra'],
#   set()],
#  [['pekaanpähkel'], set()],
#  [['brasiilia pähkel', 'parapähkel'], set()],
#  [['makadaamia', 'makadaamiapähkel'], set()],
#  [['mugul'], {'küüslauk'}],
#  [['küüslauk', 'noblu'], set()],
#  [['jaanikaun', 'jaanikõder', 'jaanileib', 'krõmpskaun'], set()],
#  [['mandel'], {'mõrumandel'}],
#  [['mõrumandel'], set()]]

# %% [markdown]
# # 2. Küsimuste genereerimine

# %%
#Küsimused
#üleüldised küsimused: Kas tegu on koduloomaga? kas tegu on metsloomaga? jne -- need sõnad võiks saada otse synsetidest -- hierarias eespool
#täpsemad küsimused: kas loom on punast värvi? kas tegu on tõuloomaga? jne -- need sõnad võiks saada definitsioonidest -- küsitakse hiljem

# %% [markdown]
# Ma ei saa lihtsalt võtta sobivad sõnad ja võtta nende synset, sest ühele sõnale võib vastata mitu erinevat synseti (nt ["Synset('hiir.n.01')", "Synset('arvutihiir.n.01')", "Synset('hiir.n.03')"])
#
# 06.02.25 1. katsetus oli, et võtaks selle listi mis ma loomadest tegin ja siis genereeriks nende sõnade peal küsimused, aga sattusin probleemi ette, et kui ma sellest sõnast synseti võtsin, siis mõnel juhul tuli vasteks mitu synseti. Kui seda viisi kasutada, siis tuleks teha lisa kontroll. (nt  wn["hiir"] == ["Synset('hiir.n.01')", "Synset('arvutihiir.n.01')", "Synset('hiir.n.03')"]). Seega otusustasin hetkel võtta lihtsalt kõik sõnad wn["loom"][0]-ist. äkki see ei tekita probleeme.
#
# tekkis mõte, et äkki saaks pärast mingeid sõnu eemalda, mille kohta pole piisavalt küsimusi. (al iga sõna kohta peab olema vähemalt 10 küsimust vms) -- ss äkki ei pea kasutama seda list_of_all_suitable_animals listi.

# %%
#üleüldised küsimused ja vastused
yleyldised_küsimused_vastused = {}
#täpsemad küsimused ja vastused
tapsemad_küsimused_vastused = {}

#Kõik kokku
küsimused_vastused = {}

# %% [markdown]
# See on hea et võtan kõik wn["loom"][0] sõnad ja teen nendest üleüldised küsimused

# %% [markdown]
# ### 2.1 üleüldised küsimused

# %%
# üleüldised küsimused
categories = [wn["söödav vili"][0]]
questions = set()

# Üldised küsimused hüpernüümide põhjal
for category in categories:
  for synset in category.closure("hyponym"):
      hypernyms = synset.hypernyms
      for hypernym in hypernyms:
          word = correct_word_form(hypernym.name, "sg kom")
          question = f"Kas tegu on {word}?"
          questions.add(question)
          # lisame igale küsimusele sõnad, mis vastavad sellele küsimusele jaatavalt
          yleyldised_küsimused_vastused.setdefault(question, set())

          yleyldised_küsimused_vastused[question].add(correct_word_form(hypernym.name, "sg n"))
          # Lisa alammõisted
          for alammõisted in hypernym.closure("hyponym"):
              yleyldised_küsimused_vastused[question].add(correct_word_form(alammõisted.name, "sg n"))
print(questions)
# Out:
# {'Kas tegu on sügisõunaga?', 'Kas tegu on mandliga?', 'Kas tegu on piimjuurega?', 'Kas tegu on persikuga?', 'Kas tegu on hernega?', 'Kas tegu on aedviljaga?', 'Kas tegu on fruktiga?', 'Kas tegu on lauguga?', 'Kas tegu on pähkliga?', 'Kas tegu on mariga?', 'Kas tegu on kirsiga?', 'Kas tegu on maasikaga?', 'Kas tegu on mugulaga?', 'Kas tegu on ivaga?', 'Kas tegu on kliiga?', 'Kas tegu on teraga?', 'Kas tegu on suvikõrvitsaga?', 'Kas tegu on sibulaga?', 'Kas tegu on viinamarjaga?', 'Kas tegu on greibiga?', 'Kas tegu on aedselleriga?', 'Kas tegu on kaarlaga?', 'Kas tegu on meloniga?', 'Kas tegu on tanguga?', 'Kas tegu on aedoaga?', 'Kas tegu on ploomiga?', 'Kas tegu on taliõunaga?', 'Kas tegu on laimiga?', 'Kas tegu on salatiga?', 'Kas tegu on kurgiga?', 'Kas tegu on rosinaga?', 'Kas tegu on söödavaga viljaga?', 'Kas tegu on ubinaga?', 'Kas tegu on kõrvitsaga?', 'Kas tegu on pirniga?', 'Kas tegu on tsitrusega?', 'Kas tegu on tatraga?', 'Kas tegu on juurikaga?', 'Kas tegu on mandariiniga?', 'Kas tegu on tomatiga?', 'Kas tegu on oaga?', 'Kas tegu on kuivatatuga viljaga?', 'Kas tegu on kiviviljaga?', 'Kas tegu on apelsiniga?', 'Kas tegu on banaaniga?', 'Kas tegu on nisuga?', 'Kas tegu on köögiviljaga?', 'Kas tegu on kaunviljaga?', 'Kas tegu on sõstraga?', 'Kas tegu on kapsapeaga?'}

# %% [markdown]
# lihtsalt koma juurest eraldades tekivad probleemid nagu:
#
# ```
# 'Kas see loom on tööloom? (tööloom, kelle kasv, lihased ja sitkus võimaldavad tal vedada raskeid koormaid)': {'raskeveohobune'},
#
# 'Kas see loom on kasv? (tööloom, kelle kasv, lihased ja sitkus võimaldavad tal vedada raskeid koormaid)': {'raskeveohobune'},
#
# 'Kas see loom on lihased sitkus võimaldavad vedada raskeid koormaid? *sõnastus veider (tööloom, kelle kasv, lihased ja sitkus võimaldavad tal vedada raskeid koormaid)': {'raskeveohobune'},
# ```

# %% [markdown]
# ### 2.2 definitsiooni põhjal küsimused

# %%
# Täpsemad küsimused -- kasutame ainult definitsioone

# (examples pole mõtet kasutada, sest nendest ei saa sisukaid küsimusi,
# nt (['Varblased tunglesid saiapalukese ümber.'] example)": {'varblane'},
# (['Nägime kardinali, kelle pea oli helepunane.'] example)": {'kardinal'}, (mõni hea aga pole väärt seda tööd))

# %%
import re
from collections import defaultdict

def generate_specific_questions(sentence):
    # Eemaldab ebavajalikud sõnad, leiab POS-märgendid ja teeb küsimused

    # eemaldame sulud ja sulgude sees olevad sõnad
    sentence = re.sub(r'\([^)]*\)', '', sentence)

    new_sentence = ""
    words_with_pos = []

    text = Text(sentence).tag_layer()

    for word in text.morph_analysis:
        wordPOS = word.partofspeech[0]
        words_with_pos.append((word.text, wordPOS))  # Salvestame nii sõna kui ka POS-i

    pos = [pos for _, pos in words_with_pos]  # Loome POS-ide listi
    seq_str = " ".join(pos)  # Muudame listi stringiks

    # 1. variant: "keegi, kes VERB..." -> "kas see loom VERB"
    if re.search(r"\bP Z P V\b", seq_str):
        remaining_words = [word for word, wordPOS in words_with_pos if wordPOS not in ["P", "Z", "P"]]
        result = f"Kas see taim {' '.join(remaining_words)}?"
        return result

    # 2. variant: asesõna + VERB -> asesõna asemele läheb 'loom' ('Kas see loom on ta on hundisuurune; tüvepikkus on 76–102 cm, saba pikkus 31–41 cm, õlakõrgus 60 cm ja mass 16–23 kg? {'hüään'})
    if re.search(r"^P V\b", seq_str):
        remaining_words = [word for word, wordPOS in words_with_pos[1:]]
        result = f"Kas see taim {' '.join(remaining_words)}?"
        return result
    else:
      result = f"Kas see taim on {sentence.strip()}?"
      return result

# %%
def pair_questions_answers(category):
    # küsimused ja vastused kokku
    definition_word = defaultdict(set)

    for words in category.closure("hyponym"):

        if words.definition:
          specific_questions = generate_specific_questions(words.definition)
          #specific_questions = specific_questions + " (" + str(words.definition)+ ")" # et näha tervet words.defi
          definition_word[specific_questions].add(correct_word_form(words.name , "sg n"))

    return definition_word

# %%
# Testimine
categories = [wn["söödav vili"][0]]
for category in categories:
    new_data = pair_questions_answers(category)  # Genereerime küsimused ja vastused

    # Ühendame uued vastused olemasolevatega
    for question, answers in new_data.items():
        tapsemad_küsimused_vastused.setdefault(question, set()).update(answers)

tapsemad_küsimused_vastused
# Out:
# {'Kas see taim on kapparipõõsa õitsemise järel saadav mari, mida kasutatakse marineerituna toiduks?': {'kappar'},
#  'Kas see taim on köögivili, puuvili ja aias kasvavad marjad?': {'aedvili'},
#  'Kas see taim on rohttaim, mille mingeid osi kasutatakse söögiks kas värskelt või töödeldult?': {'köögivili'},
#  'Kas see taim on soojalembene köögivili, mida kasutatakse rohkelt India ja kreooli köögis?': {'baamia'},
#  'Kas see taim on suvel v. varasügisel kasutatavate kõrvitsate üldnimetus?': {'suvikõrvits'},
#  'Kas see taim on on kõrvitsaliik, mille viljaliha muutub pärast küpsemist spagetisarnasteks ribadeks?': {'spagetikõrvits'},
#  'Kas see taim on rullkõrvitsataime vili toiduna?': {'kabatšokk'},
#  'Kas see taim on vees kasvav kõrreline, mille juuremugulaid kasutatakse palju Hiina köögis?': {'hiina alss'},
#  'Kas see taim on köögivili, millel toiduks tarvitatakse valget juurt, mõnedel sortidel ka lehti?': {'piimjuur'},
#  'Kas see taim on Aed-piimjuur on väga vana, maitselt sparglit meenutav kultuurtaim; koor on kreemikas ja sisu valge?': {'aed-piimjuur'},
#  'Kas see taim on rohkesti piimmahla sisaldav väike rohttaim, ka salatitaimena kasvatatav köögiviljataim .?': {'salat'},
#  'Kas see taim on mahlane ja krõmpsuvate lehtedega salat, mis on nt Caesari salati põhikomponent?': {'rooma salat'},
#  'Kas see taim on köögiviljana kasvatatav klaasjalt läikivate, kergelt külmununa näivate rabedate lehtedega aiataim?': {'jääsalat'},
#  'Kas see taim on Suurte söödavate viljadega ning lamavate vartega taime vili?': {'arbuus'},
#  'Kas see taim on mis tahes erinevad lihavad söödavad maa-alused juured või mugulad?': {'juurikas'},
#  'Kas see taim on suurt kartulit meenutav piklik mugul, millel on helepruun või punakas koor ja magus maitse?': {'bataat'},
#  'Kas see taim on köögiviljana või söödaks kasvatatav lihaka kollaka juurikaga rohttaim?': {'naeris'},
#  'Kas see taim on vastava kultuurtaime söödav vili?': {'maapirn'},
#  'Kas see taim on vastava kultuurtaime väikesed hea lõhna ja maitsega pead?': {'brüsseli kapsas'},
#  'Kas see taim on köögiviljana kasvatatav, tihedalt mähkunud lehtedest ühe suure pea moodustav aiataim, valge peakapsas?': {'peakapsas'},
#  'Kas see taim on rohelised v. kollakasrohelised piklikud viljad, mida tarvitatav toiduks?': {'kurk'},
#  'Kas see taim on hapendatud kurk?': {'hapukurk'},
#  'Kas see taim on suurte ümarjate viljade ja lamavate v. ronivate vartega köögiviljakultuuri söödav vili?': {'kõrvits'},
#  'Kas see taim on väike tumeroheline või kollane squash kollase kuni oranži lihaga?': {'tõrukõrvits'},
#  'Kas see taim on köögivilljataim, millel söömiseks kasutatakse valmimata rohelisi vilju, noori võrseid ja lehti?': {'karella'},
#  'Kas see taim on intentsiivse lõhnaga, enamasti tumekollase viljalihaga soojalembene kõrvitsaline?': {'muskaatkõrvits'},
#  'Kas see taim on haruldane ja hinnatud kõrvitsasort, mille suured roosa banaani kujulised viljad on maitsvad ja säilivad hästi kevadeni?': {'banaankõrvits'},
#  'Kas see taim on rohelise viljalihaga kõrvits, mis meenutab tsukiinit?': {'kokosell'},
#  'Kas see taim on õli pressimiseks kasvatatav kõrvitsaline?': {'õlikõrvits'},
#  'Kas see taim on pikliku kõverdunud viljaga köögivili kõrvitsaliste sugukonnast?': {'keerdkaelaline kõrvits'},
#  'Kas see taim on kettakujuline köögivili kõrvitsaliste sugukonnast?': {'patisson'},
#  'Kas see taim on kaunu kasvatav põllu- v. aiakultuur, mille vilju ja seemneid kasut. toiduks v. söödaks?': {'kaunvili'},
#  'Kas see taim on kaunviljade hulka kuuluva hrl. aia- ja põllukultuurina kasvatatava ümmarguste seemnetega ronitaime söödav seeme?': {'hernes'},
#  'Kas see taim on üks söögiherne sort?': {'aedhernes'},
#  'Kas see taim on valgurikas kaunvili, mida kasutatakse palju Vahemere, Araabia ja Aasia köökides?': {'kikerhernes'},
#  'Kas see taim on hrl. põllukultuurina kasvatatav liblikõieline suurte seemnetega kaunvili?': {'uba'},
#  'Kas see taim on musta kestaga uba, mis on maitselt pehme, magus ja pisut mullane?': {'must uba'},
#  'Kas see taim on tumepunase kestaga uba, mille kuju meenutab neeru?': {'punane uba'},
#  'Kas see taim on väga proteiinirikas aedvili?': {'soja'},
#  'Kas see taim on liblikõieliste sugukonda kuuluv, nõrgalt haruneva lühikese või kõrge varrega taim?': {'aeduba'},
#  'Kas see taim on punane väike aeduba?': {'adzuki'},
#  'Kas see taim on väike roheline uba, väga levinud Aasia köögis?': {'munguba'},
#  'Kas see taim on laukude hulka kuuluv köögiviljataim?': {'sibul'},
#  'Kas see taim on mitmeaastane talvekindel köögiviljataim?': {'talisibul'},
#  'Kas see taim on väike mahedamaitseline sibul?': {'pesasibul'},
#  'Kas see taim on violetse värvuse ja mahedama maitsega sibul?': {'punane sibul'},
#  'Kas see taim on peam. punaste lihakate viljadega köögivilja söödav vili?': {'tomat'},
#  'Kas see taim on väikeseviljaline tomatisort?': {'kirsstomat'},
#  'Kas see taim on väike ploomikujuline tomatisort?': {'ploomtomat'},
#  'Kas see taim on vähese seemnehulga ja rohke viljalihaga tomat?': {'lihatomat'},
#  'Kas see taim on köögiviljana kasvatatav lehtedest moodustunud varrega, sibulast mahedama maitsega rohttaim?': {'porrulauk'},
#  'Kas see taim on köögivilja- ja maitsetaim?': {'aedseller'},
#  'Kas see taim on köögiviljana kasvatatav tumeroheliste lehtede ja väikeste valgete õitega aromaatne rohttaim, millest peale lehtede ja leherootsude tarvitatakse toiduks ka ümmargust lihakat juurt; aedselleri teisend?': {'juurseller'},
#  'Kas see taim on selleri teisend, mis ei kasvata juurvilja ega lehevarsi vaid lehed, mis sobivad hästi toidu maitsestamiseks?': {'lehtseller'},
#  'Kas see taim on köögiviljana kasvatatav tumeroheliste lehtede ja väikeste valgete õitega aromaatne rohttaim, millest toiduks tarvitatakse suuri lehti ja mahlakaid leherootse, aedselleri teisend?': {'varsseller'},
#  'Kas see taim on saadus kapsa taimest?': {'kapsapea'},
#  'Kas see taim on riivitud kapsas?': {'riivkapsas'},
#  'Kas see taim on lillakate lehtedega kapsas, mis kuulub ristõieliste taimede perekonda?': {'punane kapsas'},
#  'Kas see taim on karuohakat meenutav suurte hallikasroheliste lehtede ja soomustega kaetud õisikutega rohttaim, mida kasvatatakse köögiviljana ja ilutaimena?': {'artišokk'},
#  'Kas see taim on India päritolu tomatitaoline köögiviljataime vili?': {'baklažaan'},
#  'Kas see taim on iseloomulikult lõhnava jämeda risoomi v. sibulaga ning ruljate rootsuta lehtedega taime söödav osa?': {'lauk'},
#  'Kas see taim on laukude hulka kuuluv köögiviljataim ; selle söödav valge sibulake?': {'pärlsibul'},
#  'Kas see taim on hrl aias maitsetaimena kasvatatav püstise varre, õõnsate ruljate lehtede ja lillade õitega rohttaim?': {'murulauk'},
#  'Kas see taim on amarülliliste sugukonda kuuluv taimeliik?': {'nurmlauk'},
#  'Kas see taim on karulaugu sibul maitseainena?': {'karulauk'},
#  'Kas see taim on köögiviljana kasvatatav lamedate lehtedega kaheaastane lauk?': {'porru'},
#  'Kas see taim on küüslaugulõhnaliste lehtedega maitse- ja ravimtaim, millel kasutatakse söögiks peamiselt lehti, kuid ka varsi, õisi ja sibulat?': {'karulauk'},
#  'Kas see taim on puisniitudel ja niitudel kasvav lauk?': {'metslauk'},
#  'Kas see taim on kitsaste roheliste lehtede ja väikese sibulaga rohttaim?': {'rohulauk'},
#  'Kas see taim on ühe troopikataime magusamaitseline mahlakas ümar vili?': {'melon'},
#  'Kas see taim on , želeetaolise viljalihaga lõunamaa vili?': {'kivaano'},
#  'Kas see taim on maitsetaimena ja köögiviljana kasvatatav porganditaolise kollakasvalge juurega aiataim?': {'aed-moorputk'},
#  'Kas see taim on Rabarberi mahlakas lehevars toiduainena?': {'rabarber'},
#  'Kas see taim on sparglitaime söödavad noored võrsed?': {'aspar'},
#  'Kas see taim on spinatitaime raua- ja vitamiinirikkad lehed ja lehevarred toiduna?': {'spinat'},
#  'Kas see taim on suure ümara kauna taoline mahedamaitseline, mahlakas, värvikas vili köögiviljana?': {'paprika'},
#  'Kas see taim on aedvili, millest toiduks kasutatakse lehti?': {'lehtaedvili'},
#  'Kas see taim on troopilises Ameerikas kasvava kannatuslille söödav vili?': {'granadill'},
#  'Kas see taim on teravilja seeme, viljatera?': {'iva'},
#  'Kas see taim on kanepitaime toitainerikkad seemned, mida süüakse niisama või kasutatakse leiva vm toiduainete sees lisandina?': {'kanepiseeme'},
#  'Kas see taim on linataime seemned, mis sisaldavad palju inimesele kasulikke vitamiine, mineraalaineid, kiudaineid jms?': {'linaseeme'},
#  'Kas see taim on Hariliku seesami tillukesed lamedad seemned?': {'seesamiseeme'},
#  'Kas see taim on päevalillede söödav seeme;kasutatakse toidu ja linnuliha söödana ning õliallikana?': {'päevalilleseeme'},
#  'Kas see taim on väike hall mooniõie seeme; kasutatud tervena või jahvatatult küpsetistes?': {'moon'},
#  'Kas see taim on seedermänni söödav seeme?': {'piiniaseeme'},
#  'Kas see taim on teravilja seeme?': {'tera'},
#  'Kas see taim on kehv või tühi viljatera, tühi kest?': {'kõlutera'},
#  'Kas see taim on tatrataime vili , ka toiduna?': {'tatar'},
#  'Kas see taim on tatar, millel kestad on teradest eemaldatud kuivkoorimise, mitte kuumutamise teel?': {'toortatar'},
#  'Kas see taim on jahvatamise saadus, miski jahvatatu?': {'jahvatis'},
#  'Kas see taim on teravilja jahvatamisel eraldatud seemnekestad koos nende külge jäänud taimekoe- ja iduosadega?': {'klii'},
#  'Kas see taim on nisuteradelt jahvatamisel eraldatud kestad?': {'nisuklii'},
#  'Kas see taim on piim- v. vahaküpsuses koristatud teravili, mida sileeritakse v. kuivatatakse söödaks?': {'vilis'},
#  'Kas see taim on teravilja  kooritud ja lihvitud terad?': {'kruup'},
#  'Kas see taim on teravilja tera, tavaliselt jahvatatud jahuks?': {'nisu'},
#  'Kas see taim on leotatud, keedetud, kuivatatud ja lõpuks purustatud nisu?': {'bulgur'},
#  'Kas see taim on kaerataime vili?': {'kaer'},
#  'Kas see taim on teravilja  kooritud ja purustatud tera?': {'tang'},
#  'Kas see taim on maisi kooritud ja purustatud tera; sellised terad kogumina?': {'maisitang'},
#  'Kas see taim on odra kooritud ja purustatud tera?': {'odratang'},
#  'Kas see taim on eelaurutatud ja purustatud nisutangud?': {'kuskuss'},
#  'Kas see taim on hirsi kooritud ja purustatud tera?': {'hirsitang'},
#  'Kas see taim on Põhja-Ameerika veerohu terad?': {'indiaani riis'},
#  'Kas see taim on idandatud ja kuivatatud teravili, mida kasutatakse õlle, viski ja äädika valmistamisel ning pagaritööstuses jahu küpsetusomaduste parandamiseks ja värvi, lõhna või maitse lisamiseks?': {None},
#  'Kas see taim on üheseemneline vili, milles seemet ümbritseb puitunud sisekest, luu ehk kivi?': {'kivivili'},
#  'Kas see taim on loorberi must luuvili?': {'loorberimari'},
#  'Kas see taim on hapukirsipuu vili?': {'hapukirss'},
#  'Kas see taim on aprikoosipuu viltjas-karvane luuvili?': {'aprikoos'},
#  'Kas see taim on mõnede mangopuude söödav magushapu viljalihaga luuvili?': {'mango'},
#  'Kas see taim on õlipuu ploomitaoline söödav luuvili?': {'oliiv'},
#  'Kas see taim on kirsipuu vili?': {'kirss'},
#  'Kas see taim on klaas-kirsipuu heledaviljaline värvitu mahlaga vili?': {'klaaskirss'},
#  'Kas see taim on kookospalmi vili?': {'kookos'},
#  'Kas see taim on ploomi moodi ümmargused, enamasti kollased viljad?': {'mirabell'},
#  'Kas see taim on murelipuu tume vili?': {'murel'},
#  'Kas see taim on taimede lihakas hulgaseemneline vili,  lihakas söödav koguvili v. luuvili?': {'mari'},
#  'Kas see taim on rabaservadel ja siirdesoodes kasvava sinakasroheliste lehtedega kääbuspõõsa, sinika mari?': {'joovikas'},
#  'Kas see taim on erinevate astelpajude viljad, mis annavad värvaineid või pigmente?': {'astelpaju'},
#  'Kas see taim on sõstrapõõsa mari?': {'sõstar'},
#  'Kas see taim on sõstraliste sugukonda kuuluv marjakultuur?': {'valge sõstar'},
#  'Kas see taim on punasesõstrapõõsa punane mari?': {'hõrakmari'},
#  'Kas see taim on sõstramari, mis on musta värvi ja iseloomuliku maitsega?': {'must sõstar'},
#  'Kas see taim on punast sõstart meenutavate, kuid magedate, maitsetute marjadega lehtpõõsas?': {'mage sõstar'},
#  'Kas see taim on looduslikult kasvava või aedades kasvatatava püstiste varte ja hrl punaste marjadega lehtpõõsa mari?': {'vaarikas'},
#  'Kas see taim on metsas kasvava taime mari?': {'metsamari'},
#  'Kas see taim on mustade vaarikasarnaste viljadega poolpõõsas?': {'aedmurakas'},
#  'Kas see taim on Pamplite ja vaarikate vahelised ristandid?': {'vaarikpampel'},
#  'Kas see taim on kadakapuu väike käbi, mida kasutatakse toitude ja jookide maitsestamiseks?': {'kadakamari'},
#  'Kas see taim on tomatipuu hrl. pruunikaspunase kestaga piklikmunajas söödav mari?': {'tamarillo'},
#  'Kas see taim on hrl. rabamuraka punakas, valminult kollane vili.?': {'kaarel'},
#  'Kas see taim on põldmuraka mari?': {'põldmari'},
#  'Kas see taim on punaste õite ja viljadega murakas?': {'mesimurakas'},
#  'Kas see taim on sõstraliste sugukonda kuuluv marjakultuur ja taimeperekond?': {'karusmari'},
#  'Kas see taim on maasikataime magus punane vili?': {'maasikas'},
#  'Kas see taim on looduslikult kasvav kolmeosaliste lehtede, valgete õite ja väikeste punaste viljadega madal rohttaim?': {'metsmaasikas'},
#  'Kas see taim on aedmaasika vili?': {'aedmaasikas'},
#  'Kas see taim on muuluka valkjas, tipust punane söödav vili?': {'muulukamari'},
#  'Kas see taim on punane marjataoline puuvili?': {'pihlakamari'},
#  'Kas see taim on hariliku viigipuu vili.?': {'viigimari'},
#  'Kas see taim on jõhvikataime söödav tumepunane hapu mari?': {'jõhvikas'},
#  'Kas see taim on alrauni vili, sisaldab tugevatoimelisi alkaloide: hüostsüamiini ja skopolamiini?': {'alrauni mari'},
#  'Kas see taim on hrl. okasmetsas kasvava heitlehelise kääbuspõõsa, mustika mari?': {'mustikas'},
#  'Kas see taim on söödav, valmina punane hapu mari?': {'palukas'},
#  'Kas see taim on kuivatatud viinamari?': {'rosin'},
#  'Kas see taim on väike suhkrurikas seemneteta rosin?': {'korint'},
#  'Kas see taim on kollakas-rohelisest  viinamarjast saadav rosin?': {'sultana'},
#  'Kas see taim on kuivatatud aprikoos?': {'urjukk'},
#  'Kas see taim on toiduks tarvitatav viljapuu vili?': {'frukt'},
#  'Kas see taim on aromaatsed hapu maitsega pirnikujulised viljad, mida kasutatakse hoidistes?': {'küdoonia'},
#  'Kas see taim on kollane, tähekujulise ristlõikega troopiline puuvili?': {'karamboola'},
#  'Kas see taim on peamiselt Aasias kasvatav oranži värvusega magusamaitseline puuvili?': {'diospüür'},
#  'Kas see taim on piklik, kollasekooreline suhkru- ning tärkliserikas puuvili?': {'banaan'},
#  'Kas see taim on Ladina-Ameerikas populaarne banaanisort, mida süüakse vaid küpsetatud kuju?': {'jahubanaan'},
#  'Kas see taim on ploomipuu vili?': {'ploom'},
#  'Kas see taim on roheline ploom?': {'renklood'},
#  'Kas see taim on punane, kollane v. roheline õunapuu vili?': {'ubin'},
#  'Kas see taim on väike hapu õun?': {'viss'},
#  'Kas see taim on metsõunapuu õun?': {'metsõun'},
#  'Kas see taim on söögi juurde pakutav magus õun?': {'dessertõun'},
#  "Kas see taim on 'Pärnu tuviõuna' sorti sügisõun v. 'Krügeri tuviõuna' sorti suviõun?": {'tuviõun'},
#  'Kas see taim on säilitamiseks ettenähtud õun?': {'säilitusõun'},
#  'Kas see taim on keskmise suurusega kuldkollane ja väga hea maitsega sügisõun?': {'kuldrenett'},
#  'Kas see taim on keskmise suurusega kollakasvalge maitsev suviõun, mille viljaliha on roosakate laikude ja triipudega?': {'suislepp'},
#  "Kas see taim on kollakasvalge suviõun, sordilt 'Valge klaarõun'?": {'klaar'},
#  'Kas see taim on sügisel valmiv, hrl ületalve säiliv  õun?': {'taliõun'},
#  "Kas see taim on 'Antonovka' sorti taliõun?": {'antoonovka'},
#  'Kas see taim on suvel valmiv õun, mis ei säili ületalve?': {'suviõun'},
#  'Kas see taim on väike sibulakujuline rohekaskollane maitsev taliõun?': {'sibulõun'},
#  'Kas see taim on paradiisiõunapuu vili?': {'paradiisiõun'},
#  'Kas see taim on sügisel valmiv õun?': {'sügisõun'},
#  'Kas see taim on teatud sügisõunasortide rühm?': {'renett'},
#  'Kas see taim on pirnipuu vili?': {'pirn'},
#  'Kas see taim on ümarate viljadega pirnisort?': {'bergamott'},
#  'Kas see taim on ogaline peasuurune tugeva spetsiifilise lõhnaga durianipuu vili; koosneb mitmest sektorist?': {'durian'},
#  'Kas see taim on hariliku virsikupuu mahlakas viltja kestaga luuvili?': {'persik'},
#  'Kas see taim on Hiinast pärit lameda virsikupuu mahlane, õrna viljalihaga ja magusa maitsega lameda kujuga vili?': {'lamevirsik'},
#  'Kas see taim on Ananassi taime suur käbijas vilikond?': {'ananass'},
#  'Kas see taim on nt apelsini-, greibi-, sidrunipuu) mahlakas vili?': {'tsitrus'},
#  'Kas see taim on laimipuu vili?': {'laim'},
#  'Kas see taim on Austraaliast pärit, kujult kurki meenutav tumeroheline või tumepunane sõrm-pisilaimipuu vili?': {'sõrmlaim'},
#  'Kas see taim on Tai köögis laialdaselt kasutatavad kahvrilaimipuu vili?': {'kahvrilaim'},
#  'Kas see taim on pomelipuu suur paksukooreline söödav vili?': {'pomel'},
#  'Kas see taim on selle puu suur apelsinitaoline mõrkjasmagusa mahlaga vili.?': {'greip'},
#  'Kas see taim on punase viljaliha ja mahlaga greip?': {'punagreip'},
#  'Kas see taim on kinkanipuu vili?': {'kinkan', 'munakinkan'},
#  'Kas see taim on tangeriinipuu vili?': {'tangeriin'},
#  'Kas see taim on hariliku sidrunipuu vili?': {'sidrun'},
#  'Kas see taim on apelsinipuu mahlakas ning aromaatne oranš vili?': {'apelsin'},
#  'Kas see taim on punase viljaliha ja mahlaga apelsin?': {'veriapelsin'},
#  'Kas see taim on pomerantsipuu apelsinitaoline hapu vili?': {'pomerants'},
#  'Kas see taim on mandariinipuu vili?': {'mandariin'},
#  'Kas see taim on väike seemneteta mandariin?': {'klementiin'},
#  'Kas see taim on punane Jaapani mandariin?': {'satsuma'},
#  'Kas see taim on punase kestaga, paljusid mahlaseid tumepunaseid söödavaid seemneid sisaldav granaadipuu vili?': {'granaat'},
#  'Kas see taim on Ameerika pirnloorberi  vili?': {'alligaatorpirn'},
#  'Kas see taim on guajaavipuu kollane pirnjas vitamiinirikas vili?': {'guajaav'},
#  'Kas see taim on suured ovaalsed melonilaadsed kollaka lihaga troopilised viljad?': {'inglite vili'},
#  'Kas see taim on suureviljalise viigikaktuse  söödav, viigimarja meenutav vili?': {'kaktusvili'},
#  'Kas see taim on Kagu- ja Lõuna-Aasias vm kasvatatava maasik-metskaktuse  söödav vili, millel on punane koor ja väikeste mustade seemnetega valge pehme sisu?': {'draakonivili'},
#  'Kas see taim on Peruu ja Ecuadori Andide mägiorgudest pärineva viljapuu  rohekaskollase koorega magusamaitseline ümar vili?': {'kerimoia'},
#  'Kas see taim on piklikümar pruunikas roheka viljalihaga  puuvili?': {'kiivi'},
#  'Kas see taim on sileda koorega virsik, nektariinipuu vili?': {'nektariin'},
#  'Kas see taim on litšipuu kerajas magushapu viljalihaga vili?': {'hiina ploom'},
#  'Kas see taim on rambutanipuu vili?': {'litši'},
#  'Kas see taim on viinapuu mahlakas suhkrurikas vili?': {'viinamari'},
#  'Kas see taim on peenike seemneteta viinamari?': {'kišmišš'},
#  'Kas see taim on söödavate või söödaks tarvitatavate mugulatega taim?': {'mugulvili'},
#  'Kas see taim on mingi kõvakestaline söödav vili v. seeme?': {'pähkel'},
#  'Kas see taim on beetli-areekapalmi seeme, mida kasutatakse ergutava toimega närimisainena?': {'areekapähkel'},
#  'Kas see taim on perekonna Corylus mitme puu pähkel?': {'metspähkel'},
#  'Kas see taim on Kreeka pähklipuu luuvili, mille söödav seeme koosneb kahest sopilisest poolmest?': {'Kreeka pähkel'},
#  'Kas see taim on pistaatsia luuvili?': {'pistaatsia'},
#  'Kas see taim on lääneanakardi ehk india nakrapuu seeme?': {'akazuupähkel'},
#  'Kas see taim on pole tegelikult pähkel vaid on luuvili ehk vili ühe seemnega, mida ümbritseb kest?': {'pekaanpähkel'},
#  'Kas see taim on parapähklipuu vili?': {'brasiilia pähkel'},
#  'Kas see taim on Austraalias, Indoneesias ja Madagaskaril kasvav igihaljas lehtpuu või -põõsas, mille mõnd liiki kasvatatakse pähklitaoliste seemnete saamiseks?': {'makadaamia'},
#  'Kas see taim on juure v. varre lihakas toitainerikas paksend?': {'mugul'},
#  'Kas see taim on küüslaugu taime sibul?': {'küüslauk'},
#  'Kas see taim on jaanikaunapuu söödav vili?': {'jaanikaun'},
#  'Kas see taim on mandlipuu luuseemne õlirikas tuum?': {'mandel'},
#  'Kas see taim on kasutatakse peamiselt essentsi jms valmistamiseks?': {'mõrumandel'}}

# %%
len(tapsemad_küsimused_vastused)
# Out:
# 221

# %% [markdown]
# ### 2.3 Wordneti teised seosed

# %% [markdown]
# 1. Kui ma hetkel võtan mingi mõiste ja saan teada, millega ta seotud on, siis kas ma saan kindel olla, et selle mõiste alammõisted on ka nende sõnadega seotud
#  - pigem ei saa vist seda eeldada, aga kui mitte võtta kõiki suhteid, siis äkki on fine
#
#
# 2. Olen saanud kätte sõnad ja nende teised seosed. Nüüd tuleks teha eraldi kontroll, et ma ei lisaks küsimusi, mis on juba olemas ala siidisabale 'kas on laululind?', sest eelduslikult võiks selline küsimus juba olemas olla. Samas tuleks üle kontrollida kas ikka on
#
# 3. millised küsimusi täpselt koostada
#
# 4. olenevalt seose tüübist tuleb ka küsimus moodustada (vb tuleb mõni seos veel eemaldada)

# %%
def otherRelations(synsets):
    word_info = []
    for synset in synsets:
        relations = {}

        for relation in wn.all_relation_types():
            if relation not in ["hyponym", "hypernym", "domain_topic", "antonym", "similar"]:
                related_synsets = synset.get_related_synset(relation)
                if related_synsets:
                    relations[relation] = [str(r_synset.lemmas[0]) for r_synset in related_synsets]

        if relations:  # Ainult siis, kui on seoseid
            word_info.append([synset, relations])

    return word_info

# %%
otherRelations = otherRelations(taimed)

# %%
# vaatame palju seoseid sõnadel on
#for mõiste, seosed in otherRelations:
  #print(seosed)
 # print(mõiste, len(seosed.keys()), list(seosed.values()))

# %%
# Kui paljudel loomadel leidub lisaseoseid?
print(len(otherRelations))
print(len(taimed))
# Out:
# 123

# %%
# vaatame milliseid seoseid mul leidub
unikaalsed_seosed = set()
for mõiste, seosed in otherRelations:
  for relation_type, relations in seosed.items():
    unikaalsed_seosed.add(relation_type)

print(unikaalsed_seosed, len(unikaalsed_seosed))
# Out:
# {'be_in_state', 'state_of', 'mero_part', 'role', 'mero_location', 'holo_substance', 'instrument', 'holo_member', 'holo_location', 'holo_portion', 'holo_part', 'holonym', 'also', 'meronym', 'mero_member', 'mero_substance'} 16

# %%
# vaatame milliseid seoseid oleks mõistlik kasutada

all_related_words_by_type = {}

for mõiste, seosed in otherRelations:
    for relation_type, relations in seosed.items():
        if relation_type not in all_related_words_by_type:
            all_related_words_by_type[relation_type] = set()  # Kasutame hulka, et vältida kordusi
        all_related_words_by_type[relation_type].update(relations)  # Lisame seotud sõnad hulka

for relation_type in all_related_words_by_type:
    all_related_words_by_type[relation_type] = list(all_related_words_by_type[relation_type])

for relation_type, words in all_related_words_by_type.items():
    print(f"{relation_type}: {words}")
# Out:
# holo_substance: ['aedviljasalat', 'kirsikompott', 'kurgivesi', 'kapsastruudel', 'vaarikasiirup', 'karusmarjakissell', 'hernepüree', 'aprikoosikompott', 'sidruniekstrakt', 'tofu', 'puuviljakook', 'salsa', 'pohlahoidis', 'maasikahoidis', 'murakakeedis', 'marjakook', 'õunapüree', 'päevalillekook', 'karulaugupesto', 'viinamarjavein', 'kadakaõli', 'puuviljakonserv', 'sõstrakeedis', 'ananassimahl', 'karusmarjakook', 'sibulasalat', 'virsikukompott', 'pihlakavein', 'sojakook', 'galett', 'mustikakissell', 'ananassikonserv', 'pihlakakeedis', 'ploomimahl', 'virsikukaste', 'aprikoos', 'rabarberikook', 'sellerisool', 'juurviljapüree', 'jõhvikajook', 'sibulakaste', 'sibulasai', 'linnasejahu', 'Bologna kaste', 'õunaviin', 'linakook', 'kreekapähklisai', 'karusmarjamahl', 'maasikakeedis', 'puuviljapuding', 'sibulasiirup', 'puuviljakreem', 'tapenaad', 'jõhvikakeedis', 'sõstravein', 'marjamahl', 'õunakaste', 'marjasiirup', 'rosinakukkel', 'õunasalat', 'õunakook', 'kaeratumm', 'grenadiin', 'murakamahl', 'sidrunimahl', 'köögiviljamahl', 'aioli', 'tatrapuder', 'tanguvorst', 'pirnisiider', 'puuviljavein', 'pistaatsiaküpsis', 'kliirokk', 'kadajataar', 'sidrunisiirup', 'ratatouille', 'aedviljakonserv', 'vaarikamahl', 'viinamarjamahl', 'kapsakotlet', 'vaarikakeedis', 'õunakompott', 'apelsinivesi', 'küüslaugukaste', 'kõrvitsapüree', 'mandariinimahl', 'sültkapsad', 'maasikamahl', 'kaeratangupuder', 'ploomikompott', 'virsikumahl', 'tomatipasta', 'teratoit', 'puuviljajook', 'viljakohv', 'õunavorm', 'pähkliküpsis', 'tempeh', 'sõstramahl', 'banaanijäätis', 'kookosmakroon', 'moonikook', 'õunakreem', 'aedviljapüree', 'vaarikahoidis', 'hernepuder', 'õunasiider', 'aedviljapuljong', 'mähk', 'karusmarjahoidis', 'sibulapirukas', 'ploomimehu', 'pirnikompott', 'sibulaomlett', 'mustikamahl', 'marjapirukas', 'seesamikook', 'puuviljasalat', 'tikrikeedis', 'mustikahoidis', 'sinepipulber', 'kurgikreem', 'ploomipuding', 'vesihoidis', 'mustasõstravein', 'tangupuder', 'pohlasalat', 'tabbouleh', 'pähklikreem', 'limonaad', 'sukaad', 'marjapüree', 'puuviljasiirup', 'ploomikaste', 'puuviljapüree', 'Mulgi puder', 'õunamehu', 'aprikoosimahl', 'sõstrahoidis', 'kaerakamajahu', 'pohlakeedis', 'ploomikeedis', 'kookosekook', 'segakompott', 'pähklitort', 'karusmarjavein', 'jahuvorst', 'maisikook', 'ploomiviin', 'pihlakaviin', 'sidrunijook', 'õunavein', 'jõhvikamahl', 'sidrunivõie', 'mangomahl', 'sojakaste', 'spinatipirukas', 'õlts', 'karusmarjakompott', 'köögiviljavorm', 'puuviljatort', 'tanguleem', 'hefu', 'manna', 'rabarberikissell', 'laimivesi', 'õunakeedis', 'mustasõstramahl', 'rosinakeeks', 'apelsinimahl', 'pähklirosinaküpsis', 'kile', 'kirsikeedis', 'kõrvitsapirukas', 'jõhvikakissell', 'marjakompott', 'rosinaküpsis', 'sidrunikreem', 'puuviljakompott', 'pirnimahl', 'mustikapirukas', 'letšo', 'virsikukook', 'maasikakompott', 'džinn', 'kurgisalat', 'kirsisiirup', 'mämm', 'õunamahl', 'kirsimahl', 'kõrvitsasalat', 'sidrunisooda', 'rabarberipirukas', 'remulaad', 'rosinakringel']
# holonym: ['tarbeaed', 'sügissort', 'suvesort', 'murakas', 'küüslaugusool', 'vaarikas', 'jõhvikas', 'mustikas', 'sibulamoos', 'opuntsia', 'hapukapsas', 'Caesari salat', 'sinep', 'seemnesegu', 'mais', 'kreegipuu', 'pohl', 'kurgitünn']
# holo_member: ['hapukurgisalat', 'köögiviljaaed', 'kõrvitsaline']
# holo_part: ['kapsas', 'seesam', 'aktiniidia', 'harilik virsikupuu', 'kinkan', 'ploom', 'granaadipuu', 'pomerantsipuu', 'mango', 'tomatipuu', 'loorber', 'karamboola', 'Brasiilia pähklipuu', 'juurviljahoidla', 'hapukirsipuu', 'kadajas', 'guajaavipuu', 'harilik viigipuu', 'viinamari', 'harilik pistaatsia', 'tiibpähklipuu', 'must pähklipuu', 'põldmurakas', 'tzatziki', 'mandariin', 'puuviljaaed', 'kõrvits', 'teravili', 'maisitõlvik', 'paradiisiõunapuu', 'banaan', 'kanep', 'pirn', 'kookospalm', 'mirabell', 'durianipuu', 'soolauba', 'vaarikpampel', 'marjakobar', 'alraun', 'nektariinipuu', 'päevalill', 'lina', 'astelpaju', 'greibipuu', 'mulgikapsad', 'aiva', 'bergamotipuu', 'uibu', 'maapähklivõi', 'apelsin', 'pähklipuu', 'tangeriinipuu', 'sükomoor-viigipuu', 'harilik õlipuu', 'põllumajandussaadus', 'sidrun', 'rambutan', 'magun', 'tsitrus', 'pihelgas', 'küüslauk', 'hirss', 'mitmeviljahelbed', 'diospüür', 'melonipuu', 'murel', 'kuskuss']
# mero_part: ['gluteen', 'kapsaleht', 'söödakaunvili', 'vaarikas', 'kõrvitsaseeme', 'söödajuurvili', 'aedmurakas', 'amügdaliin', 'koiir', 'roheline sibul', 'küüs']
# role: ['herneteramardikas', 'vaarikasaak', 'kroovikast', 'sibulakärbes', 'akažuupuu', 'herkulo']
# mero_substance: ['sojapiim', 'sojaõli', 'maisijahu', 'kanepiseemneõli', 'falafel', 'nugat', 'linaseemneõli', 'polenta', 'plaksumais', 'tatrajahu', 'viinamarjaseemneõli', 'miso', 'kookospiim', 'külmpressitud oliiviõli', 'kikerhernejahu', 'sojajahu', 'palsamiäädikas', 'maisitärklis', 'seesamipasta', 'hummus', 'maisiõli', 'kookoshelves', 'maapähkliõli']
# be_in_state: ['oakujuline', 'hapu', 'mugul']
# also: ['pirnikujuline', 'riivima']
# state_of: ['lääts']
# holo_portion: ['viljakott', 'nisukott', 'tangukott', 'rukkikott', 'terasaak', 'seemnekott', 'odrakott']
# meronym: ['virsikukivi', 'banaanikoor', 'viljaluu', 'kirsikivi', 'prolamiin', 'maisitang']
# mero_member: ['külvis']
# mero_location: ['tuum']
# holo_location: ['astelpajumahl', 'aiamaa', 'alu']
# instrument: ['rebane']

# %%
# kasutame edaspidi ainult mõistlikuid seosed (holo_member, mero_member, involved_location, agent, holo_location, holo_substance, be_in_state, mero_substance)
valid_relation_types = {"holo_member", "mero_member", "involved_location", "agent", "holo_location", "holo_substance", "be_in_state", "mero_substance"}

filtered_otherRelations = []

for mõiste, seosed in otherRelations:
    filtered_seosed = {relation_type: relations for relation_type, relations in seosed.items() if relation_type in valid_relation_types}
    if filtered_seosed:
        filtered_otherRelations.append([mõiste, filtered_seosed])

# filtreeritud ja sobivad seosed
otherRelations = filtered_otherRelations

# %%
# Teha seoste sõnadest küsimused (kasutame ainult neid seoseid, sest need on kõige mõistlikumad:
# holo_member, mero_member, involved_location, agent (tegusõnad), holo_location)

# word_and_relations = {'holo_part': ['kanakasvatus'], 'mero_part': ['kanamuna']}
# Põhjendus: # akki state_of eemaldada: sõna 'koduveis' seos 'vasikas' ({'state_of': ['vasikas']
# Sõna be_in_state eemaldada 'isatiiger' seos 'isane' ({'be_in_state': ['isane']}) esines küsimuses 'Kas see loom on isane vasikas?', aga pole lisatud {'härgvasikas'}

def generateOtherRelationsQuestion(relation, relation_type):
  question = ""

  if relation_type in  ["holo_member", "mero_member"]:
    question = f"Kas tegu on {correct_word_form(relation, 'sg kom')}?"
  elif relation_type in  ['involved_location', 'holo_location']:
    question = f"Kas see taim võib leiduda {correct_word_form(relation, 'sg in')}?"
  elif relation_type in  ['holo_substance', 'mero_substance']:
    question = f"Kas sellest taimest saab teha {correct_word_form(relation, 'sg p')}?"
  elif relation_type in  ['be_in_state']:
    question = f"Kas see taim on {correct_word_form(relation, 'sg n')} ?"
  elif relation_type in  ["agent"]:
    relation_pos = Text(relation).tag_layer().morph_analysis.partofspeech[0]
    if relation_pos[0] == "V": # võtame ainult tegusõnad
      question = f"Kas see taim {correct_word_form(relation, 'b')}?"
  return question

# %%
yleyldised_küsimused_vastused
# Out:
# {'Kas tegu on söödavaga viljaga?': {'Kreeka pähkel',
#   None,
#   'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedmaasikas',
#   'aedmari',
#   'aedmurakas',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'akazuupähkel',
#   'alligaatorpirn',
#   'alrauni mari',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'aprikoos',
#   'arahhis',
#   'arbuus',
#   'areekapähkel',
#   'artišokk',
#   'aspar',
#   'astelpaju',
#   'baamia',
#   'baklažaan',
#   'banaan',
#   'banaankõrvits',
#   'bataat',
#   'bergamott',
#   'brasiilia pähkel',
#   'brüsseli kapsas',
#   'bulgur',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'granadill',
#   'greip',
#   'guajaav',
#   'hapukirss',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'hiina ploom',
#   'hirsitang',
#   'hõrakmari',
#   'indiaani riis',
#   'inglite vili',
#   'iva',
#   'jaanikaun',
#   'jahubanaan',
#   'jahvatis',
#   'joovikas',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'jõhvikas',
#   'kaarel',
#   'kabatšokk',
#   'kadakamari',
#   'kaer',
#   'kaeraklii',
#   'kahvrilaim',
#   'kaktusvili',
#   'kanepiseeme',
#   'kappar',
#   'kapsapea',
#   'karamboola',
#   'karella',
#   'karulauk',
#   'karusmari',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kerimoia',
#   'kiivi',
#   'kikerhernes',
#   'kinkan',
#   'kirss',
#   'kirsstomat',
#   'kivaano',
#   'kivivili',
#   'kišmišš',
#   'klaar',
#   'klaaskirss',
#   'klementiin',
#   'klii',
#   'kokosell',
#   'kookos',
#   'korint',
#   'kreek',
#   'kruup',
#   'kuivatatud vili',
#   'kuldrenett',
#   'kurk',
#   'kuskuss',
#   'kõlutera',
#   'kõrvits',
#   'kõrvitsaseeme',
#   'köögivili',
#   'küdoonia',
#   'küüslauk',
#   'laim',
#   'lamevirsik',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'linaseeme',
#   'litši',
#   'longan',
#   'loorberimari',
#   'maapirn',
#   'maasikas',
#   'mage sõstar',
#   'mais',
#   'maisitang',
#   'makadaamia',
#   'mandariin',
#   'mandel',
#   'mango',
#   'mari',
#   'melon',
#   'mesimurakas',
#   'metsamari',
#   'metslauk',
#   'metsmaasikas',
#   'metspähkel',
#   'metsõun',
#   'mirabell',
#   'moon',
#   'mugul',
#   'mugulvili',
#   'munakinkan',
#   'munguba',
#   'murel',
#   'murulauk',
#   'muskaatkõrvits',
#   'must sõstar',
#   'must uba',
#   'mustikas',
#   'muulukamari',
#   'mõrumandel',
#   'naeris',
#   'nektariin',
#   'nisu',
#   'nisuklii',
#   'nurmlauk',
#   'oder',
#   'odratang',
#   'oliiv',
#   'palukas',
#   'paprika',
#   'paradiisiõun',
#   'patisson',
#   'peakapsas',
#   'pekaanpähkel',
#   'persik',
#   'pesasibul',
#   'pihlakamari',
#   'piimjuur',
#   'piiniaseeme',
#   'pirn',
#   'pistaatsia',
#   'ploom',
#   'ploomtomat',
#   'pomel',
#   'pomerants',
#   'porru',
#   'porrulauk',
#   'punagreip',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'päevalilleseeme',
#   'pähkel',
#   'pärlsibul',
#   'põldmari',
#   'rabarber',
#   'renett',
#   'renklood',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'rosin',
#   'rukis',
#   'rukkiklii',
#   'salat',
#   'satsuma',
#   'seesamiseeme',
#   'sibul',
#   'sibulõun',
#   'sidrun',
#   'sinepiseeme',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suislepp',
#   'sultana',
#   'suvikõrvits',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sõstar',
#   'söödav vili',
#   'sügisõun',
#   'talisibul',
#   'taliõun',
#   'tamarillo',
#   'tang',
#   'tangeriin',
#   'tatar',
#   'tera',
#   'tomat',
#   'toortatar',
#   'tsitrus',
#   'tuviõun',
#   'tõrukõrvits',
#   'uba',
#   'ubin',
#   'urjukk',
#   'vaarikas',
#   'vaarikpampel',
#   'valge sõstar',
#   'varsseller',
#   'veriapelsin',
#   'viigimari',
#   'viinamari',
#   'vilis',
#   'viss',
#   'õlikõrvits'},
#  'Kas tegu on aedviljaga?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas tegu on köögiviljaga?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas tegu on suvikõrvitsaga?': {'kabatšokk', 'spagetikõrvits', 'suvikõrvits'},
#  'Kas tegu on piimjuurega?': {'aed-piimjuur', 'piimjuur'},
#  'Kas tegu on salatiga?': {'jääsalat', 'rooma salat', 'salat'},
#  'Kas tegu on juurikaga?': {'bataat', 'juurikas', 'maapirn', 'naeris'},
#  'Kas tegu on kurgiga?': {'hapukurk', 'kurk'},
#  'Kas tegu on kõrvitsaga?': {'banaankõrvits',
#   'karella',
#   'keerdkaelaline kõrvits',
#   'kokosell',
#   'kõrvits',
#   'muskaatkõrvits',
#   'patisson',
#   'tõrukõrvits',
#   'õlikõrvits'},
#  'Kas tegu on kaunviljaga?': {'adzuki',
#   'aedhernes',
#   'aeduba',
#   'arahhis',
#   'hernes',
#   'kaunvili',
#   'kikerhernes',
#   'liimauba',
#   'munguba',
#   'must uba',
#   'punane uba',
#   'soja',
#   'uba'},
#  'Kas tegu on hernega?': {'aedhernes', 'hernes'},
#  'Kas tegu on oaga?': {'adzuki',
#   'aeduba',
#   'liimauba',
#   'munguba',
#   'must uba',
#   'punane uba',
#   'soja',
#   'uba'},
#  'Kas tegu on aedoaga?': {'adzuki', 'aeduba', 'liimauba', 'munguba'},
#  'Kas tegu on sibulaga?': {'pesasibul', 'punane sibul', 'sibul', 'talisibul'},
#  'Kas tegu on tomatiga?': {'kirsstomat', 'lihatomat', 'ploomtomat', 'tomat'},
#  'Kas tegu on aedselleriga?': {'aedseller',
#   'juurseller',
#   'lehtseller',
#   'varsseller'},
#  'Kas tegu on kapsapeaga?': {'kapsapea', 'punane kapsas', 'riivkapsas'},
#  'Kas tegu on lauguga?': {'karulauk',
#   'lauk',
#   'metslauk',
#   'murulauk',
#   'nurmlauk',
#   'porru',
#   'pärlsibul',
#   'rohulauk'},
#  'Kas tegu on meloniga?': {'kivaano', 'melon'},
#  'Kas tegu on ivaga?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'iva',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'kanepiseeme',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'kõrvitsaseeme',
#   'linaseeme',
#   'mais',
#   'maisitang',
#   'moon',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'piiniaseeme',
#   'päevalilleseeme',
#   'rukis',
#   'rukkiklii',
#   'seesamiseeme',
#   'sinepiseeme',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas tegu on teraga?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'mais',
#   'maisitang',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'rukis',
#   'rukkiklii',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas tegu on tatraga?': {'tatar', 'toortatar'},
#  'Kas tegu on kliiga?': {'kaeraklii', 'klii', 'nisuklii', 'rukkiklii'},
#  'Kas tegu on nisuga?': {'bulgur', 'nisu'},
#  'Kas tegu on tanguga?': {'hirsitang',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas tegu on kiviviljaga?': {'aprikoos',
#   'hapukirss',
#   'kirss',
#   'kivivili',
#   'klaaskirss',
#   'kookos',
#   'loorberimari',
#   'mango',
#   'mirabell',
#   'murel',
#   'oliiv'},
#  'Kas tegu on kirsiga?': {'kirss', 'klaaskirss'},
#  'Kas tegu on mariga?': {'aedmaasikas',
#   'aedmari',
#   'aedmurakas',
#   'alrauni mari',
#   'astelpaju',
#   'hõrakmari',
#   'joovikas',
#   'jõhvikas',
#   'kaarel',
#   'kadakamari',
#   'karusmari',
#   'maasikas',
#   'mage sõstar',
#   'mari',
#   'mesimurakas',
#   'metsamari',
#   'metsmaasikas',
#   'must sõstar',
#   'mustikas',
#   'muulukamari',
#   'palukas',
#   'pihlakamari',
#   'põldmari',
#   'sõstar',
#   'tamarillo',
#   'vaarikas',
#   'vaarikpampel',
#   'valge sõstar',
#   'viigimari'},
#  'Kas tegu on sõstraga?': {'hõrakmari',
#   'mage sõstar',
#   'must sõstar',
#   'sõstar',
#   'valge sõstar'},
#  'Kas tegu on kaarlaga?': {'kaarel', 'mesimurakas', 'põldmari'},
#  'Kas tegu on maasikaga?': {'aedmaasikas',
#   'maasikas',
#   'metsmaasikas',
#   'muulukamari'},
#  'Kas tegu on kuivatatuga viljaga?': {'korint',
#   'kuivatatud vili',
#   'rosin',
#   'sultana',
#   'urjukk'},
#  'Kas tegu on rosinaga?': {'korint', 'rosin', 'sultana'},
#  'Kas tegu on fruktiga?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas tegu on banaaniga?': {'banaan', 'jahubanaan'},
#  'Kas tegu on ploomiga?': {'ploom', 'renklood'},
#  'Kas tegu on ubinaga?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas tegu on taliõunaga?': {'antoonovka', 'taliõun'},
#  'Kas tegu on sügisõunaga?': {'renett', 'sügisõun'},
#  'Kas tegu on pirniga?': {'bergamott', 'pirn'},
#  'Kas tegu on persikuga?': {'lamevirsik', 'persik'},
#  'Kas tegu on tsitrusega?': {'apelsin',
#   'bergamott',
#   'greip',
#   'kahvrilaim',
#   'kinkan',
#   'klementiin',
#   'laim',
#   'mandariin',
#   'munakinkan',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'satsuma',
#   'sidrun',
#   'sõrmlaim',
#   'tangeriin',
#   'tsitrus',
#   'veriapelsin'},
#  'Kas tegu on laimiga?': {'kahvrilaim', 'laim', 'sõrmlaim'},
#  'Kas tegu on greibiga?': {'greip', 'punagreip'},
#  'Kas tegu on apelsiniga?': {'apelsin', 'veriapelsin'},
#  'Kas tegu on mandariiniga?': {'klementiin', 'mandariin', 'satsuma'},
#  'Kas tegu on viinamarjaga?': {'kišmišš', 'viinamari'},
#  'Kas tegu on pähkliga?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas tegu on mugulaga?': {'küüslauk', 'mugul'},
#  'Kas tegu on mandliga?': {'mandel', 'mõrumandel'}}

# %%
# tahan lisada:
# küsimused, mis on juba olemas, aga kus on üks mõiste puudu
# küsimused, mida ei ole veel olemas

def otherRelationsQuestion(otherRelations, yleyldised_küsimused_vastused):
    questions = set()
    seosed_küsimused_vastused = defaultdict(set)

    for küsimus, mõisted in yleyldised_küsimused_vastused.items():
        lemmad = Text(küsimus).tag_layer().words.lemma
        lemmad_list = [lemma[0] for lemma in lemmad]

        for mõiste, seosed in otherRelations:
            mõiste_nimi = correct_word_form(mõiste.name, "sg n")

            for key, words in seosed.items():
                for word in words:
                    if word not in lemmad_list:
                        # Uus küsimus, mida veel ei ole olemas
                        question = generateOtherRelationsQuestion(word, key)
                        questions.add(question)
                        seosed_küsimused_vastused.setdefault(question, set())
                        seosed_küsimused_vastused[question].add(mõiste_nimi)

                        # Lisa alammõisted, kui need on olemas
                        for alam_mõiste in mõiste.closure("hyponym"):
                            seosed_küsimused_vastused[question].add(correct_word_form(alam_mõiste.name, "sg n"))

                    # Küsimus on juba olemas, kontrollime, kas tuleb mõiste juurde lisada
                    elif word in lemmad_list and mõiste_nimi not in mõisted:
                      yleyldised_küsimused_vastused[küsimus].add(mõiste_nimi)

                    else:
                      continue

    return seosed_küsimused_vastused, yleyldised_küsimused_vastused

# %%
uuendatud_küsimused_vastused = otherRelationsQuestion(otherRelations, yleyldised_küsimused_vastused)

# %%
seosed_küsimused_vastused = uuendatud_küsimused_vastused[0]

# %%
yleyldised_küsimused_vastused = uuendatud_küsimused_vastused[1]

# %%
#ühendame kõik küsimused kokku:
küsimused_vastused = {}
küsimused_vastused = {**yleyldised_küsimused_vastused, **tapsemad_küsimused_vastused, **seosed_küsimused_vastused}

# %%
küsimused_vastused
# Out:
# {'Kas tegu on söödavaga viljaga?': {'Kreeka pähkel',
#   None,
#   'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedmaasikas',
#   'aedmari',
#   'aedmurakas',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'akazuupähkel',
#   'alligaatorpirn',
#   'alrauni mari',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'aprikoos',
#   'arahhis',
#   'arbuus',
#   'areekapähkel',
#   'artišokk',
#   'aspar',
#   'astelpaju',
#   'baamia',
#   'baklažaan',
#   'banaan',
#   'banaankõrvits',
#   'bataat',
#   'bergamott',
#   'brasiilia pähkel',
#   'brüsseli kapsas',
#   'bulgur',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'granadill',
#   'greip',
#   'guajaav',
#   'hapukirss',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'hiina ploom',
#   'hirsitang',
#   'hõrakmari',
#   'indiaani riis',
#   'inglite vili',
#   'iva',
#   'jaanikaun',
#   'jahubanaan',
#   'jahvatis',
#   'joovikas',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'jõhvikas',
#   'kaarel',
#   'kabatšokk',
#   'kadakamari',
#   'kaer',
#   'kaeraklii',
#   'kahvrilaim',
#   'kaktusvili',
#   'kanepiseeme',
#   'kappar',
#   'kapsapea',
#   'karamboola',
#   'karella',
#   'karulauk',
#   'karusmari',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kerimoia',
#   'kiivi',
#   'kikerhernes',
#   'kinkan',
#   'kirss',
#   'kirsstomat',
#   'kivaano',
#   'kivivili',
#   'kišmišš',
#   'klaar',
#   'klaaskirss',
#   'klementiin',
#   'klii',
#   'kokosell',
#   'kookos',
#   'korint',
#   'kreek',
#   'kruup',
#   'kuivatatud vili',
#   'kuldrenett',
#   'kurk',
#   'kuskuss',
#   'kõlutera',
#   'kõrvits',
#   'kõrvitsaseeme',
#   'köögivili',
#   'küdoonia',
#   'küüslauk',
#   'laim',
#   'lamevirsik',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'linaseeme',
#   'litši',
#   'longan',
#   'loorberimari',
#   'maapirn',
#   'maasikas',
#   'mage sõstar',
#   'mais',
#   'maisitang',
#   'makadaamia',
#   'mandariin',
#   'mandel',
#   'mango',
#   'mari',
#   'melon',
#   'mesimurakas',
#   'metsamari',
#   'metslauk',
#   'metsmaasikas',
#   'metspähkel',
#   'metsõun',
#   'mirabell',
#   'moon',
#   'mugul',
#   'mugulvili',
#   'munakinkan',
#   'munguba',
#   'murel',
#   'murulauk',
#   'muskaatkõrvits',
#   'must sõstar',
#   'must uba',
#   'mustikas',
#   'muulukamari',
#   'mõrumandel',
#   'naeris',
#   'nektariin',
#   'nisu',
#   'nisuklii',
#   'nurmlauk',
#   'oder',
#   'odratang',
#   'oliiv',
#   'palukas',
#   'paprika',
#   'paradiisiõun',
#   'patisson',
#   'peakapsas',
#   'pekaanpähkel',
#   'persik',
#   'pesasibul',
#   'pihlakamari',
#   'piimjuur',
#   'piiniaseeme',
#   'pirn',
#   'pistaatsia',
#   'ploom',
#   'ploomtomat',
#   'pomel',
#   'pomerants',
#   'porru',
#   'porrulauk',
#   'punagreip',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'päevalilleseeme',
#   'pähkel',
#   'pärlsibul',
#   'põldmari',
#   'rabarber',
#   'renett',
#   'renklood',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'rosin',
#   'rukis',
#   'rukkiklii',
#   'salat',
#   'satsuma',
#   'seesamiseeme',
#   'sibul',
#   'sibulõun',
#   'sidrun',
#   'sinepiseeme',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suislepp',
#   'sultana',
#   'suvikõrvits',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sõstar',
#   'söödav vili',
#   'sügisõun',
#   'talisibul',
#   'taliõun',
#   'tamarillo',
#   'tang',
#   'tangeriin',
#   'tatar',
#   'tera',
#   'tomat',
#   'toortatar',
#   'tsitrus',
#   'tuviõun',
#   'tõrukõrvits',
#   'uba',
#   'ubin',
#   'urjukk',
#   'vaarikas',
#   'vaarikpampel',
#   'valge sõstar',
#   'varsseller',
#   'veriapelsin',
#   'viigimari',
#   'viinamari',
#   'vilis',
#   'viss',
#   'õlikõrvits'},
#  'Kas tegu on aedviljaga?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas tegu on köögiviljaga?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas tegu on suvikõrvitsaga?': {'kabatšokk', 'spagetikõrvits', 'suvikõrvits'},
#  'Kas tegu on piimjuurega?': {'aed-piimjuur', 'piimjuur'},
#  'Kas tegu on salatiga?': {'jääsalat', 'rooma salat', 'salat'},
#  'Kas tegu on juurikaga?': {'bataat', 'juurikas', 'maapirn', 'naeris'},
#  'Kas tegu on kurgiga?': {'hapukurk', 'kurk'},
#  'Kas tegu on kõrvitsaga?': {'banaankõrvits',
#   'karella',
#   'keerdkaelaline kõrvits',
#   'kokosell',
#   'kõrvits',
#   'muskaatkõrvits',
#   'patisson',
#   'tõrukõrvits',
#   'õlikõrvits'},
#  'Kas tegu on kaunviljaga?': {'adzuki',
#   'aedhernes',
#   'aeduba',
#   'arahhis',
#   'hernes',
#   'kaunvili',
#   'kikerhernes',
#   'liimauba',
#   'munguba',
#   'must uba',
#   'punane uba',
#   'soja',
#   'uba'},
#  'Kas tegu on hernega?': {'aedhernes', 'hernes'},
#  'Kas tegu on oaga?': {'adzuki',
#   'aeduba',
#   'liimauba',
#   'munguba',
#   'must uba',
#   'punane uba',
#   'soja',
#   'uba'},
#  'Kas tegu on aedoaga?': {'adzuki', 'aeduba', 'liimauba', 'munguba'},
#  'Kas tegu on sibulaga?': {'pesasibul', 'punane sibul', 'sibul', 'talisibul'},
#  'Kas tegu on tomatiga?': {'kirsstomat', 'lihatomat', 'ploomtomat', 'tomat'},
#  'Kas tegu on aedselleriga?': {'aedseller',
#   'juurseller',
#   'lehtseller',
#   'varsseller'},
#  'Kas tegu on kapsapeaga?': {'kapsapea', 'punane kapsas', 'riivkapsas'},
#  'Kas tegu on lauguga?': {'karulauk',
#   'lauk',
#   'metslauk',
#   'murulauk',
#   'nurmlauk',
#   'porru',
#   'pärlsibul',
#   'rohulauk'},
#  'Kas tegu on meloniga?': {'kivaano', 'melon'},
#  'Kas tegu on ivaga?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'iva',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'kanepiseeme',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'kõrvitsaseeme',
#   'linaseeme',
#   'mais',
#   'maisitang',
#   'moon',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'piiniaseeme',
#   'päevalilleseeme',
#   'rukis',
#   'rukkiklii',
#   'seesamiseeme',
#   'sinepiseeme',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas tegu on teraga?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'mais',
#   'maisitang',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'rukis',
#   'rukkiklii',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas tegu on tatraga?': {'tatar', 'toortatar'},
#  'Kas tegu on kliiga?': {'kaeraklii', 'klii', 'nisuklii', 'rukkiklii'},
#  'Kas tegu on nisuga?': {'bulgur', 'nisu'},
#  'Kas tegu on tanguga?': {'hirsitang',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas tegu on kiviviljaga?': {'aprikoos',
#   'hapukirss',
#   'kirss',
#   'kivivili',
#   'klaaskirss',
#   'kookos',
#   'loorberimari',
#   'mango',
#   'mirabell',
#   'murel',
#   'oliiv'},
#  'Kas tegu on kirsiga?': {'kirss', 'klaaskirss'},
#  'Kas tegu on mariga?': {'aedmaasikas',
#   'aedmari',
#   'aedmurakas',
#   'alrauni mari',
#   'astelpaju',
#   'hõrakmari',
#   'joovikas',
#   'jõhvikas',
#   'kaarel',
#   'kadakamari',
#   'karusmari',
#   'maasikas',
#   'mage sõstar',
#   'mari',
#   'mesimurakas',
#   'metsamari',
#   'metsmaasikas',
#   'must sõstar',
#   'mustikas',
#   'muulukamari',
#   'palukas',
#   'pihlakamari',
#   'põldmari',
#   'sõstar',
#   'tamarillo',
#   'vaarikas',
#   'vaarikpampel',
#   'valge sõstar',
#   'viigimari'},
#  'Kas tegu on sõstraga?': {'hõrakmari',
#   'mage sõstar',
#   'must sõstar',
#   'sõstar',
#   'valge sõstar'},
#  'Kas tegu on kaarlaga?': {'kaarel', 'mesimurakas', 'põldmari'},
#  'Kas tegu on maasikaga?': {'aedmaasikas',
#   'maasikas',
#   'metsmaasikas',
#   'muulukamari'},
#  'Kas tegu on kuivatatuga viljaga?': {'korint',
#   'kuivatatud vili',
#   'rosin',
#   'sultana',
#   'urjukk'},
#  'Kas tegu on rosinaga?': {'korint', 'rosin', 'sultana'},
#  'Kas tegu on fruktiga?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas tegu on banaaniga?': {'banaan', 'jahubanaan'},
#  'Kas tegu on ploomiga?': {'ploom', 'renklood'},
#  'Kas tegu on ubinaga?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas tegu on taliõunaga?': {'antoonovka', 'taliõun'},
#  'Kas tegu on sügisõunaga?': {'renett', 'sügisõun'},
#  'Kas tegu on pirniga?': {'bergamott', 'pirn'},
#  'Kas tegu on persikuga?': {'lamevirsik', 'persik'},
#  'Kas tegu on tsitrusega?': {'apelsin',
#   'bergamott',
#   'greip',
#   'kahvrilaim',
#   'kinkan',
#   'klementiin',
#   'laim',
#   'mandariin',
#   'munakinkan',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'satsuma',
#   'sidrun',
#   'sõrmlaim',
#   'tangeriin',
#   'tsitrus',
#   'veriapelsin'},
#  'Kas tegu on laimiga?': {'kahvrilaim', 'laim', 'sõrmlaim'},
#  'Kas tegu on greibiga?': {'greip', 'punagreip'},
#  'Kas tegu on apelsiniga?': {'apelsin', 'veriapelsin'},
#  'Kas tegu on mandariiniga?': {'klementiin', 'mandariin', 'satsuma'},
#  'Kas tegu on viinamarjaga?': {'kišmišš', 'viinamari'},
#  'Kas tegu on pähkliga?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas tegu on mugulaga?': {'küüslauk', 'mugul', 'sibul'},
#  'Kas tegu on mandliga?': {'mandel', 'mõrumandel'},
#  'Kas see taim on kapparipõõsa õitsemise järel saadav mari, mida kasutatakse marineerituna toiduks?': {'kappar'},
#  'Kas see taim on köögivili, puuvili ja aias kasvavad marjad?': {'aedvili'},
#  'Kas see taim on rohttaim, mille mingeid osi kasutatakse söögiks kas värskelt või töödeldult?': {'köögivili'},
#  'Kas see taim on soojalembene köögivili, mida kasutatakse rohkelt India ja kreooli köögis?': {'baamia'},
#  'Kas see taim on suvel v. varasügisel kasutatavate kõrvitsate üldnimetus?': {'suvikõrvits'},
#  'Kas see taim on on kõrvitsaliik, mille viljaliha muutub pärast küpsemist spagetisarnasteks ribadeks?': {'spagetikõrvits'},
#  'Kas see taim on rullkõrvitsataime vili toiduna?': {'kabatšokk'},
#  'Kas see taim on vees kasvav kõrreline, mille juuremugulaid kasutatakse palju Hiina köögis?': {'hiina alss'},
#  'Kas see taim on köögivili, millel toiduks tarvitatakse valget juurt, mõnedel sortidel ka lehti?': {'piimjuur'},
#  'Kas see taim on Aed-piimjuur on väga vana, maitselt sparglit meenutav kultuurtaim; koor on kreemikas ja sisu valge?': {'aed-piimjuur'},
#  'Kas see taim on rohkesti piimmahla sisaldav väike rohttaim, ka salatitaimena kasvatatav köögiviljataim .?': {'salat'},
#  'Kas see taim on mahlane ja krõmpsuvate lehtedega salat, mis on nt Caesari salati põhikomponent?': {'rooma salat'},
#  'Kas see taim on köögiviljana kasvatatav klaasjalt läikivate, kergelt külmununa näivate rabedate lehtedega aiataim?': {'jääsalat'},
#  'Kas see taim on Suurte söödavate viljadega ning lamavate vartega taime vili?': {'arbuus'},
#  'Kas see taim on mis tahes erinevad lihavad söödavad maa-alused juured või mugulad?': {'juurikas'},
#  'Kas see taim on suurt kartulit meenutav piklik mugul, millel on helepruun või punakas koor ja magus maitse?': {'bataat'},
#  'Kas see taim on köögiviljana või söödaks kasvatatav lihaka kollaka juurikaga rohttaim?': {'naeris'},
#  'Kas see taim on vastava kultuurtaime söödav vili?': {'maapirn'},
#  'Kas see taim on vastava kultuurtaime väikesed hea lõhna ja maitsega pead?': {'brüsseli kapsas'},
#  'Kas see taim on köögiviljana kasvatatav, tihedalt mähkunud lehtedest ühe suure pea moodustav aiataim, valge peakapsas?': {'peakapsas'},
#  'Kas see taim on rohelised v. kollakasrohelised piklikud viljad, mida tarvitatav toiduks?': {'kurk'},
#  'Kas see taim on hapendatud kurk?': {'hapukurk'},
#  'Kas see taim on suurte ümarjate viljade ja lamavate v. ronivate vartega köögiviljakultuuri söödav vili?': {'kõrvits'},
#  'Kas see taim on väike tumeroheline või kollane squash kollase kuni oranži lihaga?': {'tõrukõrvits'},
#  'Kas see taim on köögivilljataim, millel söömiseks kasutatakse valmimata rohelisi vilju, noori võrseid ja lehti?': {'karella'},
#  'Kas see taim on intentsiivse lõhnaga, enamasti tumekollase viljalihaga soojalembene kõrvitsaline?': {'muskaatkõrvits'},
#  'Kas see taim on haruldane ja hinnatud kõrvitsasort, mille suured roosa banaani kujulised viljad on maitsvad ja säilivad hästi kevadeni?': {'banaankõrvits'},
#  'Kas see taim on rohelise viljalihaga kõrvits, mis meenutab tsukiinit?': {'kokosell'},
#  'Kas see taim on õli pressimiseks kasvatatav kõrvitsaline?': {'õlikõrvits'},
#  'Kas see taim on pikliku kõverdunud viljaga köögivili kõrvitsaliste sugukonnast?': {'keerdkaelaline kõrvits'},
#  'Kas see taim on kettakujuline köögivili kõrvitsaliste sugukonnast?': {'patisson'},
#  'Kas see taim on kaunu kasvatav põllu- v. aiakultuur, mille vilju ja seemneid kasut. toiduks v. söödaks?': {'kaunvili'},
#  'Kas see taim on kaunviljade hulka kuuluva hrl. aia- ja põllukultuurina kasvatatava ümmarguste seemnetega ronitaime söödav seeme?': {'hernes'},
#  'Kas see taim on üks söögiherne sort?': {'aedhernes'},
#  'Kas see taim on valgurikas kaunvili, mida kasutatakse palju Vahemere, Araabia ja Aasia köökides?': {'kikerhernes'},
#  'Kas see taim on hrl. põllukultuurina kasvatatav liblikõieline suurte seemnetega kaunvili?': {'uba'},
#  'Kas see taim on musta kestaga uba, mis on maitselt pehme, magus ja pisut mullane?': {'must uba'},
#  'Kas see taim on tumepunase kestaga uba, mille kuju meenutab neeru?': {'punane uba'},
#  'Kas see taim on väga proteiinirikas aedvili?': {'soja'},
#  'Kas see taim on liblikõieliste sugukonda kuuluv, nõrgalt haruneva lühikese või kõrge varrega taim?': {'aeduba'},
#  'Kas see taim on punane väike aeduba?': {'adzuki'},
#  'Kas see taim on väike roheline uba, väga levinud Aasia köögis?': {'munguba'},
#  'Kas see taim on laukude hulka kuuluv köögiviljataim?': {'sibul'},
#  'Kas see taim on mitmeaastane talvekindel köögiviljataim?': {'talisibul'},
#  'Kas see taim on väike mahedamaitseline sibul?': {'pesasibul'},
#  'Kas see taim on violetse värvuse ja mahedama maitsega sibul?': {'punane sibul'},
#  'Kas see taim on peam. punaste lihakate viljadega köögivilja söödav vili?': {'tomat'},
#  'Kas see taim on väikeseviljaline tomatisort?': {'kirsstomat'},
#  'Kas see taim on väike ploomikujuline tomatisort?': {'ploomtomat'},
#  'Kas see taim on vähese seemnehulga ja rohke viljalihaga tomat?': {'lihatomat'},
#  'Kas see taim on köögiviljana kasvatatav lehtedest moodustunud varrega, sibulast mahedama maitsega rohttaim?': {'porrulauk'},
#  'Kas see taim on köögivilja- ja maitsetaim?': {'aedseller'},
#  'Kas see taim on köögiviljana kasvatatav tumeroheliste lehtede ja väikeste valgete õitega aromaatne rohttaim, millest peale lehtede ja leherootsude tarvitatakse toiduks ka ümmargust lihakat juurt; aedselleri teisend?': {'juurseller'},
#  'Kas see taim on selleri teisend, mis ei kasvata juurvilja ega lehevarsi vaid lehed, mis sobivad hästi toidu maitsestamiseks?': {'lehtseller'},
#  'Kas see taim on köögiviljana kasvatatav tumeroheliste lehtede ja väikeste valgete õitega aromaatne rohttaim, millest toiduks tarvitatakse suuri lehti ja mahlakaid leherootse, aedselleri teisend?': {'varsseller'},
#  'Kas see taim on saadus kapsa taimest?': {'kapsapea'},
#  'Kas see taim on riivitud kapsas?': {'riivkapsas'},
#  'Kas see taim on lillakate lehtedega kapsas, mis kuulub ristõieliste taimede perekonda?': {'punane kapsas'},
#  'Kas see taim on karuohakat meenutav suurte hallikasroheliste lehtede ja soomustega kaetud õisikutega rohttaim, mida kasvatatakse köögiviljana ja ilutaimena?': {'artišokk'},
#  'Kas see taim on India päritolu tomatitaoline köögiviljataime vili?': {'baklažaan'},
#  'Kas see taim on iseloomulikult lõhnava jämeda risoomi v. sibulaga ning ruljate rootsuta lehtedega taime söödav osa?': {'lauk'},
#  'Kas see taim on laukude hulka kuuluv köögiviljataim ; selle söödav valge sibulake?': {'pärlsibul'},
#  'Kas see taim on hrl aias maitsetaimena kasvatatav püstise varre, õõnsate ruljate lehtede ja lillade õitega rohttaim?': {'murulauk'},
#  'Kas see taim on amarülliliste sugukonda kuuluv taimeliik?': {'nurmlauk'},
#  'Kas see taim on karulaugu sibul maitseainena?': {'karulauk'},
#  'Kas see taim on köögiviljana kasvatatav lamedate lehtedega kaheaastane lauk?': {'porru'},
#  'Kas see taim on küüslaugulõhnaliste lehtedega maitse- ja ravimtaim, millel kasutatakse söögiks peamiselt lehti, kuid ka varsi, õisi ja sibulat?': {'karulauk'},
#  'Kas see taim on puisniitudel ja niitudel kasvav lauk?': {'metslauk'},
#  'Kas see taim on kitsaste roheliste lehtede ja väikese sibulaga rohttaim?': {'rohulauk'},
#  'Kas see taim on ühe troopikataime magusamaitseline mahlakas ümar vili?': {'melon'},
#  'Kas see taim on , želeetaolise viljalihaga lõunamaa vili?': {'kivaano'},
#  'Kas see taim on maitsetaimena ja köögiviljana kasvatatav porganditaolise kollakasvalge juurega aiataim?': {'aed-moorputk'},
#  'Kas see taim on Rabarberi mahlakas lehevars toiduainena?': {'rabarber'},
#  'Kas see taim on sparglitaime söödavad noored võrsed?': {'aspar'},
#  'Kas see taim on spinatitaime raua- ja vitamiinirikkad lehed ja lehevarred toiduna?': {'spinat'},
#  'Kas see taim on suure ümara kauna taoline mahedamaitseline, mahlakas, värvikas vili köögiviljana?': {'paprika'},
#  'Kas see taim on aedvili, millest toiduks kasutatakse lehti?': {'lehtaedvili'},
#  'Kas see taim on troopilises Ameerikas kasvava kannatuslille söödav vili?': {'granadill'},
#  'Kas see taim on teravilja seeme, viljatera?': {'iva'},
#  'Kas see taim on kanepitaime toitainerikkad seemned, mida süüakse niisama või kasutatakse leiva vm toiduainete sees lisandina?': {'kanepiseeme'},
#  'Kas see taim on linataime seemned, mis sisaldavad palju inimesele kasulikke vitamiine, mineraalaineid, kiudaineid jms?': {'linaseeme'},
#  'Kas see taim on Hariliku seesami tillukesed lamedad seemned?': {'seesamiseeme'},
#  'Kas see taim on päevalillede söödav seeme;kasutatakse toidu ja linnuliha söödana ning õliallikana?': {'päevalilleseeme'},
#  'Kas see taim on väike hall mooniõie seeme; kasutatud tervena või jahvatatult küpsetistes?': {'moon'},
#  'Kas see taim on seedermänni söödav seeme?': {'piiniaseeme'},
#  'Kas see taim on teravilja seeme?': {'tera'},
#  'Kas see taim on kehv või tühi viljatera, tühi kest?': {'kõlutera'},
#  'Kas see taim on tatrataime vili , ka toiduna?': {'tatar'},
#  'Kas see taim on tatar, millel kestad on teradest eemaldatud kuivkoorimise, mitte kuumutamise teel?': {'toortatar'},
#  'Kas see taim on jahvatamise saadus, miski jahvatatu?': {'jahvatis'},
#  'Kas see taim on teravilja jahvatamisel eraldatud seemnekestad koos nende külge jäänud taimekoe- ja iduosadega?': {'klii'},
#  'Kas see taim on nisuteradelt jahvatamisel eraldatud kestad?': {'nisuklii'},
#  'Kas see taim on piim- v. vahaküpsuses koristatud teravili, mida sileeritakse v. kuivatatakse söödaks?': {'vilis'},
#  'Kas see taim on teravilja  kooritud ja lihvitud terad?': {'kruup'},
#  'Kas see taim on teravilja tera, tavaliselt jahvatatud jahuks?': {'nisu'},
#  'Kas see taim on leotatud, keedetud, kuivatatud ja lõpuks purustatud nisu?': {'bulgur'},
#  'Kas see taim on kaerataime vili?': {'kaer'},
#  'Kas see taim on teravilja  kooritud ja purustatud tera?': {'tang'},
#  'Kas see taim on maisi kooritud ja purustatud tera; sellised terad kogumina?': {'maisitang'},
#  'Kas see taim on odra kooritud ja purustatud tera?': {'odratang'},
#  'Kas see taim on eelaurutatud ja purustatud nisutangud?': {'kuskuss'},
#  'Kas see taim on hirsi kooritud ja purustatud tera?': {'hirsitang'},
#  'Kas see taim on Põhja-Ameerika veerohu terad?': {'indiaani riis'},
#  'Kas see taim on idandatud ja kuivatatud teravili, mida kasutatakse õlle, viski ja äädika valmistamisel ning pagaritööstuses jahu küpsetusomaduste parandamiseks ja värvi, lõhna või maitse lisamiseks?': {None},
#  'Kas see taim on üheseemneline vili, milles seemet ümbritseb puitunud sisekest, luu ehk kivi?': {'kivivili'},
#  'Kas see taim on loorberi must luuvili?': {'loorberimari'},
#  'Kas see taim on hapukirsipuu vili?': {'hapukirss'},
#  'Kas see taim on aprikoosipuu viltjas-karvane luuvili?': {'aprikoos'},
#  'Kas see taim on mõnede mangopuude söödav magushapu viljalihaga luuvili?': {'mango'},
#  'Kas see taim on õlipuu ploomitaoline söödav luuvili?': {'oliiv'},
#  'Kas see taim on kirsipuu vili?': {'kirss'},
#  'Kas see taim on klaas-kirsipuu heledaviljaline värvitu mahlaga vili?': {'klaaskirss'},
#  'Kas see taim on kookospalmi vili?': {'kookos'},
#  'Kas see taim on ploomi moodi ümmargused, enamasti kollased viljad?': {'mirabell'},
#  'Kas see taim on murelipuu tume vili?': {'murel'},
#  'Kas see taim on taimede lihakas hulgaseemneline vili,  lihakas söödav koguvili v. luuvili?': {'mari'},
#  'Kas see taim on rabaservadel ja siirdesoodes kasvava sinakasroheliste lehtedega kääbuspõõsa, sinika mari?': {'joovikas'},
#  'Kas see taim on erinevate astelpajude viljad, mis annavad värvaineid või pigmente?': {'astelpaju'},
#  'Kas see taim on sõstrapõõsa mari?': {'sõstar'},
#  'Kas see taim on sõstraliste sugukonda kuuluv marjakultuur?': {'valge sõstar'},
#  'Kas see taim on punasesõstrapõõsa punane mari?': {'hõrakmari'},
#  'Kas see taim on sõstramari, mis on musta värvi ja iseloomuliku maitsega?': {'must sõstar'},
#  'Kas see taim on punast sõstart meenutavate, kuid magedate, maitsetute marjadega lehtpõõsas?': {'mage sõstar'},
#  'Kas see taim on looduslikult kasvava või aedades kasvatatava püstiste varte ja hrl punaste marjadega lehtpõõsa mari?': {'vaarikas'},
#  'Kas see taim on metsas kasvava taime mari?': {'metsamari'},
#  'Kas see taim on mustade vaarikasarnaste viljadega poolpõõsas?': {'aedmurakas'},
#  'Kas see taim on Pamplite ja vaarikate vahelised ristandid?': {'vaarikpampel'},
#  'Kas see taim on kadakapuu väike käbi, mida kasutatakse toitude ja jookide maitsestamiseks?': {'kadakamari'},
#  'Kas see taim on tomatipuu hrl. pruunikaspunase kestaga piklikmunajas söödav mari?': {'tamarillo'},
#  'Kas see taim on hrl. rabamuraka punakas, valminult kollane vili.?': {'kaarel'},
#  'Kas see taim on põldmuraka mari?': {'põldmari'},
#  'Kas see taim on punaste õite ja viljadega murakas?': {'mesimurakas'},
#  'Kas see taim on sõstraliste sugukonda kuuluv marjakultuur ja taimeperekond?': {'karusmari'},
#  'Kas see taim on maasikataime magus punane vili?': {'maasikas'},
#  'Kas see taim on looduslikult kasvav kolmeosaliste lehtede, valgete õite ja väikeste punaste viljadega madal rohttaim?': {'metsmaasikas'},
#  'Kas see taim on aedmaasika vili?': {'aedmaasikas'},
#  'Kas see taim on muuluka valkjas, tipust punane söödav vili?': {'muulukamari'},
#  'Kas see taim on punane marjataoline puuvili?': {'pihlakamari'},
#  'Kas see taim on hariliku viigipuu vili.?': {'viigimari'},
#  'Kas see taim on jõhvikataime söödav tumepunane hapu mari?': {'jõhvikas'},
#  'Kas see taim on alrauni vili, sisaldab tugevatoimelisi alkaloide: hüostsüamiini ja skopolamiini?': {'alrauni mari'},
#  'Kas see taim on hrl. okasmetsas kasvava heitlehelise kääbuspõõsa, mustika mari?': {'mustikas'},
#  'Kas see taim on söödav, valmina punane hapu mari?': {'palukas'},
#  'Kas see taim on kuivatatud viinamari?': {'rosin'},
#  'Kas see taim on väike suhkrurikas seemneteta rosin?': {'korint'},
#  'Kas see taim on kollakas-rohelisest  viinamarjast saadav rosin?': {'sultana'},
#  'Kas see taim on kuivatatud aprikoos?': {'urjukk'},
#  'Kas see taim on toiduks tarvitatav viljapuu vili?': {'frukt'},
#  'Kas see taim on aromaatsed hapu maitsega pirnikujulised viljad, mida kasutatakse hoidistes?': {'küdoonia'},
#  'Kas see taim on kollane, tähekujulise ristlõikega troopiline puuvili?': {'karamboola'},
#  'Kas see taim on peamiselt Aasias kasvatav oranži värvusega magusamaitseline puuvili?': {'diospüür'},
#  'Kas see taim on piklik, kollasekooreline suhkru- ning tärkliserikas puuvili?': {'banaan'},
#  'Kas see taim on Ladina-Ameerikas populaarne banaanisort, mida süüakse vaid küpsetatud kuju?': {'jahubanaan'},
#  'Kas see taim on ploomipuu vili?': {'ploom'},
#  'Kas see taim on roheline ploom?': {'renklood'},
#  'Kas see taim on punane, kollane v. roheline õunapuu vili?': {'ubin'},
#  'Kas see taim on väike hapu õun?': {'viss'},
#  'Kas see taim on metsõunapuu õun?': {'metsõun'},
#  'Kas see taim on söögi juurde pakutav magus õun?': {'dessertõun'},
#  "Kas see taim on 'Pärnu tuviõuna' sorti sügisõun v. 'Krügeri tuviõuna' sorti suviõun?": {'tuviõun'},
#  'Kas see taim on säilitamiseks ettenähtud õun?': {'säilitusõun'},
#  'Kas see taim on keskmise suurusega kuldkollane ja väga hea maitsega sügisõun?': {'kuldrenett'},
#  'Kas see taim on keskmise suurusega kollakasvalge maitsev suviõun, mille viljaliha on roosakate laikude ja triipudega?': {'suislepp'},
#  "Kas see taim on kollakasvalge suviõun, sordilt 'Valge klaarõun'?": {'klaar'},
#  'Kas see taim on sügisel valmiv, hrl ületalve säiliv  õun?': {'taliõun'},
#  "Kas see taim on 'Antonovka' sorti taliõun?": {'antoonovka'},
#  'Kas see taim on suvel valmiv õun, mis ei säili ületalve?': {'suviõun'},
#  'Kas see taim on väike sibulakujuline rohekaskollane maitsev taliõun?': {'sibulõun'},
#  'Kas see taim on paradiisiõunapuu vili?': {'paradiisiõun'},
#  'Kas see taim on sügisel valmiv õun?': {'sügisõun'},
#  'Kas see taim on teatud sügisõunasortide rühm?': {'renett'},
#  'Kas see taim on pirnipuu vili?': {'pirn'},
#  'Kas see taim on ümarate viljadega pirnisort?': {'bergamott'},
#  'Kas see taim on ogaline peasuurune tugeva spetsiifilise lõhnaga durianipuu vili; koosneb mitmest sektorist?': {'durian'},
#  'Kas see taim on hariliku virsikupuu mahlakas viltja kestaga luuvili?': {'persik'},
#  'Kas see taim on Hiinast pärit lameda virsikupuu mahlane, õrna viljalihaga ja magusa maitsega lameda kujuga vili?': {'lamevirsik'},
#  'Kas see taim on Ananassi taime suur käbijas vilikond?': {'ananass'},
#  'Kas see taim on nt apelsini-, greibi-, sidrunipuu) mahlakas vili?': {'tsitrus'},
#  'Kas see taim on laimipuu vili?': {'laim'},
#  'Kas see taim on Austraaliast pärit, kujult kurki meenutav tumeroheline või tumepunane sõrm-pisilaimipuu vili?': {'sõrmlaim'},
#  'Kas see taim on Tai köögis laialdaselt kasutatavad kahvrilaimipuu vili?': {'kahvrilaim'},
#  'Kas see taim on pomelipuu suur paksukooreline söödav vili?': {'pomel'},
#  'Kas see taim on selle puu suur apelsinitaoline mõrkjasmagusa mahlaga vili.?': {'greip'},
#  'Kas see taim on punase viljaliha ja mahlaga greip?': {'punagreip'},
#  'Kas see taim on kinkanipuu vili?': {'kinkan', 'munakinkan'},
#  'Kas see taim on tangeriinipuu vili?': {'tangeriin'},
#  'Kas see taim on hariliku sidrunipuu vili?': {'sidrun'},
#  'Kas see taim on apelsinipuu mahlakas ning aromaatne oranš vili?': {'apelsin'},
#  'Kas see taim on punase viljaliha ja mahlaga apelsin?': {'veriapelsin'},
#  'Kas see taim on pomerantsipuu apelsinitaoline hapu vili?': {'pomerants'},
#  'Kas see taim on mandariinipuu vili?': {'mandariin'},
#  'Kas see taim on väike seemneteta mandariin?': {'klementiin'},
#  'Kas see taim on punane Jaapani mandariin?': {'satsuma'},
#  'Kas see taim on punase kestaga, paljusid mahlaseid tumepunaseid söödavaid seemneid sisaldav granaadipuu vili?': {'granaat'},
#  'Kas see taim on Ameerika pirnloorberi  vili?': {'alligaatorpirn'},
#  'Kas see taim on guajaavipuu kollane pirnjas vitamiinirikas vili?': {'guajaav'},
#  'Kas see taim on suured ovaalsed melonilaadsed kollaka lihaga troopilised viljad?': {'inglite vili'},
#  'Kas see taim on suureviljalise viigikaktuse  söödav, viigimarja meenutav vili?': {'kaktusvili'},
#  'Kas see taim on Kagu- ja Lõuna-Aasias vm kasvatatava maasik-metskaktuse  söödav vili, millel on punane koor ja väikeste mustade seemnetega valge pehme sisu?': {'draakonivili'},
#  'Kas see taim on Peruu ja Ecuadori Andide mägiorgudest pärineva viljapuu  rohekaskollase koorega magusamaitseline ümar vili?': {'kerimoia'},
#  'Kas see taim on piklikümar pruunikas roheka viljalihaga  puuvili?': {'kiivi'},
#  'Kas see taim on sileda koorega virsik, nektariinipuu vili?': {'nektariin'},
#  'Kas see taim on litšipuu kerajas magushapu viljalihaga vili?': {'hiina ploom'},
#  'Kas see taim on rambutanipuu vili?': {'litši'},
#  'Kas see taim on viinapuu mahlakas suhkrurikas vili?': {'viinamari'},
#  'Kas see taim on peenike seemneteta viinamari?': {'kišmišš'},
#  'Kas see taim on söödavate või söödaks tarvitatavate mugulatega taim?': {'mugulvili'},
#  'Kas see taim on mingi kõvakestaline söödav vili v. seeme?': {'pähkel'},
#  'Kas see taim on beetli-areekapalmi seeme, mida kasutatakse ergutava toimega närimisainena?': {'areekapähkel'},
#  'Kas see taim on perekonna Corylus mitme puu pähkel?': {'metspähkel'},
#  'Kas see taim on Kreeka pähklipuu luuvili, mille söödav seeme koosneb kahest sopilisest poolmest?': {'Kreeka pähkel'},
#  'Kas see taim on pistaatsia luuvili?': {'pistaatsia'},
#  'Kas see taim on lääneanakardi ehk india nakrapuu seeme?': {'akazuupähkel'},
#  'Kas see taim on pole tegelikult pähkel vaid on luuvili ehk vili ühe seemnega, mida ümbritseb kest?': {'pekaanpähkel'},
#  'Kas see taim on parapähklipuu vili?': {'brasiilia pähkel'},
#  'Kas see taim on Austraalias, Indoneesias ja Madagaskaril kasvav igihaljas lehtpuu või -põõsas, mille mõnd liiki kasvatatakse pähklitaoliste seemnete saamiseks?': {'makadaamia'},
#  'Kas see taim on juure v. varre lihakas toitainerikas paksend?': {'mugul'},
#  'Kas see taim on küüslaugu taime sibul?': {'küüslauk'},
#  'Kas see taim on jaanikaunapuu söödav vili?': {'jaanikaun'},
#  'Kas see taim on mandlipuu luuseemne õlirikas tuum?': {'mandel'},
#  'Kas see taim on kasutatakse peamiselt essentsi jms valmistamiseks?': {'mõrumandel'},
#  'Kas sellest taimest saab teha aedviljakonservi?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha aedviljasalatit?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha aedviljapuljongit?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'aedvili',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtaedvili',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas tegu on köögiviljaaiaga?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha köögiviljavormi?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha aedviljapüreed?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha köögiviljamahla?': {'adzuki',
#   'aed-moorputk',
#   'aed-piimjuur',
#   'aedhernes',
#   'aedseller',
#   'aeduba',
#   'arahhis',
#   'arbuus',
#   'artišokk',
#   'aspar',
#   'baamia',
#   'baklažaan',
#   'banaankõrvits',
#   'bataat',
#   'brüsseli kapsas',
#   'hapukurk',
#   'hernes',
#   'hiina alss',
#   'juurikas',
#   'juurseller',
#   'jääsalat',
#   'kabatšokk',
#   'kapsapea',
#   'karella',
#   'karulauk',
#   'kaunvili',
#   'keerdkaelaline kõrvits',
#   'kikerhernes',
#   'kirsstomat',
#   'kivaano',
#   'kokosell',
#   'kurk',
#   'kõrvits',
#   'köögivili',
#   'lauk',
#   'lehtseller',
#   'lihatomat',
#   'liimauba',
#   'lillkapsas',
#   'maapirn',
#   'melon',
#   'metslauk',
#   'munguba',
#   'murulauk',
#   'muskaatkõrvits',
#   'must uba',
#   'naeris',
#   'nurmlauk',
#   'paprika',
#   'patisson',
#   'peakapsas',
#   'pesasibul',
#   'piimjuur',
#   'ploomtomat',
#   'porru',
#   'porrulauk',
#   'punane kapsas',
#   'punane sibul',
#   'punane uba',
#   'pärlsibul',
#   'rabarber',
#   'riivkapsas',
#   'rohulauk',
#   'rooma salat',
#   'salat',
#   'sibul',
#   'soja',
#   'spagetikõrvits',
#   'spinat',
#   'suvikõrvits',
#   'talisibul',
#   'tomat',
#   'tõrukõrvits',
#   'uba',
#   'varsseller',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha ratatouillet?': {'baklažaan', 'kabatšokk'},
#  'Kas tegu on kõrvitsalisega?': {'arbuus'},
#  'Kas sellest taimest saab teha juurviljapüreed?': {'bataat',
#   'juurikas',
#   'maapirn',
#   'naeris'},
#  'Kas sellest taimest saab teha kurgivett?': {'hapukurk', 'kurk'},
#  'Kas sellest taimest saab teha kurgisalatit?': {'hapukurk', 'kurk'},
#  'Kas sellest taimest saab teha remulaadi?': {'hapukurk', 'kurk'},
#  'Kas sellest taimest saab teha kurgikreemi?': {'hapukurk', 'kurk'},
#  'Kas tegu on hapukurgisalatiga?': {'hapukurk'},
#  'Kas sellest taimest saab teha kõrvitsapüreed?': {'banaankõrvits',
#   'karella',
#   'keerdkaelaline kõrvits',
#   'kokosell',
#   'kõrvits',
#   'muskaatkõrvits',
#   'patisson',
#   'tõrukõrvits',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha kõrvitsapirukat?': {'banaankõrvits',
#   'karella',
#   'keerdkaelaline kõrvits',
#   'kokosell',
#   'kõrvits',
#   'muskaatkõrvits',
#   'patisson',
#   'tõrukõrvits',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha kõrvitsasalatit?': {'banaankõrvits',
#   'karella',
#   'keerdkaelaline kõrvits',
#   'kokosell',
#   'kõrvits',
#   'muskaatkõrvits',
#   'patisson',
#   'tõrukõrvits',
#   'õlikõrvits'},
#  'Kas sellest taimest saab teha maapähkliõli?': {'arahhis'},
#  'Kas sellest taimest saab teha herneputru?': {'aedhernes', 'hernes'},
#  'Kas sellest taimest saab teha hernepüreed?': {'aedhernes', 'hernes'},
#  'Kas sellest taimest saab teha kikerhernejahu?': {'kikerhernes'},
#  'Kas sellest taimest saab teha falafeli?': {'kikerhernes'},
#  'Kas sellest taimest saab teha hummust?': {'kikerhernes'},
#  'Kas see taim on oakujuline ?': {'adzuki',
#   'aeduba',
#   'liimauba',
#   'munguba',
#   'must uba',
#   'punane uba',
#   'soja',
#   'uba'},
#  'Kas sellest taimest saab teha sojajahu?': {'soja'},
#  'Kas sellest taimest saab teha misot?': {'soja'},
#  'Kas sellest taimest saab teha sojapiima?': {'soja'},
#  'Kas sellest taimest saab teha sojaõli?': {'soja'},
#  'Kas sellest taimest saab teha sojakooki?': {'soja'},
#  'Kas sellest taimest saab teha tofut?': {'soja'},
#  'Kas sellest taimest saab teha sojakastet?': {'soja'},
#  'Kas sellest taimest saab teha tempehit?': {'soja'},
#  'Kas see taim on mugul ?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha sibulaomletti?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha sibulasiirupit?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha jahuvorsti?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha salsat?': {'kirsstomat',
#   'lihatomat',
#   'pesasibul',
#   'ploomtomat',
#   'punane sibul',
#   'sibul',
#   'talisibul',
#   'tomat'},
#  'Kas sellest taimest saab teha sibulasaia?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha sibulapirukat?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha sibulasalatit?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha sibulakastet?': {'pesasibul',
#   'punane sibul',
#   'sibul',
#   'talisibul'},
#  'Kas sellest taimest saab teha tomatipastat?': {'kirsstomat',
#   'lihatomat',
#   'ploomtomat',
#   'tomat'},
#  'Kas sellest taimest saab teha letšot?': {'kirsstomat',
#   'lihatomat',
#   'paprika',
#   'ploomtomat',
#   'tomat'},
#  'Kas sellest taimest saab teha Bolognat kastet?': {'kirsstomat',
#   'lihatomat',
#   'ploomtomat',
#   'tomat'},
#  'Kas sellest taimest saab teha sellerisoolt?': {'aedseller',
#   'juurseller',
#   'lehtseller',
#   'varsseller'},
#  'Kas sellest taimest saab teha kapsakotletti?': {'kapsapea',
#   'punane kapsas',
#   'riivkapsas'},
#  'Kas sellest taimest saab teha sültkapsast?': {'kapsapea',
#   'punane kapsas',
#   'riivkapsas'},
#  'Kas sellest taimest saab teha kapsastruudlit?': {'kapsapea',
#   'punane kapsas',
#   'riivkapsas'},
#  'Kas sellest taimest saab teha karulaugupestot?': {'karulauk'},
#  'Kas sellest taimest saab teha rabarberikooki?': {'rabarber'},
#  'Kas sellest taimest saab teha rabarberipirukat?': {'rabarber'},
#  'Kas sellest taimest saab teha rabarberikisselli?': {'rabarber'},
#  'Kas sellest taimest saab teha spinatipirukat?': {'spinat'},
#  'Kas sellest taimest saab teha sinepipulbrit?': {'sinepiseeme'},
#  'Kas sellest taimest saab teha kanepiseemneõli?': {'kanepiseeme'},
#  'Kas sellest taimest saab teha hefut?': {'kanepiseeme'},
#  'Kas sellest taimest saab teha linaseemneõli?': {'linaseeme'},
#  'Kas sellest taimest saab teha linakooki?': {'linaseeme'},
#  'Kas sellest taimest saab teha seesamipastat?': {'seesamiseeme'},
#  'Kas sellest taimest saab teha seesamikooki?': {'seesamiseeme'},
#  'Kas sellest taimest saab teha päevalillekooki?': {'päevalilleseeme'},
#  'Kas sellest taimest saab teha moonikooki?': {'moon'},
#  'Kas tegu on külvisega?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'mais',
#   'maisitang',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'rukis',
#   'rukkiklii',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas sellest taimest saab teha teratoitu?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'mais',
#   'maisitang',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'rukis',
#   'rukkiklii',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas sellest taimest saab teha viljakohvi?': {None,
#   'bulgur',
#   'hirsitang',
#   'indiaani riis',
#   'jahvatis',
#   'kaer',
#   'kaeraklii',
#   'klii',
#   'kruup',
#   'kuskuss',
#   'kõlutera',
#   'mais',
#   'maisitang',
#   'nisu',
#   'nisuklii',
#   'oder',
#   'odratang',
#   'rukis',
#   'rukkiklii',
#   'tang',
#   'tatar',
#   'tera',
#   'toortatar',
#   'vilis'},
#  'Kas sellest taimest saab teha tatrajahu?': {'tatar', 'toortatar'},
#  'Kas sellest taimest saab teha tatraputru?': {'tatar', 'toortatar'},
#  'Kas sellest taimest saab teha kliirokka?': {'kaeraklii',
#   'klii',
#   'nisuklii',
#   'rukkiklii'},
#  'Kas sellest taimest saab teha tabboulehit?': {'bulgur'},
#  'Kas sellest taimest saab teha kaeratumma?': {'kaer'},
#  'Kas sellest taimest saab teha kaeratanguputru?': {'hirsitang',
#   'kaer',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas sellest taimest saab teha kilet?': {'kaer'},
#  'Kas sellest taimest saab teha kaerakamajahu?': {'kaer'},
#  'Kas sellest taimest saab teha tanguvorsti?': {'hirsitang',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas sellest taimest saab teha tanguleent?': {'hirsitang',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas sellest taimest saab teha Mulgit putru?': {'hirsitang',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas sellest taimest saab teha tanguputru?': {'hirsitang',
#   'kuskuss',
#   'maisitang',
#   'odratang',
#   'tang'},
#  'Kas sellest taimest saab teha mannat?': {'kuskuss'},
#  'Kas sellest taimest saab teha maisijahu?': {'mais'},
#  'Kas sellest taimest saab teha maisiõli?': {'mais'},
#  'Kas sellest taimest saab teha plaksumaisi?': {'mais'},
#  'Kas sellest taimest saab teha polentat?': {'mais'},
#  'Kas sellest taimest saab teha maisitärklist?': {'mais'},
#  'Kas sellest taimest saab teha maisikooki?': {'mais'},
#  'Kas sellest taimest saab teha mämmi?': {None},
#  'Kas sellest taimest saab teha mähki?': {None},
#  'Kas sellest taimest saab teha õltsi?': {None},
#  'Kas sellest taimest saab teha linnasejahu?': {None},
#  'Kas sellest taimest saab teha aprikoosi?': {'aprikoos'},
#  'Kas sellest taimest saab teha aprikoosikompotti?': {'aprikoos'},
#  'Kas sellest taimest saab teha aprikoosimahla?': {'aprikoos'},
#  'Kas sellest taimest saab teha mangomahla?': {'mango'},
#  'Kas sellest taimest saab teha külmpressitut oliiviõli?': {'oliiv'},
#  'Kas sellest taimest saab teha tapenaadi?': {'oliiv'},
#  'Kas sellest taimest saab teha kirsikeedist?': {'kirss', 'klaaskirss'},
#  'Kas sellest taimest saab teha kirsimahla?': {'kirss', 'klaaskirss'},
#  'Kas sellest taimest saab teha kirsikompotti?': {'kirss', 'klaaskirss'},
#  'Kas sellest taimest saab teha kirsisiirupit?': {'kirss', 'klaaskirss'},
#  'Kas sellest taimest saab teha kookoshelvest?': {'kookos'},
#  'Kas sellest taimest saab teha kookospiima?': {'kookos'},
#  'Kas sellest taimest saab teha kookosmakrooni?': {'kookos'},
#  'Kas sellest taimest saab teha kookosekooki?': {'kookos'},
#  'Kas sellest taimest saab teha marjasiirupit?': {'aedmaasikas',
#   'aedmari',
#   'aedmurakas',
# ...
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljapüreed?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljakompotti?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljapudingit?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljasalatit?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljatorti?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljakooki?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljaveini?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljakonservi?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha puuviljajooki?': {'alligaatorpirn',
#   'ananass',
#   'antoonovka',
#   'apelsin',
#   'banaan',
#   'bergamott',
#   'dessertõun',
#   'diospüür',
#   'draakonivili',
#   'durian',
#   'frukt',
#   'granaat',
#   'greip',
#   'guajaav',
#   'hiina ploom',
#   'inglite vili',
#   'jahubanaan',
#   'kahvrilaim',
#   'kaktusvili',
#   'karamboola',
#   'kerimoia',
#   'kiivi',
#   'kinkan',
#   'kišmišš',
#   'klaar',
#   'klementiin',
#   'kreek',
#   'kuldrenett',
#   'küdoonia',
#   'laim',
#   'lamevirsik',
#   'litši',
#   'longan',
#   'mandariin',
#   'metsõun',
#   'munakinkan',
#   'nektariin',
#   'paradiisiõun',
#   'persik',
#   'pirn',
#   'ploom',
#   'pomel',
#   'pomerants',
#   'punagreip',
#   'renett',
#   'renklood',
#   'satsuma',
#   'sibulõun',
#   'sidrun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sõrmlaim',
#   'sügisõun',
#   'taliõun',
#   'tangeriin',
#   'tsitrus',
#   'tuviõun',
#   'ubin',
#   'veriapelsin',
#   'viinamari',
#   'viss'},
#  'Kas sellest taimest saab teha banaanijäätist?': {'banaan', 'jahubanaan'},
#  'Kas sellest taimest saab teha ploomimehu?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha ploomimahla?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha ploomiviina?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha ploomikastet?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha ploomikeedist?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha ploomikompotti?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha ploomipudingit?': {'ploom', 'renklood'},
#  'Kas sellest taimest saab teha õunavormi?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunamehu?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunasiidrit?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunakreemi?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunaviina?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunapüreed?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunamahla?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunaveini?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunakastet?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunakompotti?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunakeedist?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunakooki?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas sellest taimest saab teha õunasalatit?': {'antoonovka',
#   'dessertõun',
#   'klaar',
#   'kuldrenett',
#   'metsõun',
#   'paradiisiõun',
#   'renett',
#   'sibulõun',
#   'suislepp',
#   'suviõun',
#   'säilitusõun',
#   'sügisõun',
#   'taliõun',
#   'tuviõun',
#   'ubin',
#   'viss'},
#  'Kas see taim on hapu ?': {'viss'},
#  'Kas sellest taimest saab teha pirnisiidrit?': {'bergamott', 'pirn'},
#  'Kas sellest taimest saab teha pirnimahla?': {'bergamott', 'pirn'},
#  'Kas sellest taimest saab teha pirnikompotti?': {'bergamott', 'pirn'},
#  'Kas sellest taimest saab teha virsikukastet?': {'lamevirsik', 'persik'},
#  'Kas sellest taimest saab teha virsikukompotti?': {'lamevirsik', 'persik'},
#  'Kas sellest taimest saab teha virsikumahla?': {'lamevirsik', 'persik'},
#  'Kas sellest taimest saab teha virsikukooki?': {'lamevirsik', 'persik'},
#  'Kas sellest taimest saab teha ananassikonservi?': {'ananass'},
#  'Kas sellest taimest saab teha ananassimahla?': {'ananass'},
#  'Kas sellest taimest saab teha laimivett?': {'kahvrilaim',
#   'laim',
#   'sõrmlaim'},
#  'Kas sellest taimest saab teha sidrunikreemi?': {'sidrun'},
#  'Kas sellest taimest saab teha sidrunimahla?': {'sidrun'},
#  'Kas sellest taimest saab teha sidrunijooki?': {'sidrun'},
#  'Kas sellest taimest saab teha limonaadi?': {'sidrun'},
#  'Kas sellest taimest saab teha sidrunivõiet?': {'sidrun'},
#  'Kas sellest taimest saab teha sidrunisoodat?': {'sidrun'},
#  'Kas sellest taimest saab teha sidruniekstrakti?': {'sidrun'},
#  'Kas sellest taimest saab teha sidrunisiirupit?': {'sidrun'},
#  'Kas sellest taimest saab teha apelsinivett?': {'apelsin', 'veriapelsin'},
#  'Kas sellest taimest saab teha apelsinimahla?': {'apelsin', 'veriapelsin'},
#  'Kas sellest taimest saab teha mandariinimahla?': {'klementiin',
#   'mandariin',
#   'satsuma'},
#  'Kas sellest taimest saab teha grenadiini?': {'granaat'},
#  'Kas sellest taimest saab teha palsamiäädikat?': {'kišmišš', 'viinamari'},
#  'Kas sellest taimest saab teha viinamarjaseemneõli?': {'kišmišš',
#   'viinamari'},
#  'Kas sellest taimest saab teha viinamarjaveini?': {'kišmišš', 'viinamari'},
#  'Kas sellest taimest saab teha viinamarjamahla?': {'kišmišš', 'viinamari'},
#  'Kas sellest taimest saab teha nugati?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas sellest taimest saab teha pähkliküpsist?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas sellest taimest saab teha galetti?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas sellest taimest saab teha pähklikreemi?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas sellest taimest saab teha pähklitorti?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas sellest taimest saab teha pähklirosinaküpsist?': {'Kreeka pähkel',
#   'akazuupähkel',
#   'areekapähkel',
#   'brasiilia pähkel',
#   'makadaamia',
#   'metspähkel',
#   'pekaanpähkel',
#   'pistaatsia',
#   'pähkel'},
#  'Kas sellest taimest saab teha kreekapähklisaid?': {'Kreeka pähkel'},
#  'Kas sellest taimest saab teha pistaatsiaküpsist?': {'pistaatsia'},
#  'Kas sellest taimest saab teha aiolit?': {'küüslauk'},
#  'Kas sellest taimest saab teha küüslaugukastet?': {'küüslauk'}}

# %%
len(küsimused_vastused)
# Out:
# 499

# %% [markdown]
# # 3. dataframe'i tegemine

# %% [markdown]
# Rida on Loom
#
# Veerg on küsimus

# %%
import pandas as pd

# %%
# Teisenda sõnastiku väärtused (hulgad) loenditeks ja loo DataFrame
rows = []
for question, answers in küsimused_vastused.items():
    for answer in answers:
        rows.append({'Sõna': answer, 'Küsimus': question})
rows
df = pd.DataFrame(rows)

# %%
one_hot_df = pd.get_dummies(df, columns=['Küsimus'], prefix='', prefix_sep='')

result = one_hot_df.groupby('Sõna').sum().reset_index()

# %%
# lisame juurde ka sõna sünonüümid
for sõna in result["Sõna"]:
    for lemmalist in list_of_all_suitable_vegetables:
        if sõna in lemmalist:
            result.loc[result["Sõna"] == sõna, "Synonyms"] = ", ".join(lemmalist)

# %%
result
# Out:
#               Sõna  Kas see taim on 'Antonovka' sorti taliõun?  \
# 0    Kreeka pähkel                                           0
# 1           adzuki                                           0
# 2     aed-moorputk                                           0
# 3     aed-piimjuur                                           0
# 4        aedhernes                                           0
# ..             ...                                         ...
# 230      viigimari                                           0
# 231      viinamari                                           0
# 232          vilis                                           0
# 233           viss                                           0
# 234     õlikõrvits                                           0
#
#      Kas see taim on 'Pärnu tuviõuna' sorti sügisõun v. 'Krügeri tuviõuna' sorti suviõun?  \
# 0                                                                                       0
# 1                                                                                       0
# 2                                                                                       0
# 3                                                                                       0
# 4                                                                                       0
# ..                                                                                    ...
# 230                                                                                     0
# 231                                                                                     0
# 232                                                                                     0
# 233                                                                                     0
# 234                                                                                     0
#
#      Kas see taim on , želeetaolise viljalihaga lõunamaa vili?  \
# 0                                                            0
# 1                                                            0
# 2                                                            0
# 3                                                            0
# 4                                                            0
# ..                                                         ...
# 230                                                          0
# 231                                                          0
# 232                                                          0
# 233                                                          0
# 234                                                          0
#
#      Kas see taim on Aed-piimjuur on väga vana, maitselt sparglit meenutav kultuurtaim; koor on kreemikas ja sisu valge?  \
# 0                                                                                                                      0
# 1                                                                                                                      0
# 2                                                                                                                      0
# 3                                                                                                                      1
# 4                                                                                                                      0
# ..                                                                                                                   ...
# 230                                                                                                                    0
# 231                                                                                                                    0
# 232                                                                                                                    0
# 233                                                                                                                    0
# 234                                                                                                                    0
#
#      Kas see taim on Ameerika pirnloorberi  vili?  \
# 0                                               0
# 1                                               0
# 2                                               0
# 3                                               0
# 4                                               0
# ..                                            ...
# 230                                             0
# 231                                             0
# 232                                             0
# 233                                             0
# 234                                             0
#
#      Kas see taim on Ananassi taime suur käbijas vilikond?  \
# 0                                                        0
# 1                                                        0
# 2                                                        0
# 3                                                        0
# 4                                                        0
# ..                                                     ...
# 230                                                      0
# 231                                                      0
# 232                                                      0
# 233                                                      0
# 234                                                      0
#
#      Kas see taim on Austraalias, Indoneesias ja Madagaskaril kasvav igihaljas lehtpuu või -põõsas, mille mõnd liiki kasvatatakse pähklitaoliste seemnete saamiseks?  \
# 0                                                                                                                                                                  0
# 1                                                                                                                                                                  0
# 2                                                                                                                                                                  0
# 3                                                                                                                                                                  0
# 4                                                                                                                                                                  0
# ..                                                                                                                                                               ...
# 230                                                                                                                                                                0
# 231                                                                                                                                                                0
# 232                                                                                                                                                                0
# 233                                                                                                                                                                0
# 234                                                                                                                                                                0
#
#      Kas see taim on Austraaliast pärit, kujult kurki meenutav tumeroheline või tumepunane sõrm-pisilaimipuu vili?  \
# 0                                                                                                                0
# 1                                                                                                                0
# 2                                                                                                                0
# 3                                                                                                                0
# 4                                                                                                                0
# ..                                                                                                             ...
# 230                                                                                                              0
# 231                                                                                                              0
# 232                                                                                                              0
# 233                                                                                                              0
# 234                                                                                                              0
#
#      Kas see taim on Hariliku seesami tillukesed lamedad seemned?  ...  \
# 0                                                               0  ...
# 1                                                               0  ...
# 2                                                               0  ...
# 3                                                               0  ...
# 4                                                               0  ...
# ..                                                            ...  ...
# 230                                                             0  ...
# 231                                                             0  ...
# 232                                                             0  ...
# 233                                                             0  ...
# 234                                                             0  ...
#
#      Kas tegu on sügisõunaga?  Kas tegu on taliõunaga?  Kas tegu on tanguga?  \
# 0                           0                        0                     0
# 1                           0                        0                     0
# 2                           0                        0                     0
# 3                           0                        0                     0
# 4                           0                        0                     0
# ..                        ...                      ...                   ...
# 230                         0                        0                     0
# 231                         0                        0                     0
# 232                         0                        0                     0
# 233                         0                        0                     0
# 234                         0                        0                     0
#
#      Kas tegu on tatraga?  Kas tegu on teraga?  Kas tegu on tomatiga?  \
# 0                       0                    0                      0
# 1                       0                    0                      0
# 2                       0                    0                      0
# 3                       0                    0                      0
# 4                       0                    0                      0
# ..                    ...                  ...                    ...
# 230                     0                    0                      0
# 231                     0                    0                      0
# 232                     0                    1                      0
# 233                     0                    0                      0
# 234                     0                    0                      0
#
#      Kas tegu on tsitrusega?  Kas tegu on ubinaga?  Kas tegu on viinamarjaga?  \
# 0                          0                     0                          0
# 1                          0                     0                          0
# 2                          0                     0                          0
# 3                          0                     0                          0
# 4                          0                     0                          0
# ..                       ...                   ...                        ...
# 230                        0                     0                          0
# 231                        0                     0                          1
# 232                        0                     0                          0
# 233                        0                     1                          0
# 234                        0                     0                          0
#
#                          Synonyms
# 0    Kreeka pähkel, kreeka pähkel
# 1                adzuki, asukiuba
# 2         aed-moorputk, pastinaak
# 3                    aed-piimjuur
# 4                       aedhernes
# ..                            ...
# 230               viigimari, viik
# 231                     viinamari
# 232                         vilis
# 233                          viss
# 234                    õlikõrvits
#
# [235 rows x 501 columns]

# %%
list_of_all = result["Sõna"].tolist()

# %%
unikaalsed_sõnad = result["Sõna"].nunique()
unikaalsed_sõnad
# Out:
# 235

# %%
pd.set_option('display.max_rows', None)

# %%
# sõnad millel on rohkem kui x küsimust
filtered_df = result[result.drop(columns=["Synonyms"]).iloc[:, 1:].sum(axis=1) > 6]
filtered_df.shape
# Out:
# (203, 501)

# %% [markdown]
# äkki võiks lisada, kas on tegu põhisõnastiku sõnaga ka küsimusse, aga seda mitte ekraanile kuvada vaid kaustada kuskil taustal?

# %%
result.to_csv('töötlemata_taime2_df_andmed.csv', index=False)

# %% [markdown]
# ### kontroll dataframe

# %% [markdown]
# dataaframe, mida kasutan, et osasid sõnasid eemaldada, mis pole niivõrd populaarsed.
#
# Samuti lisan tähtsuse skaala sõnadele

# %%
result = pd.read_csv("töötlemata_taime2_df_andmed.csv")

# %%
andmed = {
    'Sõna': result["Sõna"],
    'Synonyms' : result["Synonyms"],
    'most_popular': [None] * len(list_of_all),
    'põhisõnad': [None] * len(list_of_all),
    'palju_küsimusi': [None] * len(list_of_all),
    'vikipeedia': [None] * len(list_of_all)
}

df_kontroll = pd.DataFrame(andmed)

# %%
filtered_df_1 = result[result.drop(columns=["Synonyms"]).iloc[:, 1:].sum(axis=1) > 9]
filtered_df_2 = result[(result.drop(columns=["Synonyms"]).iloc[:, 1:].sum(axis=1) > 6) &
                       (result.drop(columns=["Synonyms"]).iloc[:, 1:].sum(axis=1) <= 9)]

df_sõnad_1 = filtered_df_1["Sõna"].tolist()
df_sõnad_2 = filtered_df_2["Sõna"].tolist()

# %%
df_kontroll['palju_küsimusi'] = df_kontroll['Sõna'].apply(
    lambda sõna: 1 if sõna in df_sõnad_1 else (2 if sõna in df_sõnad_2 else None)
) # kui küsimusi on üle 9 siis väärtus 1 ja kui 6-9 siis väärtus on 2

# %%
df_kontroll[(df_kontroll['palju_küsimusi'] != 1) & (df_kontroll['palju_küsimusi'] != 2) ]
# Out:
#                 Sõna                                           Synonyms  \
# 10           aedvili                                            aedvili
# 17          aprikoos                                           aprikoos
# 39         granadill                                                NaN
# 42         hapukirss                                          hapukirss
# 51               iva                                         iva, seeme
# 52         jaanikaun                                                NaN
# 67       kanepiseeme                                                NaN
# 68            kappar                                                NaN
# 83          kivivili                                  kivivili, luuvili
# 94   kuivatatud vili                                    kuivatatud vili
# 100    kõrvitsaseeme                                      kõrvitsaseeme
# 103         küüslauk                                    küüslauk, noblu
# 107      lehtaedvili                         lehtaedvili, lehtköögivili
# 112        linaseeme                             linaseeme, linaseemned
# 115     loorberimari                                       loorberimari
# 123           mandel                                                NaN
# 124            mango                                  mango, mangoploom
# 133         mirabell                                           mirabell
# 134             moon                                   moon, mooniseeme
# 135            mugul                                                NaN
# 136        mugulvili                                                NaN
# 139            murel                                              murel
# 146       mõrumandel                                         mõrumandel
# 152             oder                                     oder, odratera
# 154            oliiv                                              oliiv
# 165      piiniaseeme  piiniaseeme, seedermänni pähkel, seedermänniseeme
# 178  päevalilleseeme                            päevalilleseeme, sihvka
# 189            rukis                                   rukis, rukkitera
# 193     seesamiseeme                                       seesamiseeme
# 197      sinepiseeme                                        sinepiseeme
# 208      söödav vili                                                NaN
# 224           urjukk                                             urjukk
#
#     most_popular põhisõnad  palju_küsimusi vikipeedia
# 10          None      None             NaN       None
# 17          None      None             NaN       None
# 39          None      None             NaN       None
# 42          None      None             NaN       None
# 51          None      None             NaN       None
# 52          None      None             NaN       None
# 67          None      None             NaN       None
# 68          None      None             NaN       None
# 83          None      None             NaN       None
# 94          None      None             NaN       None
# 100         None      None             NaN       None
# 103         None      None             NaN       None
# 107         None      None             NaN       None
# 112         None      None             NaN       None
# 115         None      None             NaN       None
# 123         None      None             NaN       None
# 124         None      None             NaN       None
# 133         None      None             NaN       None
# 134         None      None             NaN       None
# 135         None      None             NaN       None
# 136         None      None             NaN       None
# 139         None      None             NaN       None
# 146         None      None             NaN       None
# 152         None      None             NaN       None
# 154         None      None             NaN       None
# 165         None      None             NaN       None
# 178         None      None             NaN       None
# 189         None      None             NaN       None
# 193         None      None             NaN       None
# 197         None      None             NaN       None
# 208         None      None             NaN       None
# 224         None      None             NaN       None

# %% [markdown]
# # andemte faili lugemine

# %%
#result.to_csv('töötlemata_andmed.csv', index=False)

# %% [markdown]
# # 4. vikipeedia scrapimine

# %%
import requests
import time

# Eeldame, et 'df_kontroll' on juba loodud ja sisaldab veergu 'Loom' ja 'Synonyms'
count_success = 0
count_fail = 0
failed = []
successed = []

# Funktsioon sünonüümide kontrollimiseks Vikipeediast
def check_vikipedia(sõna, synonyms):
    if pd.isna(synonyms):  # Kui sünonüüme pole, kontrollime ainult looma nime
        r = requests.get(f'https://et.wikipedia.org/wiki/{sõna}')
        if r.status_code == 200:
            df_kontroll.loc[df_kontroll["Sõna"] == sõna, "most_popular"] = sõna.lower()
            return 1
        else:
            return None
    else:
        synonym_list = synonyms.split(", ")  # Muudame sünonüümide stringi listiks
        for synonym in synonym_list:
            r = requests.get(f'https://et.wikipedia.org/wiki/{synonym}')
            if r.status_code == 200:
                df_kontroll.loc[df_kontroll["Sõna"] == sõna, "most_popular"] = synonym.lower()
                return 1
        return None

# Teeme Vikipeedia päringud kõigi loomade jaoks
for index, row in df_kontroll.iterrows():
    sõna = row['Sõna']
    synonyms = row['Synonyms']

    vikipeedia_status = check_vikipedia(sõna, synonyms)

    if vikipeedia_status == 1:
        count_success += 1
        df_kontroll.loc[df_kontroll["Sõna"] == sõna, "vikipeedia"] = 1
        successed.append(sõna)
    else:
        count_fail += 1
        df_kontroll.loc[df_kontroll["Sõna"] == sõna, "vikipeedia"] = None
        failed.append(sõna)

    time.sleep(0.1)  # Lisame viivituse, et vältida serveri koormamist

# Prindime kokkuvõtte
print(f'Success: {count_success}')
print(f'Failed: {count_fail}')
print(f'Successed: {successed}')
print(f'Failed: {failed}')
# Out:
# Success: 152
# Failed: 83
# Successed: ['Kreeka pähkel', 'aed-moorputk', 'aedmaasikas', 'aedmurakas', 'aedseller', 'aeduba', 'aedvili', 'akazuupähkel', 'alligaatorpirn', 'ananass', 'antoonovka', 'apelsin', 'aprikoos', 'arahhis', 'arbuus', 'areekapähkel', 'artišokk', 'aspar', 'astelpaju', 'baamia', 'baklažaan', 'banaan', 'bataat', 'bergamott', 'brasiilia pähkel', 'brüsseli kapsas', 'bulgur', 'diospüür', 'durian', 'frukt', 'granaat', 'granadill', 'greip', 'guajaav', 'hapukirss', 'hapukurk', 'hernes', 'hiina ploom', 'hõrakmari', 'inglite vili', 'iva', 'joovikas', 'juurikas', 'juurseller', 'jõhvikas', 'kaarel', 'kabatšokk', 'kadakamari', 'kaer', 'kappar', 'kapsapea', 'karamboola', 'karulauk', 'karusmari', 'kaunvili', 'kiivi', 'kikerhernes', 'kirss', 'kirsstomat', 'kivivili', 'klaar', 'klementiin', 'klii', 'kookos', 'korint', 'kreek', 'kruup', 'kuldrenett', 'kurk', 'kuskuss', 'kõrvits', 'köögivili', 'küdoonia', 'küüslauk', 'laim', 'lamevirsik', 'lauk', 'lillkapsas', 'linaseeme', 'litši', 'maapirn', 'maasikas', 'mage sõstar', 'mais', 'mandariin', 'mandel', 'mango', 'mari', 'melon', 'mesimurakas', 'metslauk', 'metsmaasikas', 'metspähkel', 'moon', 'mugul', 'munguba', 'murel', 'murulauk', 'must sõstar', 'mustikas', 'muulukamari', 'naeris', 'nektariin', 'nisu', 'nurmlauk', 'oder', 'oliiv', 'palukas', 'paprika', 'peakapsas', 'persik', 'pihlakamari', 'piimjuur', 'piiniaseeme', 'pirn', 'pistaatsia', 'ploom', 'pomel', 'pomerants', 'porru', 'porrulauk', 'punane sibul', 'pähkel', 'põldmari', 'rabarber', 'rohulauk', 'rooma salat', 'rosin', 'rukis', 'salat', 'seesamiseeme', 'sibul', 'sidrun', 'soja', 'spinat', 'suislepp', 'sultana', 'suvikõrvits', 'sõstar', 'talisibul', 'tang', 'tangeriin', 'tatar', 'tera', 'tomat', 'tsitrus', 'uba', 'ubin', 'vaarikas', 'vaarikpampel', 'viigimari', 'viinamari']
# Failed: ['adzuki', 'aed-piimjuur', 'aedhernes', 'aedmari', 'alrauni mari', 'banaankõrvits', 'dessertõun', 'draakonivili', 'hiina alss', 'hirsitang', 'indiaani riis', 'jaanikaun', 'jahubanaan', 'jahvatis', 'jääsalat', 'kaeraklii', 'kahvrilaim', 'kaktusvili', 'kanepiseeme', 'karella', 'keerdkaelaline kõrvits', 'kerimoia', 'kinkan', 'kivaano', 'kišmišš', 'klaaskirss', 'kokosell', 'kuivatatud vili', 'kõlutera', 'kõrvitsaseeme', 'lehtaedvili', 'lehtseller', 'lihatomat', 'liimauba', 'longan', 'loorberimari', 'maisitang', 'makadaamia', 'metsamari', 'metsõun', 'mirabell', 'mugulvili', 'munakinkan', 'muskaatkõrvits', 'must uba', 'mõrumandel', 'nisuklii', 'odratang', 'paradiisiõun', 'patisson', 'pekaanpähkel', 'pesasibul', 'ploomtomat', 'punagreip', 'punane kapsas', 'punane uba', 'päevalilleseeme', 'pärlsibul', 'renett', 'renklood', 'riivkapsas', 'rukkiklii', 'satsuma', 'sibulõun', 'sinepiseeme', 'spagetikõrvits', 'suviõun', 'säilitusõun', 'sõrmlaim', 'söödav vili', 'sügisõun', 'taliõun', 'tamarillo', 'toortatar', 'tuviõun', 'tõrukõrvits', 'urjukk', 'valge sõstar', 'varsseller', 'veriapelsin', 'vilis', 'viss', 'õlikõrvits']

# %%
df_kontroll
# Out:
#                        Sõna  \
# 0             Kreeka pähkel
# 1                    adzuki
# 2              aed-moorputk
# 3              aed-piimjuur
# 4                 aedhernes
# 5               aedmaasikas
# 6                   aedmari
# 7                aedmurakas
# 8                 aedseller
# 9                    aeduba
# 10                  aedvili
# 11             akazuupähkel
# 12           alligaatorpirn
# 13             alrauni mari
# 14                  ananass
# 15               antoonovka
# 16                  apelsin
# 17                 aprikoos
# 18                  arahhis
# 19                   arbuus
# 20             areekapähkel
# 21                 artišokk
# 22                    aspar
# 23                astelpaju
# 24                   baamia
# 25                baklažaan
# 26                   banaan
# 27            banaankõrvits
# 28                   bataat
# 29                bergamott
# 30         brasiilia pähkel
# 31          brüsseli kapsas
# 32                   bulgur
# 33               dessertõun
# 34                 diospüür
# 35             draakonivili
# 36                   durian
# 37                    frukt
# 38                  granaat
# 39                granadill
# 40                    greip
# 41                  guajaav
# 42                hapukirss
# 43                 hapukurk
# 44                   hernes
# 45               hiina alss
# 46              hiina ploom
# 47                hirsitang
# 48                hõrakmari
# 49            indiaani riis
# 50             inglite vili
# 51                      iva
# 52                jaanikaun
# 53               jahubanaan
# 54                 jahvatis
# 55                 joovikas
# 56                 juurikas
# 57               juurseller
# 58                 jääsalat
# 59                 jõhvikas
# 60                   kaarel
# 61                kabatšokk
# 62               kadakamari
# 63                     kaer
# 64                kaeraklii
# 65               kahvrilaim
# 66               kaktusvili
# 67              kanepiseeme
# 68                   kappar
# 69                 kapsapea
# 70               karamboola
# 71                  karella
# 72                 karulauk
# 73                karusmari
# 74                 kaunvili
# 75   keerdkaelaline kõrvits
# 76                 kerimoia
# 77                    kiivi
# 78              kikerhernes
# 79                   kinkan
# 80                    kirss
# 81               kirsstomat
# 82                  kivaano
# 83                 kivivili
# 84                  kišmišš
# 85                    klaar
# 86               klaaskirss
# 87               klementiin
# 88                     klii
# 89                 kokosell
# 90                   kookos
# 91                   korint
# 92                    kreek
# 93                    kruup
# 94          kuivatatud vili
# 95               kuldrenett
# 96                     kurk
# 97                  kuskuss
# 98                 kõlutera
# 99                  kõrvits
# 100           kõrvitsaseeme
# 101               köögivili
# 102                küdoonia
# 103                küüslauk
# 104                    laim
# 105              lamevirsik
# 106                    lauk
# 107             lehtaedvili
# 108              lehtseller
# 109               lihatomat
# 110                liimauba
# 111              lillkapsas
# 112               linaseeme
# 113                   litši
# 114                  longan
# 115            loorberimari
# 116                 maapirn
# 117                maasikas
# 118             mage sõstar
# 119                    mais
# 120               maisitang
# 121              makadaamia
# 122               mandariin
# 123                  mandel
# 124                   mango
# 125                    mari
# 126                   melon
# 127             mesimurakas
# 128               metsamari
# 129                metslauk
# 130            metsmaasikas
# 131              metspähkel
# 132                 metsõun
# 133                mirabell
# 134                    moon
# 135                   mugul
# 136               mugulvili
# 137              munakinkan
# 138                 munguba
# 139                   murel
# 140                murulauk
# 141          muskaatkõrvits
# 142             must sõstar
# 143                must uba
# 144                mustikas
# 145             muulukamari
# 146              mõrumandel
# 147                  naeris
# 148               nektariin
# 149                    nisu
# 150                nisuklii
# 151                nurmlauk
# 152                    oder
# 153                odratang
# 154                   oliiv
# 155                 palukas
# 156                 paprika
# 157            paradiisiõun
# 158                patisson
# 159               peakapsas
# 160            pekaanpähkel
# 161                  persik
# 162               pesasibul
# 163             pihlakamari
# 164                piimjuur
# 165             piiniaseeme
# 166                    pirn
# 167              pistaatsia
# 168                   ploom
# 169              ploomtomat
# 170                   pomel
# 171               pomerants
# 172                   porru
# 173               porrulauk
# 174               punagreip
# 175           punane kapsas
# 176            punane sibul
# 177              punane uba
# 178         päevalilleseeme
# 179                  pähkel
# 180               pärlsibul
# 181                põldmari
# 182                rabarber
# 183                  renett
# 184                renklood
# 185              riivkapsas
# 186                rohulauk
# 187             rooma salat
# 188                   rosin
# 189                   rukis
# 190               rukkiklii
# 191                   salat
# 192                 satsuma
# 193            seesamiseeme
# 194                   sibul
# 195                sibulõun
# 196                  sidrun
# 197             sinepiseeme
# 198                    soja
# 199          spagetikõrvits
# 200                  spinat
# 201                suislepp
# 202                 sultana
# 203             suvikõrvits
# 204                 suviõun
# 205             säilitusõun
# 206                sõrmlaim
# 207                  sõstar
# 208             söödav vili
# 209                sügisõun
# 210               talisibul
# 211                 taliõun
# 212               tamarillo
# 213                    tang
# 214               tangeriin
# 215                   tatar
# 216                    tera
# 217                   tomat
# 218               toortatar
# 219                 tsitrus
# 220                 tuviõun
# 221             tõrukõrvits
# 222                     uba
# 223                    ubin
# 224                  urjukk
# 225                vaarikas
# 226            vaarikpampel
# 227            valge sõstar
# 228              varsseller
# 229             veriapelsin
# 230               viigimari
# 231               viinamari
# 232                   vilis
# 233                    viss
# 234              õlikõrvits
#
#                                                                Synonyms  \
# 0                                          Kreeka pähkel, kreeka pähkel
# 1                                                      adzuki, asukiuba
# 2                                               aed-moorputk, pastinaak
# 3                                                          aed-piimjuur
# 4                                                             aedhernes
# 5                                                           aedmaasikas
# 6                                                      aedmari, aiamari
# 7                                                    aedmurakas, pampel
# 8                                                     aedseller, seller
# 9                                                     aeduba, Türgi uba
# 10                                                              aedvili
# 11   akazuupähkel, India pähkel, india pähkel, kašupähkel, nakar, nakra
# 12                                             alligaatorpirn, avokaado
# 13                                alrauni mari, lemmemari, tuudaimimari
# 14                                                              ananass
# 15                                                           antoonovka
# 16                                                              apelsin
# 17                                                             aprikoos
# 18                                     arahhis, hiina pähkel, maapähkel
# 19                                                               arbuus
# 20                                           areekapähkel, beetlipähkel
# 21                                                             artišokk
# 22                                                       aspar, spargel
# 23                                             astelpaju, astelpajumari
# 24                                                         baamia, okra
# 25                                                     baklažaan, pommu
# 26                                                               banaan
# 27                                                        banaankõrvits
# 28                                    bataat, maguskartul, magus kartul
# 29                                                            bergamott
# 30                                         brasiilia pähkel, parapähkel
# 31                                          brüsseli kapsas, rooskapsas
# 32                                                               bulgur
# 33                                                  dessertõun, lauaõun
# 34                                    diospüür, hurmaa, kaki, kakiploom
# 35                                                 draakonivili, pitaia
# 36                                                               durian
# 37                                                       frukt, puuvili
# 38                                                  granaat, granaatõun
# 39                                                                  NaN
# 40                                            greip, greipfruut, kreebu
# 41                                                              guajaav
# 42                                                            hapukirss
# 43                                                             hapukurk
# 44                                                               hernes
# 45                                               hiina alss, vesikastan
# 46                                             hiina ploom, litš, litši
# 47                                                 hirsitang, hirsitera
# 48                                             hõrakmari, punane sõstar
# 49            indiaani riis, metsik riis, Tuskaroora vesiriis, vesiriis
# 50                                                 inglite vili, papaia
# 51                                                           iva, seeme
# 52                                                                  NaN
# 53                                                           jahubanaan
# 54                                                             jahvatis
# 55                                                    joovikas, sinikas
# 56                                                                  NaN
# 57                                                           juurseller
# 58                                                             jääsalat
# 59                                                   jõhvikas, kuremari
# 60                                         kaarel, karumurakas, murakas
# 61                           kabatšokk, rullkõrvits, zucchini, tsukiini
# 62                                                           kadakamari
# 63                                                      kaer, kaeratera
# 64                                                                  NaN
# 65                                                 kahvrilaim, kombaava
# 66                                                           kaktusvili
# 67                                                                  NaN
# 68                                                                  NaN
# 69                                                     kapsapea, kapsas
# 70                                                 karamboola, tähtvili
# 71                                                    karella, kibekurk
# 72                                                             karulauk
# 73                                          karusmari, tikerber, tikker
# 74                                                             kaunvili
# 75                                 keerdkaelaline kõrvits, käändkõrvits
# 76                                                  kerimoia, suhkruõun
# 77                                                                kiivi
# 78                                        kikerhernes, nuut, põishernes
# 79                                      kinkan, kumkvaat, kääbusapelsin
# 80                                                        kirss, käsper
# 81                                                           kirsstomat
# 82                                                    kivaano, ogamelon
# 83                                                    kivivili, luuvili
# 84                                                              kišmišš
# 85                                         klaar, klaarõun, valge klaar
# 86                                                           klaaskirss
# 87                                                           klementiin
# 88                                                          klii, kliid
# 89                                               kokosell, pikk kõrvits
# 90                                                 kookos, kookospähkel
# 91                                                               korint
# 92                                                                kreek
# 93                                         kruubid, kruubitangud, kruup
# 94                                                      kuivatatud vili
# 95                                                           kuldrenett
# 96                                                                 kurk
# 97                                                              kuskuss
# 98                                                             kõlutera
# 99                                                              kõrvits
# 100                                                       kõrvitsaseeme
# 101                                                           köögivili
# 102                                                            küdoonia
# 103                                                     küüslauk, noblu
# 104                                                                laim
# 105                                                          lamevirsik
# 106                                                                lauk
# 107                                          lehtaedvili, lehtköögivili
# 108                                                          lehtseller
# 109                                                           lihatomat
# 110                                                            liimauba
# 111                                                          lillkapsas
# 112                                              linaseeme, linaseemned
# 113                                            litši, pulasan, rambutan
# 114                                                              longan
# 115                                                        loorberimari
# 116                                 maapirn, mugulpäevalill, topinambur
# 117                                                maasikas, maasikmari
# 118                                                         mage sõstar
# 119                                                     mais, maisitera
# 120                                                           maisitang
# 121                                        makadaamia, makadaamiapähkel
# 122                                                           mandariin
# 123                                                                 NaN
# 124                                                   mango, mangoploom
# 125                                                                mari
# 126                                                               melon
# 127                                             mesimurakas, soomurakas
# 128                                                 metsamari, metsmari
# 129                                                            metslauk
# 130                                                        metsmaasikas
# 131                                           metspähkel, sarapuupähkel
# 132                                                             metsõun
# 133                                                            mirabell
# 134                                                    moon, mooniseeme
# 135                                                                 NaN
# 136                                                                 NaN
# 137                                                  munakinkan, nagami
# 138                                                             munguba
# 139                                                               murel
# 140                                                            murulauk
# 141                                                      muskaatkõrvits
# 142                                              must sõstar, sitikmari
# 143                                                            must uba
# 144                                                mustikas, mustikmari
# 145                                               muulukamari, muulukas
# 146                                                          mõrumandel
# 147                                                              naeris
# 148                                                           nektariin
# 149                                                      nisu, nisutera
# 150                                                                 NaN
# 151                                                            nurmlauk
# 152                                                      oder, odratera
# 153                                                            odratang
# 154                                                               oliiv
# 155                                                       palukas, pohl
# 156                                                paprika, paprikakaun
# 157                                                        paradiisiõun
# 158                                            patisson, taldrikkõrvits
# 159                                                           peakapsas
# 160                                                        pekaanpähkel
# 161                                                      persik, virsik
# 162                                      pesasibul, šalott, šalottsibul
# 163                                               pihlakamari, pihlakas
# 164                                                            piimjuur
# 165                   piiniaseeme, seedermänni pähkel, seedermänniseeme
# 166                                                                pirn
# 167                                        pistaatsia, pistaatsiapähkel
# 168                                                               ploom
# 169                                                          ploomtomat
# 170                                                       pomel, pomelo
# 171                                                           pomerants
# 172                                        porru, porrulauk, porrusibul
# 173                                        porru, porrulauk, porrusibul
# 174                                                punagreip, verigreip
# 175                                                       punane kapsas
# 176                                                        punane sibul
# 177                                                          punane uba
# 178                                             päevalilleseeme, sihvka
# 179                                                              pähkel
# 180                                           pärlsibul, suvi-porrulauk
# 181                                               põldmari, põldmurakas
# 182                                                            rabarber
# 183                                                   renett, renettõun
# 184                                                            renklood
# 185                                              riivkapsas, särvkapsas
# 186                                                            rohulauk
# 187                                                         rooma salat
# 188                                                               rosin
# 189                                                    rukis, rukkitera
# 190                                                                 NaN
# 191                                                               salat
# 192                                                             satsuma
# 193                                                        seesamiseeme
# 194                                                   sibul, söögisibul
# 195                                                            sibulõun
# 196                                                              sidrun
# 197                                                         sinepiseeme
# 198                                                       soja, sojauba
# 199                                                      spagetikõrvits
# 200                                                              spinat
# 201                                                            suislepp
# 202                                               sultana, sultanarosin
# 203                                                         suvikõrvits
# 204                                                             suviõun
# 205                                                         säilitusõun
# 206                                                            sõrmlaim
# 207                                                  sõstar, sõstramari
# 208                                                                 NaN
# 209                                                            sügisõun
# 210                                                           talisibul
# 211                                                             taliõun
# 212                                                           tamarillo
# 213                                                                tang
# 214                                                           tangeriin
# 215                                                    tatar, tatratera
# 216                              tera, teravili, teris, vili, viljatera
# 217                                                               tomat
# 218                                                           toortatar
# 219                                  tsitrus, tsitruseline, tsitrusvili
# 220                                                             tuviõun
# 221                                                         tõrukõrvits
# 222                                                                 uba
# 223                                                           ubin, õun
# 224                                                              urjukk
# 225                                          vaarikas, vaarmari, vabarn
# 226                                                vaarikpampel, vampel
# 227                                                        valge sõstar
# 228                                                          varsseller
# 229                                                         veriapelsin
# 230                                                     viigimari, viik
# 231                                                           viinamari
# 232                                                               vilis
# 233                                                                viss
# 234                                                          õlikõrvits
#
#            most_popular põhisõnad  palju_küsimusi vikipeedia
# 0         kreeka pähkel      None             1.0          1
# 1                  None      None             1.0       None
# 2          aed-moorputk      None             1.0          1
# 3                  None      None             1.0       None
# 4                  None      None             1.0       None
# 5           aedmaasikas      None             1.0          1
# 6                  None      None             1.0       None
# 7            aedmurakas      None             1.0          1
# 8             aedseller      None             1.0          1
# 9                aeduba      None             1.0          1
# 10              aedvili      None             NaN          1
# 11         india pähkel      None             2.0          1
# 12             avokaado      None             1.0          1
# 13                 None      None             1.0       None
# 14              ananass      None             1.0          1
# 15           antoonovka      None             1.0          1
# 16              apelsin      None             1.0          1
# 17             aprikoos      None             NaN          1
# 18              arahhis      None             1.0          1
# 19               arbuus      None             1.0          1
# 20         beetlipähkel      None             2.0          1
# 21             artišokk      None             1.0          1
# 22                aspar      None             1.0          1
# 23            astelpaju      None             1.0          1
# 24               baamia      None             1.0          1
# 25            baklažaan      None             1.0          1
# 26               banaan      None             1.0          1
# 27                 None      None             1.0       None
# 28               bataat      None             1.0          1
# 29            bergamott      None             1.0          1
# 30     brasiilia pähkel      None             2.0          1
# 31      brüsseli kapsas      None             1.0          1
# 32               bulgur      None             2.0          1
# 33                 None      None             1.0       None
# 34             diospüür      None             1.0          1
# 35                 None      None             1.0       None
# 36               durian      None             1.0          1
# 37              puuvili      None             1.0          1
# 38              granaat      None             1.0          1
# 39            granadill      None             NaN          1
# 40                greip      None             1.0          1
# 41              guajaav      None             1.0          1
# 42            hapukirss      None             NaN          1
# 43             hapukurk      None             1.0          1
# 44               hernes      None             1.0          1
# 45                 None      None             1.0       None
# 46                litši      None             1.0          1
# 47                 None      None             1.0       None
# 48        punane sõstar      None             1.0          1
# 49                 None      None             2.0       None
# 50               papaia      None             1.0          1
# 51                  iva      None             NaN          1
# 52                 None      None             NaN       None
# 53                 None      None             1.0       None
# 54                 None      None             2.0       None
# 55             joovikas      None             1.0          1
# 56             juurikas      None             1.0          1
# 57           juurseller      None             1.0          1
# 58                 None      None             1.0       None
# 59             jõhvikas      None             1.0          1
# 60               kaarel      None             1.0          1
# 61             zucchini      None             1.0          1
# 62           kadakamari      None             1.0          1
# 63                 kaer      None             1.0          1
# 64                 None      None             2.0       None
# 65                 None      None             1.0       None
# 66                 None      None             1.0       None
# 67                 None      None             NaN       None
# 68               kappar      None             NaN          1
# 69             kapsapea      None             1.0          1
# 70           karamboola      None             1.0          1
# 71                 None      None             1.0       None
# 72             karulauk      None             1.0          1
# 73            karusmari      None             1.0          1
# 74             kaunvili      None             1.0          1
# 75                 None      None             1.0       None
# 76                 None      None             1.0       None
# 77                kiivi      None             1.0          1
# 78          kikerhernes      None             1.0          1
# 79                 None      None             1.0       None
# 80                kirss      None             2.0          1
# 81           kirsstomat      None             1.0          1
# 82                 None      None             1.0       None
# 83              luuvili      None             NaN          1
# 84                 None      None             1.0       None
# 85                klaar      None             1.0          1
# 86                 None      None             2.0       None
# 87           klementiin      None             1.0          1
# 88                 klii      None             2.0          1
# 89                 None      None             1.0       None
# 90               kookos      None             2.0          1
# 91               korint      None             2.0          1
# 92                kreek      None             1.0          1
# 93              kruubid      None             2.0          1
# 94                 None      None             NaN       None
# 95           kuldrenett      None             1.0          1
# 96                 kurk      None             1.0          1
# 97              kuskuss      None             1.0          1
# 98                 None      None             2.0       None
# 99              kõrvits      None             1.0          1
# 100                None      None             NaN       None
# 101           köögivili      None             1.0          1
# 102            küdoonia      None             1.0          1
# 103            küüslauk      None             NaN          1
# 104                laim      None             1.0          1
# 105          lamevirsik      None             1.0          1
# 106                lauk      None             1.0          1
# 107                None      None             NaN       None
# 108                None      None             1.0       None
# 109                None      None             1.0       None
# 110                None      None             1.0       None
# 111          lillkapsas      None             1.0          1
# 112         linaseemned      None             NaN          1
# 113               litši      None             1.0          1
# 114                None      None             1.0       None
# 115                None      None             NaN       None
# 116             maapirn      None             1.0          1
# 117            maasikas      None             1.0          1
# 118         mage sõstar      None             1.0          1
# 119                mais      None             1.0          1
# 120                None      None             1.0       None
# 121                None      None             2.0       None
# 122           mandariin      None             1.0          1
# 123              mandel      None             NaN          1
# 124               mango      None             NaN          1
# 125                mari      None             1.0          1
# 126               melon      None             1.0          1
# 127         mesimurakas      None             1.0          1
# 128                None      None             1.0       None
# 129            metslauk      None             1.0          1
# 130        metsmaasikas      None             1.0          1
# 131          metspähkel      None             2.0          1
# 132                None      None             1.0       None
# 133                None      None             NaN       None
# 134                moon      None             NaN          1
# 135               mugul      None             NaN          1
# 136                None      None             NaN       None
# 137                None      None             1.0       None
# 138             munguba      None             1.0          1
# 139               murel      None             NaN          1
# 140            murulauk      None             1.0          1
# 141                None      None             1.0       None
# 142         must sõstar      None             1.0          1
# 143                None      None             1.0       None
# 144            mustikas      None             1.0          1
# 145            muulukas      None             1.0          1
# 146                None      None             NaN       None
# 147              naeris      None             1.0          1
# 148           nektariin      None             1.0          1
# 149                nisu      None             2.0          1
# 150                None      None             2.0       None
# 151            nurmlauk      None             1.0          1
# 152                oder      None             NaN          1
# 153                None      None             1.0       None
# 154               oliiv      None             NaN          1
# 155             palukas      None             1.0          1
# 156             paprika      None             1.0          1
# 157                None      None             1.0       None
# 158                None      None             1.0       None
# 159           peakapsas      None             1.0          1
# 160                None      None             2.0       None
# 161              persik      None             1.0          1
# 162                None      None             1.0       None
# 163            pihlakas      None             1.0          1
# 164            piimjuur      None             1.0          1
# 165  seedermänni pähkel      None             NaN          1
# 166                pirn      None             1.0          1
# 167          pistaatsia      None             1.0          1
# 168               ploom      None             1.0          1
# 169                None      None             1.0       None
# 170               pomel      None             1.0          1
# 171           pomerants      None             1.0          1
# 172           porrulauk      None             1.0          1
# 173           porrulauk      None             1.0          1
# 174                None      None             1.0       None
# 175                None      None             1.0       None
# 176        punane sibul      None             1.0          1
# 177                None      None             1.0       None
# 178                None      None             NaN       None
# 179              pähkel      None             2.0          1
# 180                None      None             1.0       None
# 181            põldmari      None             1.0          1
# 182            rabarber      None             1.0          1
# 183                None      None             1.0       None
# 184                None      None             1.0       None
# 185                None      None             1.0       None
# 186            rohulauk      None             1.0          1
# 187         rooma salat      None             1.0          1
# 188               rosin      None             2.0          1
# 189               rukis      None             NaN          1
# 190                None      None             2.0       None
# 191               salat      None             1.0          1
# 192                None      None             1.0       None
# 193        seesamiseeme      None             NaN          1
# 194               sibul      None             1.0          1
# 195                None      None             1.0       None
# 196              sidrun      None             1.0          1
# 197                None      None             NaN       None
# 198                soja      None             1.0          1
# 199                None      None             1.0       None
# 200              spinat      None             1.0          1
# 201            suislepp      None             1.0          1
# 202             sultana      None             2.0          1
# 203         suvikõrvits      None             1.0          1
# 204                None      None             1.0       None
# 205                None      None             1.0       None
# 206                None      None             1.0       None
# 207              sõstar      None             1.0          1
# 208                None      None             NaN       None
# 209                None      None             1.0       None
# 210           talisibul      None             1.0          1
# 211                None      None             1.0       None
# 212                None      None             1.0       None
# 213                tang      None             1.0          1
# 214           tangeriin      None             1.0          1
# 215               tatar      None             1.0          1
# 216                tera      None             2.0          1
# 217               tomat      None             1.0          1
# 218                None      None             1.0       None
# 219             tsitrus      None             1.0          1
# 220                None      None             1.0       None
# 221                None      None             1.0       None
# 222                 uba      None             1.0          1
# 223                ubin      None             1.0          1
# 224                None      None             NaN       None
# 225            vaarikas      None             1.0          1
# 226        vaarikpampel      None             1.0          1
# 227                None      None             1.0       None
# 228                None      None             1.0       None
# 229                None      None             1.0       None
# 230           viigimari      None             1.0          1
# 231           viinamari      None             1.0          1
# 232                None      None             2.0       None
# 233                None      None             1.0       None
# 234                None      None             1.0       None

# %% [markdown]
# # 3. Populaarsemate sõnade analüüs

# %%
with open('marksonad.txt', 'r') as f:
     lines = [line.strip() for line in f]
põhisõnavara = lines

# %%
important_words = set()
for põhisõna in põhisõnavara:
  for sõna in list_of_all_suitable_vegetables:
    for i in range(len(sõna)):
      if põhisõna.lower() == sõna[i].lower():
        important_words.add(sõna[i])

print(important_words)
# Out:
# {'kapsas', 'tera', 'hernes', 'nisu', 'köögivili', 'ploom', 'hapukurk', 'puuvili', 'vili', 'viinamari', 'õun', 'kirss', 'lillkapsas', 'kaer', 'mandariin', 'ananass', 'kõrvits', 'teravili', 'karusmari', 'banaan', 'pirn', 'kurk', 'maasikas', 'mustikas', 'tatar', 'virsik', 'uba', 'arbuus', 'juurvili', 'rukis', 'apelsin', 'pähkel', 'salat', 'sidrun', 'paprika', 'oder', 'tomat', 'jõhvikas', 'vaarikas', 'mari', 'aedvili', 'seeme', 'küüslauk', 'viik', 'sibul'}

# %%
df_kontroll['põhisõnad'] = df_kontroll['Sõna'].apply(lambda sõna: 1 if any(põhisõna.lower() == sõna.lower() for põhisõna in põhisõnavara) else None)

# %%
print(df_kontroll.columns)
# Out:
# Index(['Sõna', 'Synonyms', 'most_popular', 'põhisõnad', 'palju_küsimusi',
#        'vikipeedia'],
#       dtype='object')

# %%
# Põhisõnade kontroll sünonüümide kaudu
def check_main_word(row, põhisõnavara):
    sõna = row["Sõna"]
    synonyms = row["Synonyms"]

    # Kontrollime, kas looma nimi on põhisõnavaras
    if sõna.lower() in põhisõnavara:
        df_kontroll.loc[df_kontroll["Sõna"] == sõna, "most_popular"] = sõna.lower()
        return 1

    # Kontrollime sünonüüme, kui need on olemas
    if pd.notna(synonyms):
        synonym_list = synonyms.split(", ")
        for synonym in synonym_list:
            if synonym.lower() in põhisõnavara:
                df_kontroll.loc[df_kontroll["Sõna"] == sõna, "most_popular"] = synonym.lower()
                return 1

    return None

# Rakendame kontrolli
df_kontroll["põhisõnad"] = df_kontroll.apply(
    lambda row: check_main_word(row, põhisõnavara), axis=1
)

# %%
len(important_words)
# Out:
# 45

# %%
df_kontroll
# Out:
#                        Sõna  \
# 0             Kreeka pähkel
# 1                    adzuki
# 2              aed-moorputk
# 3              aed-piimjuur
# 4                 aedhernes
# 5               aedmaasikas
# 6                   aedmari
# 7                aedmurakas
# 8                 aedseller
# 9                    aeduba
# 10                  aedvili
# 11             akazuupähkel
# 12           alligaatorpirn
# 13             alrauni mari
# 14                  ananass
# 15               antoonovka
# 16                  apelsin
# 17                 aprikoos
# 18                  arahhis
# 19                   arbuus
# 20             areekapähkel
# 21                 artišokk
# 22                    aspar
# 23                astelpaju
# 24                   baamia
# 25                baklažaan
# 26                   banaan
# 27            banaankõrvits
# 28                   bataat
# 29                bergamott
# 30         brasiilia pähkel
# 31          brüsseli kapsas
# 32                   bulgur
# 33               dessertõun
# 34                 diospüür
# 35             draakonivili
# 36                   durian
# 37                    frukt
# 38                  granaat
# 39                granadill
# 40                    greip
# 41                  guajaav
# 42                hapukirss
# 43                 hapukurk
# 44                   hernes
# 45               hiina alss
# 46              hiina ploom
# 47                hirsitang
# 48                hõrakmari
# 49            indiaani riis
# 50             inglite vili
# 51                      iva
# 52                jaanikaun
# 53               jahubanaan
# 54                 jahvatis
# 55                 joovikas
# 56                 juurikas
# 57               juurseller
# 58                 jääsalat
# 59                 jõhvikas
# 60                   kaarel
# 61                kabatšokk
# 62               kadakamari
# 63                     kaer
# 64                kaeraklii
# 65               kahvrilaim
# 66               kaktusvili
# 67              kanepiseeme
# 68                   kappar
# 69                 kapsapea
# 70               karamboola
# 71                  karella
# 72                 karulauk
# 73                karusmari
# 74                 kaunvili
# 75   keerdkaelaline kõrvits
# 76                 kerimoia
# 77                    kiivi
# 78              kikerhernes
# 79                   kinkan
# 80                    kirss
# 81               kirsstomat
# 82                  kivaano
# 83                 kivivili
# 84                  kišmišš
# 85                    klaar
# 86               klaaskirss
# 87               klementiin
# 88                     klii
# 89                 kokosell
# 90                   kookos
# 91                   korint
# 92                    kreek
# 93                    kruup
# 94          kuivatatud vili
# 95               kuldrenett
# 96                     kurk
# 97                  kuskuss
# 98                 kõlutera
# 99                  kõrvits
# 100           kõrvitsaseeme
# 101               köögivili
# 102                küdoonia
# 103                küüslauk
# 104                    laim
# 105              lamevirsik
# 106                    lauk
# 107             lehtaedvili
# 108              lehtseller
# 109               lihatomat
# 110                liimauba
# 111              lillkapsas
# 112               linaseeme
# 113                   litši
# 114                  longan
# 115            loorberimari
# 116                 maapirn
# 117                maasikas
# 118             mage sõstar
# 119                    mais
# 120               maisitang
# 121              makadaamia
# 122               mandariin
# 123                  mandel
# 124                   mango
# 125                    mari
# 126                   melon
# 127             mesimurakas
# 128               metsamari
# 129                metslauk
# 130            metsmaasikas
# 131              metspähkel
# 132                 metsõun
# 133                mirabell
# 134                    moon
# 135                   mugul
# 136               mugulvili
# 137              munakinkan
# 138                 munguba
# 139                   murel
# 140                murulauk
# 141          muskaatkõrvits
# 142             must sõstar
# 143                must uba
# 144                mustikas
# 145             muulukamari
# 146              mõrumandel
# 147                  naeris
# 148               nektariin
# 149                    nisu
# 150                nisuklii
# 151                nurmlauk
# 152                    oder
# 153                odratang
# 154                   oliiv
# 155                 palukas
# 156                 paprika
# 157            paradiisiõun
# 158                patisson
# 159               peakapsas
# 160            pekaanpähkel
# 161                  persik
# 162               pesasibul
# 163             pihlakamari
# 164                piimjuur
# 165             piiniaseeme
# 166                    pirn
# 167              pistaatsia
# 168                   ploom
# 169              ploomtomat
# 170                   pomel
# 171               pomerants
# 172                   porru
# 173               porrulauk
# 174               punagreip
# 175           punane kapsas
# 176            punane sibul
# 177              punane uba
# 178         päevalilleseeme
# 179                  pähkel
# 180               pärlsibul
# 181                põldmari
# 182                rabarber
# 183                  renett
# 184                renklood
# 185              riivkapsas
# 186                rohulauk
# 187             rooma salat
# 188                   rosin
# 189                   rukis
# 190               rukkiklii
# 191                   salat
# 192                 satsuma
# 193            seesamiseeme
# 194                   sibul
# 195                sibulõun
# 196                  sidrun
# 197             sinepiseeme
# 198                    soja
# 199          spagetikõrvits
# 200                  spinat
# 201                suislepp
# 202                 sultana
# 203             suvikõrvits
# 204                 suviõun
# 205             säilitusõun
# 206                sõrmlaim
# 207                  sõstar
# 208             söödav vili
# 209                sügisõun
# 210               talisibul
# 211                 taliõun
# 212               tamarillo
# 213                    tang
# 214               tangeriin
# 215                   tatar
# 216                    tera
# 217                   tomat
# 218               toortatar
# 219                 tsitrus
# 220                 tuviõun
# 221             tõrukõrvits
# 222                     uba
# 223                    ubin
# 224                  urjukk
# 225                vaarikas
# 226            vaarikpampel
# 227            valge sõstar
# 228              varsseller
# 229             veriapelsin
# 230               viigimari
# 231               viinamari
# 232                   vilis
# 233                    viss
# 234              õlikõrvits
#
#                                                                Synonyms  \
# 0                                          Kreeka pähkel, kreeka pähkel
# 1                                                      adzuki, asukiuba
# 2                                               aed-moorputk, pastinaak
# 3                                                          aed-piimjuur
# 4                                                             aedhernes
# 5                                                           aedmaasikas
# 6                                                      aedmari, aiamari
# 7                                                    aedmurakas, pampel
# 8                                                     aedseller, seller
# 9                                                     aeduba, Türgi uba
# 10                                                              aedvili
# 11   akazuupähkel, India pähkel, india pähkel, kašupähkel, nakar, nakra
# 12                                             alligaatorpirn, avokaado
# 13                                alrauni mari, lemmemari, tuudaimimari
# 14                                                              ananass
# 15                                                           antoonovka
# 16                                                              apelsin
# 17                                                             aprikoos
# 18                                     arahhis, hiina pähkel, maapähkel
# 19                                                               arbuus
# 20                                           areekapähkel, beetlipähkel
# 21                                                             artišokk
# 22                                                       aspar, spargel
# 23                                             astelpaju, astelpajumari
# 24                                                         baamia, okra
# 25                                                     baklažaan, pommu
# 26                                                               banaan
# 27                                                        banaankõrvits
# 28                                    bataat, maguskartul, magus kartul
# 29                                                            bergamott
# 30                                         brasiilia pähkel, parapähkel
# 31                                          brüsseli kapsas, rooskapsas
# 32                                                               bulgur
# 33                                                  dessertõun, lauaõun
# 34                                    diospüür, hurmaa, kaki, kakiploom
# 35                                                 draakonivili, pitaia
# 36                                                               durian
# 37                                                       frukt, puuvili
# 38                                                  granaat, granaatõun
# 39                                                                  NaN
# 40                                            greip, greipfruut, kreebu
# 41                                                              guajaav
# 42                                                            hapukirss
# 43                                                             hapukurk
# 44                                                               hernes
# 45                                               hiina alss, vesikastan
# 46                                             hiina ploom, litš, litši
# 47                                                 hirsitang, hirsitera
# 48                                             hõrakmari, punane sõstar
# 49            indiaani riis, metsik riis, Tuskaroora vesiriis, vesiriis
# 50                                                 inglite vili, papaia
# 51                                                           iva, seeme
# 52                                                                  NaN
# 53                                                           jahubanaan
# 54                                                             jahvatis
# 55                                                    joovikas, sinikas
# 56                                                                  NaN
# 57                                                           juurseller
# 58                                                             jääsalat
# 59                                                   jõhvikas, kuremari
# 60                                         kaarel, karumurakas, murakas
# 61                           kabatšokk, rullkõrvits, zucchini, tsukiini
# 62                                                           kadakamari
# 63                                                      kaer, kaeratera
# 64                                                                  NaN
# 65                                                 kahvrilaim, kombaava
# 66                                                           kaktusvili
# 67                                                                  NaN
# 68                                                                  NaN
# 69                                                     kapsapea, kapsas
# 70                                                 karamboola, tähtvili
# 71                                                    karella, kibekurk
# 72                                                             karulauk
# 73                                          karusmari, tikerber, tikker
# 74                                                             kaunvili
# 75                                 keerdkaelaline kõrvits, käändkõrvits
# 76                                                  kerimoia, suhkruõun
# 77                                                                kiivi
# 78                                        kikerhernes, nuut, põishernes
# 79                                      kinkan, kumkvaat, kääbusapelsin
# 80                                                        kirss, käsper
# 81                                                           kirsstomat
# 82                                                    kivaano, ogamelon
# 83                                                    kivivili, luuvili
# 84                                                              kišmišš
# 85                                         klaar, klaarõun, valge klaar
# 86                                                           klaaskirss
# 87                                                           klementiin
# 88                                                          klii, kliid
# 89                                               kokosell, pikk kõrvits
# 90                                                 kookos, kookospähkel
# 91                                                               korint
# 92                                                                kreek
# 93                                         kruubid, kruubitangud, kruup
# 94                                                      kuivatatud vili
# 95                                                           kuldrenett
# 96                                                                 kurk
# 97                                                              kuskuss
# 98                                                             kõlutera
# 99                                                              kõrvits
# 100                                                       kõrvitsaseeme
# 101                                                           köögivili
# 102                                                            küdoonia
# 103                                                     küüslauk, noblu
# 104                                                                laim
# 105                                                          lamevirsik
# 106                                                                lauk
# 107                                          lehtaedvili, lehtköögivili
# 108                                                          lehtseller
# 109                                                           lihatomat
# 110                                                            liimauba
# 111                                                          lillkapsas
# 112                                              linaseeme, linaseemned
# 113                                            litši, pulasan, rambutan
# 114                                                              longan
# 115                                                        loorberimari
# 116                                 maapirn, mugulpäevalill, topinambur
# 117                                                maasikas, maasikmari
# 118                                                         mage sõstar
# 119                                                     mais, maisitera
# 120                                                           maisitang
# 121                                        makadaamia, makadaamiapähkel
# 122                                                           mandariin
# 123                                                                 NaN
# 124                                                   mango, mangoploom
# 125                                                                mari
# 126                                                               melon
# 127                                             mesimurakas, soomurakas
# 128                                                 metsamari, metsmari
# 129                                                            metslauk
# 130                                                        metsmaasikas
# 131                                           metspähkel, sarapuupähkel
# 132                                                             metsõun
# 133                                                            mirabell
# 134                                                    moon, mooniseeme
# 135                                                                 NaN
# 136                                                                 NaN
# 137                                                  munakinkan, nagami
# 138                                                             munguba
# 139                                                               murel
# 140                                                            murulauk
# 141                                                      muskaatkõrvits
# 142                                              must sõstar, sitikmari
# 143                                                            must uba
# 144                                                mustikas, mustikmari
# 145                                               muulukamari, muulukas
# 146                                                          mõrumandel
# 147                                                              naeris
# 148                                                           nektariin
# 149                                                      nisu, nisutera
# 150                                                                 NaN
# 151                                                            nurmlauk
# 152                                                      oder, odratera
# 153                                                            odratang
# 154                                                               oliiv
# 155                                                       palukas, pohl
# 156                                                paprika, paprikakaun
# 157                                                        paradiisiõun
# 158                                            patisson, taldrikkõrvits
# 159                                                           peakapsas
# 160                                                        pekaanpähkel
# 161                                                      persik, virsik
# 162                                      pesasibul, šalott, šalottsibul
# 163                                               pihlakamari, pihlakas
# 164                                                            piimjuur
# 165                   piiniaseeme, seedermänni pähkel, seedermänniseeme
# 166                                                                pirn
# 167                                        pistaatsia, pistaatsiapähkel
# 168                                                               ploom
# 169                                                          ploomtomat
# 170                                                       pomel, pomelo
# 171                                                           pomerants
# 172                                        porru, porrulauk, porrusibul
# 173                                        porru, porrulauk, porrusibul
# 174                                                punagreip, verigreip
# 175                                                       punane kapsas
# 176                                                        punane sibul
# 177                                                          punane uba
# 178                                             päevalilleseeme, sihvka
# 179                                                              pähkel
# 180                                           pärlsibul, suvi-porrulauk
# 181                                               põldmari, põldmurakas
# 182                                                            rabarber
# 183                                                   renett, renettõun
# 184                                                            renklood
# 185                                              riivkapsas, särvkapsas
# 186                                                            rohulauk
# 187                                                         rooma salat
# 188                                                               rosin
# 189                                                    rukis, rukkitera
# 190                                                                 NaN
# 191                                                               salat
# 192                                                             satsuma
# 193                                                        seesamiseeme
# 194                                                   sibul, söögisibul
# 195                                                            sibulõun
# 196                                                              sidrun
# 197                                                         sinepiseeme
# 198                                                       soja, sojauba
# 199                                                      spagetikõrvits
# 200                                                              spinat
# 201                                                            suislepp
# 202                                               sultana, sultanarosin
# 203                                                         suvikõrvits
# 204                                                             suviõun
# 205                                                         säilitusõun
# 206                                                            sõrmlaim
# 207                                                  sõstar, sõstramari
# 208                                                                 NaN
# 209                                                            sügisõun
# 210                                                           talisibul
# 211                                                             taliõun
# 212                                                           tamarillo
# 213                                                                tang
# 214                                                           tangeriin
# 215                                                    tatar, tatratera
# 216                              tera, teravili, teris, vili, viljatera
# 217                                                               tomat
# 218                                                           toortatar
# 219                                  tsitrus, tsitruseline, tsitrusvili
# 220                                                             tuviõun
# 221                                                         tõrukõrvits
# 222                                                                 uba
# 223                                                           ubin, õun
# 224                                                              urjukk
# 225                                          vaarikas, vaarmari, vabarn
# 226                                                vaarikpampel, vampel
# 227                                                        valge sõstar
# 228                                                          varsseller
# 229                                                         veriapelsin
# 230                                                     viigimari, viik
# 231                                                           viinamari
# 232                                                               vilis
# 233                                                                viss
# 234                                                          õlikõrvits
#
#            most_popular  põhisõnad  palju_küsimusi vikipeedia
# 0         kreeka pähkel        NaN             1.0          1
# 1                  None        NaN             1.0       None
# 2          aed-moorputk        NaN             1.0          1
# 3                  None        NaN             1.0       None
# 4                  None        NaN             1.0       None
# 5           aedmaasikas        NaN             1.0          1
# 6                  None        NaN             1.0       None
# 7            aedmurakas        NaN             1.0          1
# 8             aedseller        NaN             1.0          1
# 9                aeduba        NaN             1.0          1
# 10              aedvili        1.0             NaN          1
# 11         india pähkel        NaN             2.0          1
# 12             avokaado        NaN             1.0          1
# 13                 None        NaN             1.0       None
# 14              ananass        1.0             1.0          1
# 15           antoonovka        NaN             1.0          1
# 16              apelsin        1.0             1.0          1
# 17             aprikoos        NaN             NaN          1
# 18              arahhis        NaN             1.0          1
# 19               arbuus        1.0             1.0          1
# 20         beetlipähkel        NaN             2.0          1
# 21             artišokk        NaN             1.0          1
# 22                aspar        NaN             1.0          1
# 23            astelpaju        NaN             1.0          1
# 24               baamia        NaN             1.0          1
# 25            baklažaan        NaN             1.0          1
# 26               banaan        1.0             1.0          1
# 27                 None        NaN             1.0       None
# 28               bataat        NaN             1.0          1
# 29            bergamott        NaN             1.0          1
# 30     brasiilia pähkel        NaN             2.0          1
# 31      brüsseli kapsas        NaN             1.0          1
# 32               bulgur        NaN             2.0          1
# 33                 None        NaN             1.0       None
# 34             diospüür        NaN             1.0          1
# 35                 None        NaN             1.0       None
# 36               durian        NaN             1.0          1
# 37              puuvili        1.0             1.0          1
# 38              granaat        NaN             1.0          1
# 39            granadill        NaN             NaN          1
# 40                greip        NaN             1.0          1
# 41              guajaav        NaN             1.0          1
# 42            hapukirss        NaN             NaN          1
# 43             hapukurk        1.0             1.0          1
# 44               hernes        1.0             1.0          1
# 45                 None        NaN             1.0       None
# 46                litši        NaN             1.0          1
# 47                 None        NaN             1.0       None
# 48        punane sõstar        NaN             1.0          1
# 49                 None        NaN             2.0       None
# 50               papaia        NaN             1.0          1
# 51                seeme        1.0             NaN          1
# 52                 None        NaN             NaN       None
# 53                 None        NaN             1.0       None
# 54                 None        NaN             2.0       None
# 55             joovikas        NaN             1.0          1
# 56             juurikas        NaN             1.0          1
# 57           juurseller        NaN             1.0          1
# 58                 None        NaN             1.0       None
# 59             jõhvikas        1.0             1.0          1
# 60               kaarel        NaN             1.0          1
# 61             zucchini        NaN             1.0          1
# 62           kadakamari        NaN             1.0          1
# 63                 kaer        1.0             1.0          1
# 64                 None        NaN             2.0       None
# 65                 None        NaN             1.0       None
# 66                 None        NaN             1.0       None
# 67                 None        NaN             NaN       None
# 68               kappar        NaN             NaN          1
# 69               kapsas        1.0             1.0          1
# 70           karamboola        NaN             1.0          1
# 71                 None        NaN             1.0       None
# 72             karulauk        NaN             1.0          1
# 73            karusmari        1.0             1.0          1
# 74             kaunvili        NaN             1.0          1
# 75                 None        NaN             1.0       None
# 76                 None        NaN             1.0       None
# 77                kiivi        NaN             1.0          1
# 78          kikerhernes        NaN             1.0          1
# 79                 None        NaN             1.0       None
# 80                kirss        1.0             2.0          1
# 81           kirsstomat        NaN             1.0          1
# 82                 None        NaN             1.0       None
# 83              luuvili        NaN             NaN          1
# 84                 None        NaN             1.0       None
# 85                klaar        NaN             1.0          1
# 86                 None        NaN             2.0       None
# 87           klementiin        NaN             1.0          1
# 88                 klii        NaN             2.0          1
# 89                 None        NaN             1.0       None
# 90               kookos        NaN             2.0          1
# 91               korint        NaN             2.0          1
# 92                kreek        NaN             1.0          1
# 93              kruubid        NaN             2.0          1
# 94                 None        NaN             NaN       None
# 95           kuldrenett        NaN             1.0          1
# 96                 kurk        1.0             1.0          1
# 97              kuskuss        NaN             1.0          1
# 98                 None        NaN             2.0       None
# 99              kõrvits        1.0             1.0          1
# 100                None        NaN             NaN       None
# 101           köögivili        1.0             1.0          1
# 102            küdoonia        NaN             1.0          1
# 103            küüslauk        1.0             NaN          1
# 104                laim        NaN             1.0          1
# 105          lamevirsik        NaN             1.0          1
# 106                lauk        NaN             1.0          1
# 107                None        NaN             NaN       None
# 108                None        NaN             1.0       None
# 109                None        NaN             1.0       None
# 110                None        NaN             1.0       None
# 111          lillkapsas        1.0             1.0          1
# 112         linaseemned        NaN             NaN          1
# 113               litši        NaN             1.0          1
# 114                None        NaN             1.0       None
# 115                None        NaN             NaN       None
# 116             maapirn        NaN             1.0          1
# 117            maasikas        1.0             1.0          1
# 118         mage sõstar        NaN             1.0          1
# 119                mais        NaN             1.0          1
# 120                None        NaN             1.0       None
# 121                None        NaN             2.0       None
# 122           mandariin        1.0             1.0          1
# 123              mandel        NaN             NaN          1
# 124               mango        NaN             NaN          1
# 125                mari        1.0             1.0          1
# 126               melon        NaN             1.0          1
# 127         mesimurakas        NaN             1.0          1
# 128                None        NaN             1.0       None
# 129            metslauk        NaN             1.0          1
# 130        metsmaasikas        NaN             1.0          1
# 131          metspähkel        NaN             2.0          1
# 132                None        NaN             1.0       None
# 133                None        NaN             NaN       None
# 134                moon        NaN             NaN          1
# 135               mugul        NaN             NaN          1
# 136                None        NaN             NaN       None
# 137                None        NaN             1.0       None
# 138             munguba        NaN             1.0          1
# 139               murel        NaN             NaN          1
# 140            murulauk        NaN             1.0          1
# 141                None        NaN             1.0       None
# 142         must sõstar        NaN             1.0          1
# 143                None        NaN             1.0       None
# 144            mustikas        1.0             1.0          1
# 145            muulukas        NaN             1.0          1
# 146                None        NaN             NaN       None
# 147              naeris        NaN             1.0          1
# 148           nektariin        NaN             1.0          1
# 149                nisu        1.0             2.0          1
# 150                None        NaN             2.0       None
# 151            nurmlauk        NaN             1.0          1
# 152                oder        1.0             NaN          1
# 153                None        NaN             1.0       None
# 154               oliiv        NaN             NaN          1
# 155             palukas        NaN             1.0          1
# 156             paprika        1.0             1.0          1
# 157                None        NaN             1.0       None
# 158                None        NaN             1.0       None
# 159           peakapsas        NaN             1.0          1
# 160                None        NaN             2.0       None
# 161              virsik        1.0             1.0          1
# 162                None        NaN             1.0       None
# 163            pihlakas        NaN             1.0          1
# 164            piimjuur        NaN             1.0          1
# 165  seedermänni pähkel        NaN             NaN          1
# 166                pirn        1.0             1.0          1
# 167          pistaatsia        NaN             1.0          1
# 168               ploom        1.0             1.0          1
# 169                None        NaN             1.0       None
# 170               pomel        NaN             1.0          1
# 171           pomerants        NaN             1.0          1
# 172           porrulauk        NaN             1.0          1
# 173           porrulauk        NaN             1.0          1
# 174                None        NaN             1.0       None
# 175                None        NaN             1.0       None
# 176        punane sibul        NaN             1.0          1
# 177                None        NaN             1.0       None
# 178                None        NaN             NaN       None
# 179              pähkel        1.0             2.0          1
# 180                None        NaN             1.0       None
# 181            põldmari        NaN             1.0          1
# 182            rabarber        NaN             1.0          1
# 183                None        NaN             1.0       None
# 184                None        NaN             1.0       None
# 185                None        NaN             1.0       None
# 186            rohulauk        NaN             1.0          1
# 187         rooma salat        NaN             1.0          1
# 188               rosin        NaN             2.0          1
# 189               rukis        1.0             NaN          1
# 190                None        NaN             2.0       None
# 191               salat        1.0             1.0          1
# 192                None        NaN             1.0       None
# 193        seesamiseeme        NaN             NaN          1
# 194               sibul        1.0             1.0          1
# 195                None        NaN             1.0       None
# 196              sidrun        1.0             1.0          1
# 197                None        NaN             NaN       None
# 198                soja        NaN             1.0          1
# 199                None        NaN             1.0       None
# 200              spinat        NaN             1.0          1
# 201            suislepp        NaN             1.0          1
# 202             sultana        NaN             2.0          1
# 203         suvikõrvits        NaN             1.0          1
# 204                None        NaN             1.0       None
# 205                None        NaN             1.0       None
# 206                None        NaN             1.0       None
# 207              sõstar        NaN             1.0          1
# 208                None        NaN             NaN       None
# 209                None        NaN             1.0       None
# 210           talisibul        NaN             1.0          1
# 211                None        NaN             1.0       None
# 212                None        NaN             1.0       None
# 213                tang        NaN             1.0          1
# 214           tangeriin        NaN             1.0          1
# 215               tatar        1.0             1.0          1
# 216                tera        1.0             2.0          1
# 217               tomat        1.0             1.0          1
# 218                None        NaN             1.0       None
# 219             tsitrus        NaN             1.0          1
# 220                None        NaN             1.0       None
# 221                None        NaN             1.0       None
# 222                 uba        1.0             1.0          1
# 223                 õun        1.0             1.0          1
# 224                None        NaN             NaN       None
# 225            vaarikas        1.0             1.0          1
# 226        vaarikpampel        NaN             1.0          1
# 227                None        NaN             1.0       None
# 228                None        NaN             1.0       None
# 229                None        NaN             1.0       None
# 230                viik        1.0             1.0          1
# 231           viinamari        1.0             1.0          1
# 232                None        NaN             2.0       None
# 233                None        NaN             1.0       None
# 234                None        NaN             1.0       None

# %%
df_kontroll.to_csv('sõnade_kontroll_taimed2.csv', index=False)

# %% [markdown]
# # sobivate sõnade valimine

# %%
df_sõnad = pd.read_csv("sõnade_kontroll_taimed2.csv")

# %%
# sõnad mida me tahame kindlasti
df_sõnad_kindlasti = df_sõnad[
    (df_sõnad["põhisõnad"] == 1) |
    ((df_sõnad["vikipeedia"] == 1) & (df_sõnad["palju_küsimusi"] == 1))
]

# %%
df_sõnad_kindlasti.shape
# Out:
# (127, 6)

# %%
df_sõnad[df_sõnad["Loom"].isin([
    "angerjas", "imetaja", "jaaguar", "jõesilm", "kiisk",
    "merikilpkonn", "nastik", "puuma", "rohekilpkonn",
    "salamander", "sipelgakaru", "sisalik", "särg", "tindikala"
])] # neid sõnu tahan ka
# Out:
#               Loom  põhisõnad  palju_küsimusi  vikipeedia
# 51        angerjas        NaN             NaN         1.0
# 369        imetaja        NaN             NaN         1.0
# 396        jaaguar        NaN             NaN         1.0
# 430        jõesilm        NaN             NaN         1.0
# 533          kiisk        NaN             NaN         1.0
# 819   merikilpkonn        NaN             NaN         NaN
# 929         nastik        NaN             NaN         1.0
# 1112         puuma        NaN             NaN         1.0
# 1174  rohekilpkonn        NaN             NaN         NaN
# 1224    salamander        NaN             NaN         NaN
# 1268   sipelgakaru        NaN             NaN         NaN
# 1272       sisalik        NaN             NaN         1.0
# 1332          särg        NaN             NaN         1.0
# 1383     tindikala        NaN             NaN         1.0

# %%
# kõik väärtused on olematud
df_sõnad[
    (df_sõnad["põhisõnad"] != 1) &
    ((df_sõnad["vikipeedia"] != 1) & (df_sõnad["palju_küsimusi"] != 1) & (df_sõnad["palju_küsimusi"] != 2))
]
# Out:
#                 Sõna                    Synonyms most_popular  põhisõnad  \
# 52         jaanikaun                         NaN          NaN        NaN
# 67       kanepiseeme                         NaN          NaN        NaN
# 94   kuivatatud vili             kuivatatud vili          NaN        NaN
# 100    kõrvitsaseeme               kõrvitsaseeme          NaN        NaN
# 107      lehtaedvili  lehtaedvili, lehtköögivili          NaN        NaN
# 115     loorberimari                loorberimari          NaN        NaN
# 133         mirabell                    mirabell          NaN        NaN
# 136        mugulvili                         NaN          NaN        NaN
# 146       mõrumandel                  mõrumandel          NaN        NaN
# 178  päevalilleseeme     päevalilleseeme, sihvka          NaN        NaN
# 197      sinepiseeme                 sinepiseeme          NaN        NaN
# 208      söödav vili                         NaN          NaN        NaN
# 224           urjukk                      urjukk          NaN        NaN
#
#      palju_küsimusi  vikipeedia
# 52              NaN         NaN
# 67              NaN         NaN
# 94              NaN         NaN
# 100             NaN         NaN
# 107             NaN         NaN
# 115             NaN         NaN
# 133             NaN         NaN
# 136             NaN         NaN
# 146             NaN         NaN
# 178             NaN         NaN
# 197             NaN         NaN
# 208             NaN         NaN
# 224             NaN         NaN

# %%
df_sõnad[
    (df_sõnad["põhisõnad"] != 1) |
    ((df_sõnad["vikipeedia"] != 1) | (df_sõnad["palju_küsimusi"] != 1) | (df_sõnad["palju_küsimusi"] != 2))
]# teeme eraldi veeru, kus on sõna tähtsus. Kui sõna põhisõna ss 1, 2 kohas (vikis ja palju_küsimusi) ss 2 ainult palju küsimusi ss 3 jne
# Out:
#                        Sõna  \
# 0             Kreeka pähkel
# 1                    adzuki
# 2              aed-moorputk
# 3              aed-piimjuur
# 4                 aedhernes
# 5               aedmaasikas
# 6                   aedmari
# 7                aedmurakas
# 8                 aedseller
# 9                    aeduba
# 10                  aedvili
# 11             akazuupähkel
# 12           alligaatorpirn
# 13             alrauni mari
# 14                  ananass
# 15               antoonovka
# 16                  apelsin
# 17                 aprikoos
# 18                  arahhis
# 19                   arbuus
# 20             areekapähkel
# 21                 artišokk
# 22                    aspar
# 23                astelpaju
# 24                   baamia
# 25                baklažaan
# 26                   banaan
# 27            banaankõrvits
# 28                   bataat
# 29                bergamott
# 30         brasiilia pähkel
# 31          brüsseli kapsas
# 32                   bulgur
# 33               dessertõun
# 34                 diospüür
# 35             draakonivili
# 36                   durian
# 37                    frukt
# 38                  granaat
# 39                granadill
# 40                    greip
# 41                  guajaav
# 42                hapukirss
# 43                 hapukurk
# 44                   hernes
# 45               hiina alss
# 46              hiina ploom
# 47                hirsitang
# 48                hõrakmari
# 49            indiaani riis
# 50             inglite vili
# 51                      iva
# 52                jaanikaun
# 53               jahubanaan
# 54                 jahvatis
# 55                 joovikas
# 56                 juurikas
# 57               juurseller
# 58                 jääsalat
# 59                 jõhvikas
# 60                   kaarel
# 61                kabatšokk
# 62               kadakamari
# 63                     kaer
# 64                kaeraklii
# 65               kahvrilaim
# 66               kaktusvili
# 67              kanepiseeme
# 68                   kappar
# 69                 kapsapea
# 70               karamboola
# 71                  karella
# 72                 karulauk
# 73                karusmari
# 74                 kaunvili
# 75   keerdkaelaline kõrvits
# 76                 kerimoia
# 77                    kiivi
# 78              kikerhernes
# 79                   kinkan
# 80                    kirss
# 81               kirsstomat
# 82                  kivaano
# 83                 kivivili
# 84                  kišmišš
# 85                    klaar
# 86               klaaskirss
# 87               klementiin
# 88                     klii
# 89                 kokosell
# 90                   kookos
# 91                   korint
# 92                    kreek
# 93                    kruup
# 94          kuivatatud vili
# 95               kuldrenett
# 96                     kurk
# 97                  kuskuss
# 98                 kõlutera
# 99                  kõrvits
# 100           kõrvitsaseeme
# 101               köögivili
# 102                küdoonia
# 103                küüslauk
# 104                    laim
# 105              lamevirsik
# 106                    lauk
# 107             lehtaedvili
# 108              lehtseller
# 109               lihatomat
# 110                liimauba
# 111              lillkapsas
# 112               linaseeme
# 113                   litši
# 114                  longan
# 115            loorberimari
# 116                 maapirn
# 117                maasikas
# 118             mage sõstar
# 119                    mais
# 120               maisitang
# 121              makadaamia
# 122               mandariin
# 123                  mandel
# 124                   mango
# 125                    mari
# 126                   melon
# 127             mesimurakas
# 128               metsamari
# 129                metslauk
# 130            metsmaasikas
# 131              metspähkel
# 132                 metsõun
# 133                mirabell
# 134                    moon
# 135                   mugul
# 136               mugulvili
# 137              munakinkan
# 138                 munguba
# 139                   murel
# 140                murulauk
# 141          muskaatkõrvits
# 142             must sõstar
# 143                must uba
# 144                mustikas
# 145             muulukamari
# 146              mõrumandel
# 147                  naeris
# 148               nektariin
# 149                    nisu
# 150                nisuklii
# 151                nurmlauk
# 152                    oder
# 153                odratang
# 154                   oliiv
# 155                 palukas
# 156                 paprika
# 157            paradiisiõun
# 158                patisson
# 159               peakapsas
# 160            pekaanpähkel
# 161                  persik
# 162               pesasibul
# 163             pihlakamari
# 164                piimjuur
# 165             piiniaseeme
# 166                    pirn
# 167              pistaatsia
# 168                   ploom
# 169              ploomtomat
# 170                   pomel
# 171               pomerants
# 172                   porru
# 173               porrulauk
# 174               punagreip
# 175           punane kapsas
# 176            punane sibul
# 177              punane uba
# 178         päevalilleseeme
# 179                  pähkel
# 180               pärlsibul
# 181                põldmari
# 182                rabarber
# 183                  renett
# 184                renklood
# 185              riivkapsas
# 186                rohulauk
# 187             rooma salat
# 188                   rosin
# 189                   rukis
# 190               rukkiklii
# 191                   salat
# 192                 satsuma
# 193            seesamiseeme
# 194                   sibul
# 195                sibulõun
# 196                  sidrun
# 197             sinepiseeme
# 198                    soja
# 199          spagetikõrvits
# 200                  spinat
# 201                suislepp
# 202                 sultana
# 203             suvikõrvits
# 204                 suviõun
# 205             säilitusõun
# 206                sõrmlaim
# 207                  sõstar
# 208             söödav vili
# 209                sügisõun
# 210               talisibul
# 211                 taliõun
# 212               tamarillo
# 213                    tang
# 214               tangeriin
# 215                   tatar
# 216                    tera
# 217                   tomat
# 218               toortatar
# 219                 tsitrus
# 220                 tuviõun
# 221             tõrukõrvits
# 222                     uba
# 223                    ubin
# 224                  urjukk
# 225                vaarikas
# 226            vaarikpampel
# 227            valge sõstar
# 228              varsseller
# 229             veriapelsin
# 230               viigimari
# 231               viinamari
# 232                   vilis
# 233                    viss
# 234              õlikõrvits
#
#                                                                Synonyms  \
# 0                                          Kreeka pähkel, kreeka pähkel
# 1                                                      adzuki, asukiuba
# 2                                               aed-moorputk, pastinaak
# 3                                                          aed-piimjuur
# 4                                                             aedhernes
# 5                                                           aedmaasikas
# 6                                                      aedmari, aiamari
# 7                                                    aedmurakas, pampel
# 8                                                     aedseller, seller
# 9                                                     aeduba, Türgi uba
# 10                                                              aedvili
# 11   akazuupähkel, India pähkel, india pähkel, kašupähkel, nakar, nakra
# 12                                             alligaatorpirn, avokaado
# 13                                alrauni mari, lemmemari, tuudaimimari
# 14                                                              ananass
# 15                                                           antoonovka
# 16                                                              apelsin
# 17                                                             aprikoos
# 18                                     arahhis, hiina pähkel, maapähkel
# 19                                                               arbuus
# 20                                           areekapähkel, beetlipähkel
# 21                                                             artišokk
# 22                                                       aspar, spargel
# 23                                             astelpaju, astelpajumari
# 24                                                         baamia, okra
# 25                                                     baklažaan, pommu
# 26                                                               banaan
# 27                                                        banaankõrvits
# 28                                    bataat, maguskartul, magus kartul
# 29                                                            bergamott
# 30                                         brasiilia pähkel, parapähkel
# 31                                          brüsseli kapsas, rooskapsas
# 32                                                               bulgur
# 33                                                  dessertõun, lauaõun
# 34                                    diospüür, hurmaa, kaki, kakiploom
# 35                                                 draakonivili, pitaia
# 36                                                               durian
# 37                                                       frukt, puuvili
# 38                                                  granaat, granaatõun
# 39                                                                  NaN
# 40                                            greip, greipfruut, kreebu
# 41                                                              guajaav
# 42                                                            hapukirss
# 43                                                             hapukurk
# 44                                                               hernes
# 45                                               hiina alss, vesikastan
# 46                                             hiina ploom, litš, litši
# 47                                                 hirsitang, hirsitera
# 48                                             hõrakmari, punane sõstar
# 49            indiaani riis, metsik riis, Tuskaroora vesiriis, vesiriis
# 50                                                 inglite vili, papaia
# 51                                                           iva, seeme
# 52                                                                  NaN
# 53                                                           jahubanaan
# 54                                                             jahvatis
# 55                                                    joovikas, sinikas
# 56                                                                  NaN
# 57                                                           juurseller
# 58                                                             jääsalat
# 59                                                   jõhvikas, kuremari
# 60                                         kaarel, karumurakas, murakas
# 61                           kabatšokk, rullkõrvits, zucchini, tsukiini
# 62                                                           kadakamari
# 63                                                      kaer, kaeratera
# 64                                                                  NaN
# 65                                                 kahvrilaim, kombaava
# 66                                                           kaktusvili
# 67                                                                  NaN
# 68                                                                  NaN
# 69                                                     kapsapea, kapsas
# 70                                                 karamboola, tähtvili
# 71                                                    karella, kibekurk
# 72                                                             karulauk
# 73                                          karusmari, tikerber, tikker
# 74                                                             kaunvili
# 75                                 keerdkaelaline kõrvits, käändkõrvits
# 76                                                  kerimoia, suhkruõun
# 77                                                                kiivi
# 78                                        kikerhernes, nuut, põishernes
# 79                                      kinkan, kumkvaat, kääbusapelsin
# 80                                                        kirss, käsper
# 81                                                           kirsstomat
# 82                                                    kivaano, ogamelon
# 83                                                    kivivili, luuvili
# 84                                                              kišmišš
# 85                                         klaar, klaarõun, valge klaar
# 86                                                           klaaskirss
# 87                                                           klementiin
# 88                                                          klii, kliid
# 89                                               kokosell, pikk kõrvits
# 90                                                 kookos, kookospähkel
# 91                                                               korint
# 92                                                                kreek
# 93                                         kruubid, kruubitangud, kruup
# 94                                                      kuivatatud vili
# 95                                                           kuldrenett
# 96                                                                 kurk
# 97                                                              kuskuss
# 98                                                             kõlutera
# 99                                                              kõrvits
# 100                                                       kõrvitsaseeme
# 101                                                           köögivili
# 102                                                            küdoonia
# 103                                                     küüslauk, noblu
# 104                                                                laim
# 105                                                          lamevirsik
# 106                                                                lauk
# 107                                          lehtaedvili, lehtköögivili
# 108                                                          lehtseller
# 109                                                           lihatomat
# 110                                                            liimauba
# 111                                                          lillkapsas
# 112                                              linaseeme, linaseemned
# 113                                            litši, pulasan, rambutan
# 114                                                              longan
# 115                                                        loorberimari
# 116                                 maapirn, mugulpäevalill, topinambur
# 117                                                maasikas, maasikmari
# 118                                                         mage sõstar
# 119                                                     mais, maisitera
# 120                                                           maisitang
# 121                                        makadaamia, makadaamiapähkel
# 122                                                           mandariin
# 123                                                                 NaN
# 124                                                   mango, mangoploom
# 125                                                                mari
# 126                                                               melon
# 127                                             mesimurakas, soomurakas
# 128                                                 metsamari, metsmari
# 129                                                            metslauk
# 130                                                        metsmaasikas
# 131                                           metspähkel, sarapuupähkel
# 132                                                             metsõun
# 133                                                            mirabell
# 134                                                    moon, mooniseeme
# 135                                                                 NaN
# 136                                                                 NaN
# 137                                                  munakinkan, nagami
# 138                                                             munguba
# 139                                                               murel
# 140                                                            murulauk
# 141                                                      muskaatkõrvits
# 142                                              must sõstar, sitikmari
# 143                                                            must uba
# 144                                                mustikas, mustikmari
# 145                                               muulukamari, muulukas
# 146                                                          mõrumandel
# 147                                                              naeris
# 148                                                           nektariin
# 149                                                      nisu, nisutera
# 150                                                                 NaN
# 151                                                            nurmlauk
# 152                                                      oder, odratera
# 153                                                            odratang
# 154                                                               oliiv
# 155                                                       palukas, pohl
# 156                                                paprika, paprikakaun
# 157                                                        paradiisiõun
# 158                                            patisson, taldrikkõrvits
# 159                                                           peakapsas
# 160                                                        pekaanpähkel
# 161                                                      persik, virsik
# 162                                      pesasibul, šalott, šalottsibul
# 163                                               pihlakamari, pihlakas
# 164                                                            piimjuur
# 165                   piiniaseeme, seedermänni pähkel, seedermänniseeme
# 166                                                                pirn
# 167                                        pistaatsia, pistaatsiapähkel
# 168                                                               ploom
# 169                                                          ploomtomat
# 170                                                       pomel, pomelo
# 171                                                           pomerants
# 172                                        porru, porrulauk, porrusibul
# 173                                        porru, porrulauk, porrusibul
# 174                                                punagreip, verigreip
# 175                                                       punane kapsas
# 176                                                        punane sibul
# 177                                                          punane uba
# 178                                             päevalilleseeme, sihvka
# 179                                                              pähkel
# 180                                           pärlsibul, suvi-porrulauk
# 181                                               põldmari, põldmurakas
# 182                                                            rabarber
# 183                                                   renett, renettõun
# 184                                                            renklood
# 185                                              riivkapsas, särvkapsas
# 186                                                            rohulauk
# 187                                                         rooma salat
# 188                                                               rosin
# 189                                                    rukis, rukkitera
# 190                                                                 NaN
# 191                                                               salat
# 192                                                             satsuma
# 193                                                        seesamiseeme
# 194                                                   sibul, söögisibul
# 195                                                            sibulõun
# 196                                                              sidrun
# 197                                                         sinepiseeme
# 198                                                       soja, sojauba
# 199                                                      spagetikõrvits
# 200                                                              spinat
# 201                                                            suislepp
# 202                                               sultana, sultanarosin
# 203                                                         suvikõrvits
# 204                                                             suviõun
# 205                                                         säilitusõun
# 206                                                            sõrmlaim
# 207                                                  sõstar, sõstramari
# 208                                                                 NaN
# 209                                                            sügisõun
# 210                                                           talisibul
# 211                                                             taliõun
# 212                                                           tamarillo
# 213                                                                tang
# 214                                                           tangeriin
# 215                                                    tatar, tatratera
# 216                              tera, teravili, teris, vili, viljatera
# 217                                                               tomat
# 218                                                           toortatar
# 219                                  tsitrus, tsitruseline, tsitrusvili
# 220                                                             tuviõun
# 221                                                         tõrukõrvits
# 222                                                                 uba
# 223                                                           ubin, õun
# 224                                                              urjukk
# 225                                          vaarikas, vaarmari, vabarn
# 226                                                vaarikpampel, vampel
# 227                                                        valge sõstar
# 228                                                          varsseller
# 229                                                         veriapelsin
# 230                                                     viigimari, viik
# 231                                                           viinamari
# 232                                                               vilis
# 233                                                                viss
# 234                                                          õlikõrvits
#
#            most_popular  põhisõnad  palju_küsimusi  vikipeedia
# 0         kreeka pähkel        NaN             1.0         1.0
# 1                   NaN        NaN             1.0         NaN
# 2          aed-moorputk        NaN             1.0         1.0
# 3                   NaN        NaN             1.0         NaN
# 4                   NaN        NaN             1.0         NaN
# 5           aedmaasikas        NaN             1.0         1.0
# 6                   NaN        NaN             1.0         NaN
# 7            aedmurakas        NaN             1.0         1.0
# 8             aedseller        NaN             1.0         1.0
# 9                aeduba        NaN             1.0         1.0
# 10              aedvili        1.0             NaN         1.0
# 11         india pähkel        NaN             2.0         1.0
# 12             avokaado        NaN             1.0         1.0
# 13                  NaN        NaN             1.0         NaN
# 14              ananass        1.0             1.0         1.0
# 15           antoonovka        NaN             1.0         1.0
# 16              apelsin        1.0             1.0         1.0
# 17             aprikoos        NaN             NaN         1.0
# 18              arahhis        NaN             1.0         1.0
# 19               arbuus        1.0             1.0         1.0
# 20         beetlipähkel        NaN             2.0         1.0
# 21             artišokk        NaN             1.0         1.0
# 22                aspar        NaN             1.0         1.0
# 23            astelpaju        NaN             1.0         1.0
# 24               baamia        NaN             1.0         1.0
# 25            baklažaan        NaN             1.0         1.0
# 26               banaan        1.0             1.0         1.0
# 27                  NaN        NaN             1.0         NaN
# 28               bataat        NaN             1.0         1.0
# 29            bergamott        NaN             1.0         1.0
# 30     brasiilia pähkel        NaN             2.0         1.0
# 31      brüsseli kapsas        NaN             1.0         1.0
# 32               bulgur        NaN             2.0         1.0
# 33                  NaN        NaN             1.0         NaN
# 34             diospüür        NaN             1.0         1.0
# 35                  NaN        NaN             1.0         NaN
# 36               durian        NaN             1.0         1.0
# 37              puuvili        1.0             1.0         1.0
# 38              granaat        NaN             1.0         1.0
# 39            granadill        NaN             NaN         1.0
# 40                greip        NaN             1.0         1.0
# 41              guajaav        NaN             1.0         1.0
# 42            hapukirss        NaN             NaN         1.0
# 43             hapukurk        1.0             1.0         1.0
# 44               hernes        1.0             1.0         1.0
# 45                  NaN        NaN             1.0         NaN
# 46                litši        NaN             1.0         1.0
# 47                  NaN        NaN             1.0         NaN
# 48        punane sõstar        NaN             1.0         1.0
# 49                  NaN        NaN             2.0         NaN
# 50               papaia        NaN             1.0         1.0
# 51                seeme        1.0             NaN         1.0
# 52                  NaN        NaN             NaN         NaN
# 53                  NaN        NaN             1.0         NaN
# 54                  NaN        NaN             2.0         NaN
# 55             joovikas        NaN             1.0         1.0
# 56             juurikas        NaN             1.0         1.0
# 57           juurseller        NaN             1.0         1.0
# 58                  NaN        NaN             1.0         NaN
# 59             jõhvikas        1.0             1.0         1.0
# 60               kaarel        NaN             1.0         1.0
# 61             zucchini        NaN             1.0         1.0
# 62           kadakamari        NaN             1.0         1.0
# 63                 kaer        1.0             1.0         1.0
# 64                  NaN        NaN             2.0         NaN
# 65                  NaN        NaN             1.0         NaN
# 66                  NaN        NaN             1.0         NaN
# 67                  NaN        NaN             NaN         NaN
# 68               kappar        NaN             NaN         1.0
# 69               kapsas        1.0             1.0         1.0
# 70           karamboola        NaN             1.0         1.0
# 71                  NaN        NaN             1.0         NaN
# 72             karulauk        NaN             1.0         1.0
# 73            karusmari        1.0             1.0         1.0
# 74             kaunvili        NaN             1.0         1.0
# 75                  NaN        NaN             1.0         NaN
# 76                  NaN        NaN             1.0         NaN
# 77                kiivi        NaN             1.0         1.0
# 78          kikerhernes        NaN             1.0         1.0
# 79                  NaN        NaN             1.0         NaN
# 80                kirss        1.0             2.0         1.0
# 81           kirsstomat        NaN             1.0         1.0
# 82                  NaN        NaN             1.0         NaN
# 83              luuvili        NaN             NaN         1.0
# 84                  NaN        NaN             1.0         NaN
# 85                klaar        NaN             1.0         1.0
# 86                  NaN        NaN             2.0         NaN
# 87           klementiin        NaN             1.0         1.0
# 88                 klii        NaN             2.0         1.0
# 89                  NaN        NaN             1.0         NaN
# 90               kookos        NaN             2.0         1.0
# 91               korint        NaN             2.0         1.0
# 92                kreek        NaN             1.0         1.0
# 93              kruubid        NaN             2.0         1.0
# 94                  NaN        NaN             NaN         NaN
# 95           kuldrenett        NaN             1.0         1.0
# 96                 kurk        1.0             1.0         1.0
# 97              kuskuss        NaN             1.0         1.0
# 98                  NaN        NaN             2.0         NaN
# 99              kõrvits        1.0             1.0         1.0
# 100                 NaN        NaN             NaN         NaN
# 101           köögivili        1.0             1.0         1.0
# 102            küdoonia        NaN             1.0         1.0
# 103            küüslauk        1.0             NaN         1.0
# 104                laim        NaN             1.0         1.0
# 105          lamevirsik        NaN             1.0         1.0
# 106                lauk        NaN             1.0         1.0
# 107                 NaN        NaN             NaN         NaN
# 108                 NaN        NaN             1.0         NaN
# 109                 NaN        NaN             1.0         NaN
# 110                 NaN        NaN             1.0         NaN
# 111          lillkapsas        1.0             1.0         1.0
# 112         linaseemned        NaN             NaN         1.0
# 113               litši        NaN             1.0         1.0
# 114                 NaN        NaN             1.0         NaN
# 115                 NaN        NaN             NaN         NaN
# 116             maapirn        NaN             1.0         1.0
# 117            maasikas        1.0             1.0         1.0
# 118         mage sõstar        NaN             1.0         1.0
# 119                mais        NaN             1.0         1.0
# 120                 NaN        NaN             1.0         NaN
# 121                 NaN        NaN             2.0         NaN
# 122           mandariin        1.0             1.0         1.0
# 123              mandel        NaN             NaN         1.0
# 124               mango        NaN             NaN         1.0
# 125                mari        1.0             1.0         1.0
# 126               melon        NaN             1.0         1.0
# 127         mesimurakas        NaN             1.0         1.0
# 128                 NaN        NaN             1.0         NaN
# 129            metslauk        NaN             1.0         1.0
# 130        metsmaasikas        NaN             1.0         1.0
# 131          metspähkel        NaN             2.0         1.0
# 132                 NaN        NaN             1.0         NaN
# 133                 NaN        NaN             NaN         NaN
# 134                moon        NaN             NaN         1.0
# 135               mugul        NaN             NaN         1.0
# 136                 NaN        NaN             NaN         NaN
# 137                 NaN        NaN             1.0         NaN
# 138             munguba        NaN             1.0         1.0
# 139               murel        NaN             NaN         1.0
# 140            murulauk        NaN             1.0         1.0
# 141                 NaN        NaN             1.0         NaN
# 142         must sõstar        NaN             1.0         1.0
# 143                 NaN        NaN             1.0         NaN
# 144            mustikas        1.0             1.0         1.0
# 145            muulukas        NaN             1.0         1.0
# 146                 NaN        NaN             NaN         NaN
# 147              naeris        NaN             1.0         1.0
# 148           nektariin        NaN             1.0         1.0
# 149                nisu        1.0             2.0         1.0
# 150                 NaN        NaN             2.0         NaN
# 151            nurmlauk        NaN             1.0         1.0
# 152                oder        1.0             NaN         1.0
# 153                 NaN        NaN             1.0         NaN
# 154               oliiv        NaN             NaN         1.0
# 155             palukas        NaN             1.0         1.0
# 156             paprika        1.0             1.0         1.0
# 157                 NaN        NaN             1.0         NaN
# 158                 NaN        NaN             1.0         NaN
# 159           peakapsas        NaN             1.0         1.0
# 160                 NaN        NaN             2.0         NaN
# 161              virsik        1.0             1.0         1.0
# 162                 NaN        NaN             1.0         NaN
# 163            pihlakas        NaN             1.0         1.0
# 164            piimjuur        NaN             1.0         1.0
# 165  seedermänni pähkel        NaN             NaN         1.0
# 166                pirn        1.0             1.0         1.0
# 167          pistaatsia        NaN             1.0         1.0
# 168               ploom        1.0             1.0         1.0
# 169                 NaN        NaN             1.0         NaN
# 170               pomel        NaN             1.0         1.0
# 171           pomerants        NaN             1.0         1.0
# 172           porrulauk        NaN             1.0         1.0
# 173           porrulauk        NaN             1.0         1.0
# 174                 NaN        NaN             1.0         NaN
# 175                 NaN        NaN             1.0         NaN
# 176        punane sibul        NaN             1.0         1.0
# 177                 NaN        NaN             1.0         NaN
# 178                 NaN        NaN             NaN         NaN
# 179              pähkel        1.0             2.0         1.0
# 180                 NaN        NaN             1.0         NaN
# 181            põldmari        NaN             1.0         1.0
# 182            rabarber        NaN             1.0         1.0
# 183                 NaN        NaN             1.0         NaN
# 184                 NaN        NaN             1.0         NaN
# 185                 NaN        NaN             1.0         NaN
# 186            rohulauk        NaN             1.0         1.0
# 187         rooma salat        NaN             1.0         1.0
# 188               rosin        NaN             2.0         1.0
# 189               rukis        1.0             NaN         1.0
# 190                 NaN        NaN             2.0         NaN
# 191               salat        1.0             1.0         1.0
# 192                 NaN        NaN             1.0         NaN
# 193        seesamiseeme        NaN             NaN         1.0
# 194               sibul        1.0             1.0         1.0
# 195                 NaN        NaN             1.0         NaN
# 196              sidrun        1.0             1.0         1.0
# 197                 NaN        NaN             NaN         NaN
# 198                soja        NaN             1.0         1.0
# 199                 NaN        NaN             1.0         NaN
# 200              spinat        NaN             1.0         1.0
# 201            suislepp        NaN             1.0         1.0
# 202             sultana        NaN             2.0         1.0
# 203         suvikõrvits        NaN             1.0         1.0
# 204                 NaN        NaN             1.0         NaN
# 205                 NaN        NaN             1.0         NaN
# 206                 NaN        NaN             1.0         NaN
# 207              sõstar        NaN             1.0         1.0
# 208                 NaN        NaN             NaN         NaN
# 209                 NaN        NaN             1.0         NaN
# 210           talisibul        NaN             1.0         1.0
# 211                 NaN        NaN             1.0         NaN
# 212                 NaN        NaN             1.0         NaN
# 213                tang        NaN             1.0         1.0
# 214           tangeriin        NaN             1.0         1.0
# 215               tatar        1.0             1.0         1.0
# 216                tera        1.0             2.0         1.0
# 217               tomat        1.0             1.0         1.0
# 218                 NaN        NaN             1.0         NaN
# 219             tsitrus        NaN             1.0         1.0
# 220                 NaN        NaN             1.0         NaN
# 221                 NaN        NaN             1.0         NaN
# 222                 uba        1.0             1.0         1.0
# 223                 õun        1.0             1.0         1.0
# 224                 NaN        NaN             NaN         NaN
# 225            vaarikas        1.0             1.0         1.0
# 226        vaarikpampel        NaN             1.0         1.0
# 227                 NaN        NaN             1.0         NaN
# 228                 NaN        NaN             1.0         NaN
# 229                 NaN        NaN             1.0         NaN
# 230                viik        1.0             1.0         1.0
# 231           viinamari        1.0             1.0         1.0
# 232                 NaN        NaN             2.0         NaN
# 233                 NaN        NaN             1.0         NaN
# 234                 NaN        NaN             1.0         NaN

# %%
# kõik sõnad millel on vikipeedia leht on ka piisavalt palju küsimusi
df_sõnad[
    ((df_sõnad["vikipeedia"] == 1) )
]
# Out:
#                           Loom  põhisõnad  palju_küsimusi  vikipeedia
# 0              Ameerika paalia        NaN             2.0         1.0
# 1          Arvicola terrestris        NaN             1.0         1.0
# 2      Campbelli käpikhamstrik        NaN             2.0         1.0
# 3          Carassius carassius        NaN             NaN         1.0
# 6           Kalifornia pringel        NaN             1.0         1.0
# 7              aafrika elevant        NaN             2.0         1.0
# 8               aafrika pühvel        NaN             2.0         1.0
# 9              aafrika tsiibet        NaN             2.0         1.0
# 10                        aaga        NaN             2.0         1.0
# 11                        aara        NaN             1.0         1.0
# 12                  aasia lõvi        NaN             2.0         1.0
# 13                aasia taapir        NaN             1.0         1.0
# 14                     abakala        NaN             2.0         1.0
# 16                     abikoer        NaN             2.0         1.0
# 17                      addaks        NaN             1.0         1.0
# 18                aed-lepalind        NaN             1.0         1.0
# 19               aed-põõsalind        NaN             2.0         1.0
# 20                     afaliin        NaN             2.0         1.0
# 21                afgaani hurt        NaN             1.0         1.0
# 22              afgaani rebane        NaN             2.0         1.0
# 24                      agnaat        NaN             NaN         1.0
# 25                      aguuti        NaN             1.0         1.0
# 28                         ahv        1.0             2.0         1.0
# 29                       ahven        NaN             2.0         1.0
# 32              akvaariumikala        NaN             NaN         1.0
# 33                   albatross        NaN             1.0         1.0
# 35                         alk        NaN             1.0         1.0
# 36                  alligaator        NaN             NaN         1.0
# 41                   amfibiont        NaN             NaN         1.0
# 42                      amfiib        NaN             NaN         1.0
# 47               amuuri tiiger        NaN             2.0         1.0
# 48                    anakonda        NaN             2.0         1.0
# 51                    angerjas        NaN             NaN         1.0
# 55                    antiloop        NaN             1.0         1.0
# 57                     anuubis        NaN             2.0         1.0
# 58                    anšoovis        NaN             NaN         1.0
# 60                    arapaima        NaN             NaN         1.0
# 61                    ararauna        NaN             1.0         1.0
# 69                arheopterüks        NaN             2.0         1.0
# 71                        arni        NaN             2.0         1.0
# 72                  arusisalik        NaN             NaN         1.0
# 75                    astelrai        NaN             2.0         1.0
# 77               atlandi tursk        NaN             2.0         1.0
# 78                         aul        NaN             1.0         1.0
# 82                     babuiin        NaN             2.0         1.0
# 85              baikali viiger        NaN             2.0         1.0
# 86                 bali tiiger        NaN             2.0         1.0
# 87                  bambuskaru        NaN             2.0         1.0
# 89                     baribal        NaN             2.0         1.0
# 90                  barrakuuda        NaN             NaN         1.0
# 91                      barsoi        NaN             1.0         1.0
# 92                    basilisk        NaN             NaN         1.0
# 94                      beagle        NaN             1.0         1.0
# 95                       beira        NaN             1.0         1.0
# 96                     beluuga        NaN             NaN         1.0
# 97              bengali tiiger        NaN             2.0         1.0
# 99                  berberiahv        NaN             2.0         1.0
# 100                bernhardiin        NaN             1.0         1.0
# 102                     bester        NaN             NaN         1.0
# 105                    biruang        NaN             2.0         1.0
# 106                      bissa        NaN             NaN         1.0
# 108                        boa        NaN             2.0         1.0
# 109                     bokser        NaN             1.0         1.0
# 112                     bonobo        NaN             2.0         1.0
# 113              brahhiosaurus        NaN             2.0         1.0
# 114           brandti lendlane        NaN             2.0         1.0
# 115        briti lühikarvaline        NaN             1.0         1.0
# 116                    broiler        1.0             1.0         1.0
# 117               brontosaurus        NaN             2.0         1.0
# 118                     buldog        NaN             1.0         1.0
# 119                 bullmastif        NaN             1.0         1.0
# 120                   bungarus        NaN             2.0         1.0
# 123            dalmaatsia koer        NaN             1.0         1.0
# 125                      deegu        NaN             1.0         1.0
# 126                    delfiin        NaN             2.0         1.0
# 130                detritofaag        NaN             2.0         1.0
# 133                      dingo        NaN             2.0         1.0
# 135                 dinosaurus        NaN             2.0         1.0
# 139                  dobermann        NaN             1.0         1.0
# 140                    draakon        NaN             NaN         1.0
# 146   džungaaria kääbushamster        NaN             2.0         1.0
# 147                       eefa        NaN             2.0         1.0
# 148               eesti hobune        NaN             2.0         1.0
# 150            eesti maalammas        NaN             1.0         1.0
# 151        eesti maatõugu veis        NaN             1.0         1.0
# 152       eesti raskeveohobune        NaN             2.0         1.0
# 153      eesti suur valge siga        NaN             2.0         1.0
# 156                 eesti vutt        NaN             2.0         1.0
# 157             egiptuse kobra        NaN             2.0         1.0
# 162            elektriangerjas        NaN             NaN         1.0
# 164                 elektrirai        NaN             NaN         1.0
# 166                    elevant        1.0             2.0         1.0
# 167            elevantkilpkonn        NaN             NaN         1.0
# 172                    emakala        NaN             NaN         1.0
# 179                       emis        NaN             2.0         1.0
# 180                        emu        NaN             2.0         1.0
# 182             euroopa kobras        NaN             2.0         1.0
# 183          euroopa pruunkaru        NaN             2.0         1.0
# 184            euroopa süsikas        NaN             NaN         1.0
# 185                     faasan        NaN             1.0         1.0
# 186                     fennek        NaN             2.0         1.0
# 187                   flamingo        NaN             2.0         1.0
# 188                 foksterjer        NaN             1.0         1.0
# 189                     forell        NaN             2.0         1.0
# 190                      fossa        NaN             2.0         1.0
# 194                       fugu        NaN             NaN         1.0
# 195                   fütofaag        NaN             NaN         1.0
# 196                    gaavial        NaN             NaN         1.0
# 198                    galaago        NaN             2.0         1.0
# 201                       gaur        NaN             2.0         1.0
# 203                    gelaada        NaN             2.0         1.0
# 212                   gorbuuša        NaN             2.0         1.0
# 214                    gorilla        NaN             2.0         1.0
# 216                     grinda        NaN             1.0         1.0
# 217                     grisli        NaN             2.0         1.0
# 219                grööni vaal        NaN             1.0         1.0
# 221                      guara        NaN             2.0         1.0
# 222                       gupi        NaN             NaN         1.0
# 223                      gürsa        NaN             2.0         1.0
# 226               haavikuemand        NaN             2.0         1.0
# 227               habelendlane        NaN             2.0         1.0
# 229                   habesiga        NaN             2.0         1.0
# 232                        hai        1.0             2.0         1.0
# 233                     haigur        NaN             1.0         1.0
# 234           haiiti pilukoonu        NaN             2.0         1.0
# 235                  haisuloom        NaN             NaN         1.0
# 236                 hallhaigur        NaN             1.0         1.0
# 237                   hallhani        NaN             2.0         1.0
# 238                   hallhunt        NaN             2.0         1.0
# 239                  halljänes        NaN             2.0         1.0
# 240                   hallkibu        NaN             2.0         1.0
# 241                   hallorav        NaN             2.0         1.0
# 242                hallpapagoi        NaN             1.0         1.0
# 243               hallpea-rähn        NaN             2.0         1.0
# 244                 hallrebane        NaN             2.0         1.0
# 245                 hallrästas        NaN             2.0         1.0
# 247                   hallvaal        NaN             1.0         1.0
# 248                  hamadrill        NaN             2.0         1.0
# 251                    hamster        NaN             2.0         1.0
# 254                       hani        1.0             2.0         1.0
# 257           harilik lendorav        NaN             1.0         1.0
# 258          harilik pääsukala        NaN             NaN         1.0
# 261                     harjus        NaN             NaN         1.0
# 262                   hateeria        NaN             NaN         1.0
# 265                  haudelind        NaN             2.0         1.0
# 267                       haug        NaN             2.0         1.0
# 269                  heeringas        1.0             2.0         1.0
# 273                 heletilder        NaN             2.0         1.0
# 275                  herbivoor        NaN             NaN         1.0
# 276                  hermeliin        NaN             2.0         1.0
# 282            hiid-soomusloom        NaN             2.0         1.0
# 284               hiidanakonda        NaN             2.0         1.0
# 285                    hiidhai        NaN             2.0         1.0
# 289                hiidsaarmas        NaN             2.0         1.0
# 294                       hiir        1.0             1.0         1.0
# 296                   hiirlane        NaN             1.0         1.0
# 298                       hink        NaN             NaN         1.0
# 302                       hirv        NaN             1.0         1.0
# 304                       hobu        NaN             1.0         1.0
# 310                       huik        NaN             1.0         1.0
# 311                  hulgulind        NaN             2.0         1.0
# 318                       hunt        1.0             2.0         1.0
# 319                  huntahven        NaN             2.0         1.0
# 322                   huulkaru        NaN             2.0         1.0
# 326                   hänilane        NaN             2.0         1.0
# 327                       härg        NaN             1.0         1.0
# 328                   härgkonn        NaN             2.0         1.0
# 331                     häslik        NaN             NaN         1.0
# 333              hõbe-nahkhiir        NaN             2.0         1.0
# 336                 hõbehaigur        NaN             1.0         1.0
# 337                  hõbekoger        NaN             NaN         1.0
# 339                 hõberebane        NaN             1.0         1.0
# 340                     hõrnas        NaN             2.0         1.0
# 341                     hüljes        NaN             2.0         1.0
# 343                hüpikgasell        NaN             1.0         1.0
# 348                      hüään        NaN             2.0         1.0
# 349                       hüüp        NaN             2.0         1.0
# 350                     hüüpel        NaN             1.0         1.0
# 351               ibeeria hunt        NaN             2.0         1.0
# 352              ibeeria ilves        NaN             NaN         1.0
# 354               ida-vöötorav        NaN             2.0         1.0
# 357                 iguaanodon        NaN             2.0         1.0
# 359                       ihes        NaN             2.0         1.0
# 366                       ilka        NaN             2.0         1.0
# 368                      ilves        NaN             2.0         1.0
# 369                    imetaja        NaN             NaN         1.0
# 370                       imik        1.0             2.0         1.0
# 371                    imikala        NaN             NaN         1.0
# 373              india elevant        NaN             2.0         1.0
# 374                india kobra        NaN             2.0         1.0
# 376           india soomusloom        NaN             2.0         1.0
# 377                      indri        NaN             2.0         1.0
# 379               inglise hurt        NaN             1.0         1.0
# 380      inglise kokkerspanjel        NaN             1.0         1.0
# 385                      irbis        NaN             2.0         1.0
# 395             islandi hobune        NaN             2.0         1.0
# 396                    jaaguar        NaN             NaN         1.0
# 397                  jaanalind        NaN             2.0         1.0
# 400           jaava soomusloom        NaN             2.0         1.0
# 402                 jahifaasan        NaN             1.0         1.0
# 403                   jahikoer        NaN             1.0         1.0
# 404                   jahilind        NaN             2.0         1.0
# 405                   jahiloom        NaN             2.0         1.0
# 417                  järvekaur        NaN             1.0         1.0
# 418                  järvekonn        NaN             2.0         1.0
# 422                    jääkaru        NaN             2.0         1.0
# 423                    jääkaur        NaN             1.0         1.0
# 424                  jääkoskel        NaN             1.0         1.0
# 429                    jõesiga        NaN             2.0         1.0
# 430                    jõesilm        NaN             NaN         1.0
# 432            jõgi-ritsiklind        NaN             2.0         1.0
# 434                   jõgitiir        NaN             2.0         1.0
# 435                 jõgitilder        NaN             2.0         1.0
# 447                 kadakatäks        NaN             2.0         1.0
# 448                 kaelkirjak        NaN             2.0         1.0
# 449          kaelus-turteltuvi        NaN             1.0         1.0
# 454                 kaelustuvi        NaN             2.0         1.0
# 458                    kajakas        1.0             1.0         1.0
# 461           kaksvarvaslaisik        NaN             2.0         1.0
# 462                       kala        1.0             NaN         1.0
# 463                   kalakass        NaN             2.0         1.0
# 464                   kalamaim        NaN             NaN         1.0
# 466               kaldapääsuke        NaN             1.0         1.0
# 467         kalifornia pringel        NaN             1.0         1.0
# 468                  kaljukits        1.0             1.0         1.0
# 471                  kaljutuvi        NaN             2.0         1.0
# 472                     kalkun        1.0             1.0         1.0
# 474                     kalong        NaN             2.0         1.0
# 475                    kaluuga        NaN             NaN         1.0
# 476                  kameeleon        NaN             NaN         1.0
# 477                  kammeljas        NaN             2.0         1.0
# 478                       kana        1.0             1.0         1.0
# 480               kanada ilves        NaN             2.0         1.0
# 481              kanada kobras        NaN             2.0         1.0
# 485                 kannuskonn        NaN             2.0         1.0
# 487                  kapibaara        NaN             2.0         1.0
# 489                  kaputsiin        NaN             2.0         1.0
# 491                    karakal        NaN             NaN         1.0
# 492            karakullilammas        NaN             1.0         1.0
# 493                   kardinal        NaN             2.0         1.0
# 496                   kariloom        NaN             2.0         1.0
# 498                   karkjalg        NaN             1.0         1.0
# 499                       karp        1.0             2.0         1.0
# 500                       karu        1.0             1.0         1.0
# 504                  karusloom        NaN             NaN         1.0
# 505         karvane ninasarvik        NaN             2.0         1.0
# 507                kasetriibik        NaN             1.0         1.0
# 509                       kass        1.0             1.0         1.0
# 510                  kassipoeg        1.0             NaN         1.0
# 512                 kassleemur        NaN             1.0         1.0
# 514                      kasur        NaN             NaN         1.0
# 516                    katraan        NaN             2.0         1.0
# 517                  katseloom        NaN             NaN         1.0
# 518                      katta        NaN             2.0         1.0
# 520                       kaur        NaN             1.0         1.0
# 521                   kašelott        NaN             1.0         1.0
# 522                        kea        NaN             1.0         1.0
# 523              keerdsarvkits        NaN             1.0         1.0
# 529                       keta        NaN             NaN         1.0
# 533                      kiisk        NaN             NaN         1.0
# 534                      kiivi        NaN             2.0         1.0
# 535                      kikas        NaN             1.0         1.0
# 536                   kilpkonn        1.0             NaN         1.0
# 539                       kilu        NaN             2.0         1.0
# 540                     kimmel        NaN             1.0         1.0
# 541                   kingnokk        NaN             2.0         1.0
# 544                     kipper        NaN             2.0         1.0
# 546             kiripugu-risla        NaN             2.0         1.0
# 548                  kirjuhahk        NaN             2.0         1.0
# 549                 kirjumudil        NaN             2.0         1.0
# 550                  kirjurähn        NaN             2.0         1.0
# 552                     kiskja        NaN             NaN         1.0
# 553                       kits        1.0             2.0         1.0
# 555                kivirullija        NaN             2.0         1.0
# 556                   kivitäks        NaN             2.0         1.0
# 562                      kobra        NaN             2.0         1.0
# 563                     kobras        NaN             2.0         1.0
# 565                   koduhani        NaN             1.0         1.0
# 566                   kodukoer        NaN             2.0         1.0
# 568                 kodulammas        NaN             2.0         1.0
# 569                   kodulind        1.0             2.0         1.0
# 570                   koduloom        1.0             NaN         1.0
# 571                   kodupart        NaN             1.0         1.0
# 572                   kodusiga        NaN             2.0         1.0
# 573                   kodutuvi        NaN             2.0         1.0
# 574                   koduveis        NaN             2.0         1.0
# 577                    koerhai        NaN             2.0         1.0
# 578                       koha        NaN             NaN         1.0
# 580                        koi        NaN             2.0         1.0
# 581                     koiott        NaN             2.0         1.0
# 583                      kolli        NaN             1.0         1.0
# 585                     kondor        NaN             1.0         1.0
# 588                       konn        1.0             2.0         1.0
# 590                   koolibri        NaN             2.0         1.0
# 592                     koonik        NaN             1.0         1.0
# 598                  koprofaag        NaN             NaN         1.0
# 602                 korallmadu        NaN             2.0         1.0
# 605                     koskel        NaN             1.0         1.0
# 607         kreeta besoaarkits        NaN             2.0         1.0
# 610                  krokodill        1.0             NaN         1.0
# 614                       kukk        1.0             1.0         1.0
# 616                kuldhamster        NaN             2.0         1.0
# 618                   kuldkala        NaN             NaN         1.0
# 622                      kunel        NaN             1.0         1.0
# 623                kuningkobra        NaN             2.0         1.0
# 628                       kurg        1.0             2.0         1.0
# 629                    kurvits        NaN             1.0         1.0
# 630                   käbilind        NaN             2.0         1.0
# 632                     kährik        NaN             2.0         1.0
# 633                    känguru        NaN             2.0         1.0
# 635                   kärnkonn        NaN             2.0         1.0
# 637            kääbus-nahkhiir        NaN             2.0         1.0
# 641              kääbusjõehobu        NaN             2.0         1.0
# 642                 kääbuskass        NaN             2.0         1.0
# 645             kääbuspingviin        NaN             1.0         1.0
# 647               kääbusrebane        NaN             2.0         1.0
# 648                 kääbussiga        NaN             2.0         1.0
# 650                   kõhrkala        NaN             NaN         1.0
# 651                 kõigesööja        NaN             NaN         1.0
# 653                       kõrb        1.0             1.0         1.0
# 656             kõrkja-roolind        NaN             2.0         1.0
# 657               kõrvukrebane        NaN             2.0         1.0
# 658            kõvernokk-risla        NaN             2.0         1.0
# 659              kühmnokk-luik        NaN             1.0         1.0
# 665                        küü        NaN             NaN         1.0
# 667                     küülik        NaN             2.0         1.0
# 668                   küürvaal        NaN             1.0         1.0
# 671                       laar        NaN             2.0         1.0
# 672                   labrador        NaN             1.0         1.0
# 673                      lagle        NaN             2.0         1.0
# 674                    lagrits        NaN             NaN         1.0
# 675                       lahn        NaN             NaN         1.0
# 676                      laika        NaN             1.0         1.0
# 683                  lamantiin        NaN             2.0         1.0
# 684                  lambatall        NaN             2.0         1.0
# 685                lammitilder        NaN             2.0         1.0
# 689                 latimeeria        NaN             NaN         1.0
# 690                       lauk        NaN             2.0         1.0
# 693                  laululind        NaN             1.0         1.0
# 694                  laululuik        NaN             1.0         1.0
# 695                laulurästas        NaN             2.0         1.0
# 697                     leemur        NaN             1.0         1.0
# 699                 leeterisla        NaN             2.0         1.0
# 701                   lehekonn        NaN             2.0         1.0
# 702                   lehelind        NaN             2.0         1.0
# 703                       lehm        1.0             1.0         1.0
# 706                 lemmikloom        1.0             NaN         1.0
# 707                    lemming        NaN             1.0         1.0
# 711                   lepamaim        NaN             NaN         1.0
# 712                  lepiskala        NaN             NaN         1.0
# 713                       lest        NaN             2.0         1.0
# 718                   lihakana        NaN             1.0         1.0
# 721                   lihaloom        NaN             2.0         1.0
# 725                   lihaveis        NaN             1.0         1.0
# 726                     liiger        NaN             NaN         1.0
# 727                 liiperkala        NaN             NaN         1.0
# 730                   limusiin        NaN             1.0         1.0
# 731                     linask        NaN             NaN         1.0
# 732                       lind        1.0             2.0         1.0
# 737                       loom        1.0             NaN         1.0
# 740                     loomik        NaN             2.0         1.0
# 741              loomtoiduline        NaN             NaN         1.0
# 742                      loori        NaN             2.0         1.0
# 744                     lufaar        NaN             NaN         1.0
# 745                       luik        1.0             1.0         1.0
# 746                  luitekass        NaN             2.0         1.0
# 748                   lumekits        NaN             2.0         1.0
# 749                 lumelammas        NaN             1.0         1.0
# 750                       lunn        NaN             1.0         1.0
# 751                       luts        NaN             2.0         1.0
# 752                  luukarits        NaN             NaN         1.0
# 755           lääne-pöialpoiss        NaN             1.0         1.0
# 757                  lõgismadu        NaN             NaN         1.0
# 758                       lõhe        1.0             2.0         1.0
# 760                        lõo        NaN             1.0         1.0
# 763                  lüpsilehm        NaN             1.0         1.0
# 764                      maara        NaN             NaN         1.0
# 765                  maasuslik        NaN             2.0         1.0
# 768                       madu        1.0             NaN         1.0
# 769                   madunõel        NaN             NaN         1.0
# 770                   madutäht        NaN             2.0         1.0
# 771                mageveekala        NaN             NaN         1.0
# 780                     makaak        NaN             2.0         1.0
# 782                    makrell        NaN             NaN         1.0
# 785                      mamba        NaN             2.0         1.0
# 787                   mandrill        NaN             2.0         1.0
# 790                      manul        NaN             2.0         1.0
# 797                     mastif        NaN             1.0         1.0
# 798                   mastodon        NaN             NaN         1.0
# 799                   meemäger        NaN             2.0         1.0
# 803                    meltsas        NaN             2.0         1.0
# 804                mereimetaja        NaN             NaN         1.0
# 806                   merelind        NaN             1.0         1.0
# 807                   mereloom        NaN             2.0         1.0
# 811                 merihobuke        NaN             NaN         1.0
# 813                   merihärg        NaN             NaN         1.0
# 822                  merikurat        NaN             NaN         1.0
# 823                   merilest        NaN             NaN         1.0
# 825                   merinõel        NaN             NaN         1.0
# 828                 meripühvel        NaN             NaN         1.0
# 829                  meririsla        NaN             2.0         1.0
# 830                   merisiga        NaN             1.0         1.0
# 832                   merisiig        NaN             2.0         1.0
# 834                   merisutt        NaN             NaN         1.0
# 835                   meritint        NaN             NaN         1.0
# 836                   meritäht        NaN             2.0         1.0
# 837               merivarblane        NaN             NaN         1.0
# 838                   merivart        NaN             1.0         1.0
# 841              mets-lehelind        NaN             2.0         1.0
# 845                 metshobune        NaN             2.0         1.0
# 848                 metskalkun        NaN             1.0         1.0
# 849                   metskass        NaN             2.0         1.0
# 854                   metsloom        1.0             2.0         1.0
# 855                 metstilder        NaN             2.0         1.0
# 857                   metsunel        NaN             NaN         1.0
# 859                metsümiseja        NaN             2.0         1.0
# 861                        moa        NaN             2.0         1.0
# 866                       mops        NaN             1.0         1.0
# 869                   mudakonn        NaN             2.0         1.0
# 870                   mudamaim        NaN             NaN         1.0
# 871                   mudanepp        NaN             1.0         1.0
# 872                 mudatilder        NaN             2.0         1.0
# 874                     muflon        NaN             2.0         1.0
# 877                   mullikas        NaN             1.0         1.0
# 882                     mureen        NaN             NaN         1.0
# 884                 muskuspart        NaN             2.0         1.0
# 885                 muskusveis        NaN             2.0         1.0
# 886                 must mamba        NaN             2.0         1.0
# 887            must-ninasarvik        NaN             2.0         1.0
# 888             must-toonekurg        NaN             1.0         1.0
# 889                    mustang        NaN             2.0         1.0
# 893          mustpea-põõsalind        NaN             2.0         1.0
# 894                mustpringel        NaN             1.0         1.0
# 895                 musträstas        NaN             2.0         1.0
# 896             mustsaba-vigle        NaN             2.0         1.0
# 898                      mustu        NaN             1.0         1.0
# 899                 mustvaeras        NaN             1.0         1.0
# 900                 mustviires        NaN             1.0         1.0
# 901                       mutt        NaN             2.0         1.0
# 902                mägigorilla        NaN             2.0         1.0
# 903                 mägihõrnas        NaN             2.0         1.0
# 906                   mägikits        NaN             2.0         1.0
# 907                 mägilammas        NaN             2.0         1.0
# 909                       mära        NaN             1.0         1.0
# 912                 mõrtsukhai        NaN             2.0         1.0
# 913                    mõrukas        NaN             NaN         1.0
# 915                   mõõkkala        NaN             NaN         1.0
# 917                   möiraahv        NaN             2.0         1.0
# 918                   mürkmadu        NaN             2.0         1.0
# 921                naaskelnokk        NaN             1.0         1.0
# 923                   nahkhiir        NaN             2.0         1.0
# 924               nahkkilpkonn        NaN             NaN         1.0
# 927                      nandu        NaN             1.0         1.0
# 928                     narval        NaN             1.0         1.0
# 929                     nastik        NaN             NaN         1.0
# 930         nattereri lendlane        NaN             2.0         1.0
# 932                  nekrofaag        NaN             NaN         1.0
# 933              nelipoiseluts        NaN             2.0         1.0
# 935                neljajalgne        NaN             NaN         1.0
# 937                      nerka        NaN             2.0         1.0
# 939                      nigli        NaN             2.0         1.0
# 940                 niidurisla        NaN             2.0         1.0
# 943                    ninaahv        NaN             NaN         1.0
# 944                 ninasarvik        1.0             2.0         1.0
# 946                     njuufa        NaN             1.0         1.0
# 947                    noakala        NaN             2.0         1.0
# 948                  nokissiil        NaN             2.0         1.0
# 950                   nokkloom        NaN             2.0         1.0
# 951                     nolgus        NaN             NaN         1.0
# 954                   noorkala        NaN             NaN         1.0
# 960                       nurg        NaN             NaN         1.0
# 961                     nutria        NaN             1.0         1.0
# 965                   näriline        NaN             1.0         1.0
# 966                 nõmmelõoke        NaN             1.0         1.0
# 967                     ogalik        NaN             NaN         1.0
# 973                    ojasilm        NaN             NaN         1.0
# 976                   okassiga        NaN             NaN         1.0
# 979                    ondatra        NaN             1.0         1.0
# 982                  orangutan        NaN             2.0         1.0
# 983                       orav        1.0             2.0         1.0
# 986                     orikas        NaN             2.0         1.0
# 988                      orüks        NaN             1.0         1.0
# 991                    paavian        NaN             2.0         1.0
# 993                  paigalind        NaN             2.0         1.0
# 995                  pakaraana        NaN             NaN         1.0
# 997               paljastuhnur        NaN             NaN         1.0
# 998                  palmiorav        NaN             2.0         1.0
# 1000                  palomino        NaN             1.0         1.0
# 1003                 pangoliin        NaN             2.0         1.0
# 1004                   papagoi        NaN             1.0         1.0
# 1005             paradiisilind        NaN             2.0         1.0
# 1010              pareiasaurus        NaN             2.0         1.0
# 1011            pargi-nahkhiir        NaN             2.0         1.0
# 1012                      part        1.0             1.0         1.0
# 1022                     peled        NaN             NaN         1.0
# 1027                  pesukaru        NaN             2.0         1.0
# 1031                  piilpart        NaN             2.0         1.0
# 1036       pikksaba-soomusloom        NaN             2.0         1.0
# 1037                 pilukoonu        NaN             2.0         1.0
# 1039                  pingviin        NaN             1.0         1.0
# 1042                    pinšer        NaN             1.0         1.0
# 1044                   piraaja        NaN             NaN         1.0
# 1056                     plütt        NaN             1.0         1.0
# 1061              polaarrebane        NaN             2.0         1.0
# 1063                  polüfaag        NaN             NaN         1.0
# 1064                      poni        NaN             1.0         1.0
# 1065                 poolmaaki        NaN             1.0         1.0
# 1066       poolvereline hobune        NaN             1.0         1.0
# 1069                 prillkaru        NaN             2.0         1.0
# 1071              prillpringel        NaN             1.0         1.0
# 1072                   pringel        NaN             1.0         1.0
# 1075       pruun-harjasvöölane        NaN             2.0         1.0
# 1076            pruun-suurkõrv        NaN             2.0         1.0
# 1077           pruun-vööthüään        NaN             2.0         1.0
# 1078       pruunselg-põõsalind        NaN             2.0         1.0
# 1079                 prügikala        NaN             NaN         1.0
# 1084                      pukk        NaN             NaN         1.0
# 1086                      puli        NaN             2.0         1.0
# 1087                      pull        NaN             1.0         1.0
# 1089               pulstikkits        NaN             1.0         1.0
# 1090                      pumi        NaN             1.0         1.0
# 1091             puna-kabeorav        NaN             1.0         1.0
# 1092           puna-veetallaja        NaN             1.0         1.0
# 1093                  punahunt        NaN             2.0         1.0
# 1094                 punailves        NaN             2.0         1.0
# 1095           punajalg-tilder        NaN             2.0         1.0
# 1097             punakurk-kaur        NaN             1.0         1.0
# 1099              punapea-vart        NaN             1.0         1.0
# 1100                punarebane        NaN             1.0         1.0
# 1101                  punarind        NaN             2.0         1.0
# 1106                  purikala        NaN             NaN         1.0
# 1107              purpurhaigur        NaN             1.0         1.0
# 1112                     puuma        NaN             NaN         1.0
# 1116                pähklinäpp        NaN             NaN         1.0
# 1119               pärsia kass        NaN             1.0         1.0
# 1122            põhja-nahkhiir        NaN             2.0         1.0
# 1124                 põhjalunn        NaN             1.0         1.0
# 1125             põhjapringlik        NaN             1.0         1.0
# 1128                 põldlõoke        NaN             2.0         1.0
# 1129                  põldvutt        NaN             2.0         1.0
# 1131                 põõsalind        NaN             2.0         1.0
# 1132           pügmee-nahkhiir        NaN             2.0         1.0
# 1133                    pühvel        NaN             2.0         1.0
# 1134         pürenee kaljukits        NaN             1.0         1.0
# 1136                      püvi        NaN             2.0         1.0
# 1138                    püüton        NaN             2.0         1.0
# 1139                  rabakonn        NaN             2.0         1.0
# 1141                rahvuslind        NaN             2.0         1.0
# 1142                       rai        NaN             2.0         1.0
# 1143                     raibe        NaN             NaN         1.0
# 1146                     ramul        NaN             2.0         1.0
# 1147                    randal        NaN             2.0         1.0
# 1148                  randtiir        NaN             2.0         1.0
# 1149            rannikugorilla        NaN             2.0         1.0
# 1151            raskeveohobune        NaN             1.0         1.0
# 1153               ratsahobune        NaN             1.0         1.0
# 1154                   raudjas        NaN             1.0         1.0
# 1155                 raudkiisk        NaN             NaN         1.0
# 1156                  raudkull        NaN             2.0         1.0
# 1157                    rebane        1.0             2.0         1.0
# 1163                 retriiver        NaN             1.0         1.0
# 1164                       rex        NaN             1.0         1.0
# 1168                     risla        NaN             2.0         1.0
# 1169                  ristpart        NaN             2.0         1.0
# 1171               ristsugutis        NaN             NaN         1.0
# 1173       rodeesia kaelkirjak        NaN             2.0         1.0
# 1175              rohekärnkonn        NaN             2.0         1.0
# 1176            roheline mamba        NaN             2.0         1.0
# 1177                rohepärdik        NaN             NaN         1.0
# 1178         rohtla-soomusloom        NaN             2.0         1.0
# 1179              rohtlahaukur        NaN             2.0         1.0
# 1180                  rohukonn        NaN             2.0         1.0
# 1181                rohukoskel        NaN             2.0         1.0
# 1182                  rohunepp        NaN             1.0         1.0
# 1188              roo-loorkull        NaN             2.0         1.0
# 1189                roohabekas        NaN             2.0         1.0
# 1191                   rookass        NaN             2.0         1.0
# 1192                   roolind        NaN             2.0         1.0
# 1193                   rooruik        NaN             2.0         1.0
# 1194                   roosärg        NaN             NaN         1.0
# 1196                 rotveiler        NaN             1.0         1.0
# 1198                 ruugerüdi        NaN             2.0         1.0
# 1199                      ruun        NaN             1.0         1.0
# 1200                      rähn        NaN             2.0         1.0
# 1201                      räim        1.0             2.0         1.0
# 1204                    rästas        NaN             2.0         1.0
# 1205            rästas-roolind        NaN             2.0         1.0
# 1206                    rästik        NaN             2.0         1.0
# 1207                 räusktiir        NaN             2.0         1.0
# 1208                    rääbis        NaN             2.0         1.0
# 1209             räästapääsuke        NaN             1.0         1.0
# 1210                  röövkala        NaN             NaN         1.0
# 1216                  saakloom        NaN             NaN         1.0
# 1217                   saarmas        NaN             2.0         1.0
# 1218                sabatihane        NaN             1.0         1.0
# 1221                     saiga        NaN             1.0         1.0
# 1226             salu-lehelind        NaN             2.0         1.0
# 1227                      samb        NaN             2.0         1.0
# 1229                 saprofaag        NaN             NaN         1.0
# 1237                     seebu        NaN             2.0         1.0
# 1238                    seepia        NaN             NaN         1.0
# 1241                selgroogne        NaN             NaN         1.0
# 1243                    setter        NaN             1.0         1.0
# 1248                    sifaka        NaN             NaN         1.0
# 1250                siidhaigur        NaN             1.0         1.0
# 1251                 siidisaba        NaN             1.0         1.0
# 1254                siirdekala        NaN             NaN         1.0
# 1256               silepringel        NaN             1.0         1.0
# 1258                      silm        1.0             NaN         1.0
# 1262                  sinignuu        NaN             1.0         1.0
# 1264                  sinikael        NaN             1.0         1.0
# 1265                  siniraag        NaN             2.0         1.0
# 1266                sinirebane        NaN             2.0         1.0
# 1267                  sinirind        NaN             2.0         1.0
# 1269               sipelgasiil        NaN             2.0         1.0
# 1272                   sisalik        NaN             NaN         1.0
# 1274                skaiterjer        NaN             1.0         1.0
# 1278                    soobel        NaN             NaN         1.0
# 1280               sookilpkonn        NaN             NaN         1.0
# 1281                   sookurg        NaN             2.0         1.0
# 1282                 sooküülik        NaN             2.0         1.0
# 1285                soomuslest        NaN             2.0         1.0
# 1286                soomusloom        NaN             2.0         1.0
# 1287                  soorisla        NaN             2.0         1.0
# 1293               stegosaurus        NaN             2.0         1.0
# 1294          stelleri meriõhv        NaN             2.0         1.0
# 1295             stepikilpkonn        NaN             NaN         1.0
# 1300                  sugutäkk        NaN             1.0         1.0
# 1302             suitsupääsuke        NaN             1.0         1.0
# 1306        sumatra ninasarvik        NaN             2.0         1.0
# 1307                      suni        NaN             1.0         1.0
# 1308                    suslik        NaN             2.0         1.0
# 1312            suur-kirjurähn        NaN             2.0         1.0
# 1313           suur-turteltuvi        NaN             2.0         1.0
# 1314    suur-valgejalghamstrik        NaN             2.0         1.0
# 1315           suur-veetallaja        NaN             1.0         1.0
# 1316            suur-vereimeja        NaN             2.0         1.0
# 1318             suurkoovitaja        NaN             2.0         1.0
# 1319                  suurkudu        NaN             1.0         1.0
# 1321                 suurnandu        NaN             1.0         1.0
# 1322                 suurrisla        NaN             2.0         1.0
# 1325                suurtobias        NaN             2.0         1.0
# 1327                  suuruluk        NaN             2.0         1.0
# 1328             suurvidevlane        NaN             2.0         1.0
# 1330                      säga        NaN             2.0         1.0
# 1331                    säinas        NaN             NaN         1.0
# 1332                      särg        NaN             NaN         1.0
# 1336                    sõtkas        NaN             2.0         1.0
# 1339              süvamerekala        NaN             NaN         1.0
# 1340                    taapir        NaN             1.0         1.0
# 1343                      tait        NaN             2.0         1.0
# 1345                      taks        NaN             1.0         1.0
# 1356               tavadelfiin        NaN             2.0         1.0
# 1359               tavašimpans        NaN             2.0         1.0
# 1363             teleskoopkala        NaN             NaN         1.0
# 1370                      tibu        1.0             1.0         1.0
# 1371                    tihane        1.0             1.0         1.0
# 1374                    tiiger        1.0             2.0         1.0
# 1375                 tiigerhai        NaN             2.0         1.0
# 1377             tiigi-roolind        NaN             2.0         1.0
# 1379                 tiigikonn        NaN             2.0         1.0
# 1380             tiigilendlane        NaN             2.0         1.0
# 1382                    tilder        NaN             2.0         1.0
# 1383                 tindikala        NaN             NaN         1.0
# 1385              tippviidikas        NaN             NaN         1.0
# 1388                    tobias        NaN             2.0         1.0
# 1390                 toonekurg        NaN             1.0         1.0
# 1392               tori hobune        NaN             2.0         1.0
# 1393                 tormilind        NaN             2.0         1.0
# 1395                   traavel        NaN             1.0         1.0
# 1396           trakeeni hobune        NaN             2.0         1.0
# 1397                   triibik        NaN             NaN         1.0
# 1399                   triiton        NaN             NaN         1.0
# 1403                  trulling        NaN             NaN         1.0
# 1407               tsiitsitaja        NaN             1.0         1.0
# 1411                    tuhnik        NaN             NaN         1.0
# 1413                  tulipart        NaN             2.0         1.0
# 1414                  tumehunt        NaN             2.0         1.0
# 1415                tumetilder        NaN             2.0         1.0
# 1416          tundra-neppvigle        NaN             2.0         1.0
# 1417                tundrakaur        NaN             1.0         1.0
# 1420                      turb        NaN             NaN         1.0
# 1421                     tursk        NaN             2.0         1.0
# 1422                turteltuvi        NaN             1.0         1.0
# 1424                 tutt-tiir        NaN             2.0         1.0
# 1425                 tuttlõoke        NaN             1.0         1.0
# 1426                tuttmakaak        NaN             2.0         1.0
# 1427                  tuttvart        NaN             2.0         1.0
# 1429                 tuulehaug        NaN             NaN         1.0
# 1432          tähniksalamander        NaN             NaN         1.0
# 1434             tähnikvesilik        NaN             NaN         1.0
# 1435                      täkk        NaN             1.0         1.0
# 1437                 täpikhuik        NaN             1.0         1.0
# 1440            tõmmu-lehelind        NaN             1.0         1.0
# 1441             tõmmulendlane        NaN             2.0         1.0
# 1443               tõmmuvaeras        NaN             1.0         1.0
# 1444                   tõugjas        NaN             NaN         1.0
# 1457                   tõutäkk        NaN             1.0         1.0
# 1461               töönduskala        NaN             NaN         1.0
# 1462             türannosaurus        NaN             2.0         1.0
# 1463                tüügassiga        NaN             2.0         1.0
# 1464                 tšau-tšau        NaN             1.0         1.0
# 1466                tšintšilja        NaN             1.0         1.0
# 1473                       ung        NaN             2.0         1.0
# 1474                   unilane        NaN             1.0         1.0
# 1475                    uriaal        NaN             2.0         1.0
# 1476                     urson        NaN             1.0         1.0
# 1481                     uurik        NaN             1.0         1.0
# 1482                 uustulnuk        NaN             1.0         1.0
# 1483                      vaal        1.0             2.0         1.0
# 1484                   vaalhai        NaN             2.0         1.0
# 1487                    vaeras        NaN             1.0         1.0
# 1490               vainurästas        NaN             2.0         1.0
# 1491           valge-toonekurg        NaN             1.0         1.0
# 1492                valgejänes        NaN             2.0         1.0
# 1493          valgekoondelfiin        NaN             NaN         1.0
# 1494      valgekõht-soomusloom        NaN             2.0         1.0
# 1495          valgelaup-sifaka        NaN             NaN         1.0
# 1497       valgeselg-kirjurähn        NaN             2.0         1.0
# 1498          valgetiib-viires        NaN             1.0         1.0
# 1500                 valgevaal        NaN             2.0         1.0
# 1504                    varaan        NaN             NaN         1.0
# 1505                  varblane        1.0             2.0         1.0
# 1509                     varss        NaN             1.0         1.0
# 1510                      vart        NaN             1.0         1.0
# 1512                  vasarhai        NaN             2.0         1.0
# 1513               vasartiibur        NaN             2.0         1.0
# 1514                   vasikas        NaN             NaN         1.0
# 1516                   veekonn        NaN             2.0         1.0
# 1517               veelendlane        NaN             2.0         1.0
# 1518                   veelind        NaN             2.0         1.0
# 1519                   veeloom        NaN             2.0         1.0
# 1521                veetallaja        NaN             1.0         1.0
# 1522                      veis        NaN             2.0         1.0
# 1525                   veoloom        NaN             NaN         1.0
# 1529                  vesimutt        NaN             2.0         1.0
# 1530                  vesipapp        NaN             1.0         1.0
# 1531                 vesivohlu        NaN             1.0         1.0
# 1533                     vigle        NaN             2.0         1.0
# 1534                  viidikas        NaN             NaN         1.0
# 1535                viiksjänes        NaN             2.0         1.0
# 1536                    viires        NaN             1.0         1.0
# 1537               viirpapagoi        NaN             1.0         1.0
# 1538               vikerforell        NaN             2.0         1.0
# 1550                      vimb        NaN             NaN         1.0
# 1551                 vingerjas        NaN             NaN         1.0
# 1552                      vint        NaN             1.0         1.0
# 1553                vintaloosa        NaN             2.0         1.0
# 1555                     vobla        NaN             NaN         1.0
# 1558                      vutt        NaN             2.0         1.0
# 1559           väike-kirjurähn        NaN             2.0         1.0
# 1560          väike-kärbsenäpp        NaN             2.0         1.0
# 1561            väike-lehelind        NaN             2.0         1.0
# 1562           väike-põõsalind        NaN             2.0         1.0
# 1563                 väikehuik        NaN             1.0         1.0
# 1564            väikekoovitaja        NaN             2.0         1.0
# 1569                väikerisla        NaN             2.0         1.0
# 1575            välja-loorkull        NaN             2.0         1.0
# 1577                  värbhuik        NaN             1.0         1.0
# 1578                 värbrisla        NaN             2.0         1.0
# 1579                   västrik        NaN             2.0         1.0
# 1580                      võik        NaN             1.0         1.0
# 1581                   võikala        NaN             NaN         1.0
# 1584                    võldas        NaN             NaN         1.0
# 1589                  võsaraat        NaN             1.0         1.0
# 1590                    vöödik        NaN             2.0         1.0
# 1591                   vöölane        NaN             2.0         1.0
# 1593                 vööthüään        NaN             2.0         1.0
# 1596            vöötsaba-vigle        NaN             2.0         1.0
# 1599                 älverisla        NaN             2.0         1.0
# 1601             äärdeilterjer        NaN             1.0         1.0
# 1604                       õhv        NaN             1.0         1.0
# 1607                õudnäsalik        NaN             NaN         1.0
# 1609                  õõnetuvi        NaN             2.0         1.0
# 1611                  ööhaigur        NaN             1.0         1.0
# 1613             üheksavöölane        NaN             2.0         1.0
# 1614                 ürgkobras        NaN             2.0         1.0
# 1615                    šaakal        NaN             2.0         1.0
# 1619                   šimpans        NaN             2.0         1.0
# 1620             šoti mägiveis        NaN             1.0         1.0

# %%
import numpy as np
# Defineerime tingimused ja vastavad väärtused
conditions = [
    (df_kontroll["põhisõnad"] == 1),
    (df_kontroll["vikipeedia"] == 1) & ((df_kontroll["palju_küsimusi"] == 1) | (df_kontroll["palju_küsimusi"] == 2)),
    (df_kontroll["palju_küsimusi"] == 1) & (df_kontroll["põhisõnad"] != 1) & (df_kontroll["vikipeedia"] != 1),
    (df_kontroll["palju_küsimusi"] == 2) & (df_kontroll["põhisõnad"] != 1) & (df_kontroll["vikipeedia"] != 1),
    (df_kontroll["vikipeedia"] == 1),
]

values = [1, 2, 3, 4, 4]  # Määrame vastavad tähtsuse väärtused

# Loome uue veeru "tähtsus"
df_kontroll["tähtsus"] = np.select(conditions, values, default=0)  # Vaikimisi 0, kui ei sobi ükski tingimus

# Kuvame tulemuse
df_kontroll
# Out:
#                        Sõna  \
# 0             Kreeka pähkel
# 1                    adzuki
# 2              aed-moorputk
# 3              aed-piimjuur
# 4                 aedhernes
# 5               aedmaasikas
# 6                   aedmari
# 7                aedmurakas
# 8                 aedseller
# 9                    aeduba
# 10                  aedvili
# 11             akazuupähkel
# 12           alligaatorpirn
# 13             alrauni mari
# 14                  ananass
# 15               antoonovka
# 16                  apelsin
# 17                 aprikoos
# 18                  arahhis
# 19                   arbuus
# 20             areekapähkel
# 21                 artišokk
# 22                    aspar
# 23                astelpaju
# 24                   baamia
# 25                baklažaan
# 26                   banaan
# 27            banaankõrvits
# 28                   bataat
# 29                bergamott
# 30         brasiilia pähkel
# 31          brüsseli kapsas
# 32                   bulgur
# 33               dessertõun
# 34                 diospüür
# 35             draakonivili
# 36                   durian
# 37                    frukt
# 38                  granaat
# 39                granadill
# 40                    greip
# 41                  guajaav
# 42                hapukirss
# 43                 hapukurk
# 44                   hernes
# 45               hiina alss
# 46              hiina ploom
# 47                hirsitang
# 48                hõrakmari
# 49            indiaani riis
# 50             inglite vili
# 51                      iva
# 52                jaanikaun
# 53               jahubanaan
# 54                 jahvatis
# 55                 joovikas
# 56                 juurikas
# 57               juurseller
# 58                 jääsalat
# 59                 jõhvikas
# 60                   kaarel
# 61                kabatšokk
# 62               kadakamari
# 63                     kaer
# 64                kaeraklii
# 65               kahvrilaim
# 66               kaktusvili
# 67              kanepiseeme
# 68                   kappar
# 69                 kapsapea
# 70               karamboola
# 71                  karella
# 72                 karulauk
# 73                karusmari
# 74                 kaunvili
# 75   keerdkaelaline kõrvits
# 76                 kerimoia
# 77                    kiivi
# 78              kikerhernes
# 79                   kinkan
# 80                    kirss
# 81               kirsstomat
# 82                  kivaano
# 83                 kivivili
# 84                  kišmišš
# 85                    klaar
# 86               klaaskirss
# 87               klementiin
# 88                     klii
# 89                 kokosell
# 90                   kookos
# 91                   korint
# 92                    kreek
# 93                    kruup
# 94          kuivatatud vili
# 95               kuldrenett
# 96                     kurk
# 97                  kuskuss
# 98                 kõlutera
# 99                  kõrvits
# 100           kõrvitsaseeme
# 101               köögivili
# 102                küdoonia
# 103                küüslauk
# 104                    laim
# 105              lamevirsik
# 106                    lauk
# 107             lehtaedvili
# 108              lehtseller
# 109               lihatomat
# 110                liimauba
# 111              lillkapsas
# 112               linaseeme
# 113                   litši
# 114                  longan
# 115            loorberimari
# 116                 maapirn
# 117                maasikas
# 118             mage sõstar
# 119                    mais
# 120               maisitang
# 121              makadaamia
# 122               mandariin
# 123                  mandel
# 124                   mango
# 125                    mari
# 126                   melon
# 127             mesimurakas
# 128               metsamari
# 129                metslauk
# 130            metsmaasikas
# 131              metspähkel
# 132                 metsõun
# 133                mirabell
# 134                    moon
# 135                   mugul
# 136               mugulvili
# 137              munakinkan
# 138                 munguba
# 139                   murel
# 140                murulauk
# 141          muskaatkõrvits
# 142             must sõstar
# 143                must uba
# 144                mustikas
# 145             muulukamari
# 146              mõrumandel
# 147                  naeris
# 148               nektariin
# 149                    nisu
# 150                nisuklii
# 151                nurmlauk
# 152                    oder
# 153                odratang
# 154                   oliiv
# 155                 palukas
# 156                 paprika
# 157            paradiisiõun
# 158                patisson
# 159               peakapsas
# 160            pekaanpähkel
# 161                  persik
# 162               pesasibul
# 163             pihlakamari
# 164                piimjuur
# 165             piiniaseeme
# 166                    pirn
# 167              pistaatsia
# 168                   ploom
# 169              ploomtomat
# 170                   pomel
# 171               pomerants
# 172                   porru
# 173               porrulauk
# 174               punagreip
# 175           punane kapsas
# 176            punane sibul
# 177              punane uba
# 178         päevalilleseeme
# 179                  pähkel
# 180               pärlsibul
# 181                põldmari
# 182                rabarber
# 183                  renett
# 184                renklood
# 185              riivkapsas
# 186                rohulauk
# 187             rooma salat
# 188                   rosin
# 189                   rukis
# 190               rukkiklii
# 191                   salat
# 192                 satsuma
# 193            seesamiseeme
# 194                   sibul
# 195                sibulõun
# 196                  sidrun
# 197             sinepiseeme
# 198                    soja
# 199          spagetikõrvits
# 200                  spinat
# 201                suislepp
# 202                 sultana
# 203             suvikõrvits
# 204                 suviõun
# 205             säilitusõun
# 206                sõrmlaim
# 207                  sõstar
# 208             söödav vili
# 209                sügisõun
# 210               talisibul
# 211                 taliõun
# 212               tamarillo
# 213                    tang
# 214               tangeriin
# 215                   tatar
# 216                    tera
# 217                   tomat
# 218               toortatar
# 219                 tsitrus
# 220                 tuviõun
# 221             tõrukõrvits
# 222                     uba
# 223                    ubin
# 224                  urjukk
# 225                vaarikas
# 226            vaarikpampel
# 227            valge sõstar
# 228              varsseller
# 229             veriapelsin
# 230               viigimari
# 231               viinamari
# 232                   vilis
# 233                    viss
# 234              õlikõrvits
#
#                                                                Synonyms  \
# 0                                          Kreeka pähkel, kreeka pähkel
# 1                                                      adzuki, asukiuba
# 2                                               aed-moorputk, pastinaak
# 3                                                          aed-piimjuur
# 4                                                             aedhernes
# 5                                                           aedmaasikas
# 6                                                      aedmari, aiamari
# 7                                                    aedmurakas, pampel
# 8                                                     aedseller, seller
# 9                                                     aeduba, Türgi uba
# 10                                                              aedvili
# 11   akazuupähkel, India pähkel, india pähkel, kašupähkel, nakar, nakra
# 12                                             alligaatorpirn, avokaado
# 13                                alrauni mari, lemmemari, tuudaimimari
# 14                                                              ananass
# 15                                                           antoonovka
# 16                                                              apelsin
# 17                                                             aprikoos
# 18                                     arahhis, hiina pähkel, maapähkel
# 19                                                               arbuus
# 20                                           areekapähkel, beetlipähkel
# 21                                                             artišokk
# 22                                                       aspar, spargel
# 23                                             astelpaju, astelpajumari
# 24                                                         baamia, okra
# 25                                                     baklažaan, pommu
# 26                                                               banaan
# 27                                                        banaankõrvits
# 28                                    bataat, maguskartul, magus kartul
# 29                                                            bergamott
# 30                                         brasiilia pähkel, parapähkel
# 31                                          brüsseli kapsas, rooskapsas
# 32                                                               bulgur
# 33                                                  dessertõun, lauaõun
# 34                                    diospüür, hurmaa, kaki, kakiploom
# 35                                                 draakonivili, pitaia
# 36                                                               durian
# 37                                                       frukt, puuvili
# 38                                                  granaat, granaatõun
# 39                                                                  NaN
# 40                                            greip, greipfruut, kreebu
# 41                                                              guajaav
# 42                                                            hapukirss
# 43                                                             hapukurk
# 44                                                               hernes
# 45                                               hiina alss, vesikastan
# 46                                             hiina ploom, litš, litši
# 47                                                 hirsitang, hirsitera
# 48                                             hõrakmari, punane sõstar
# 49            indiaani riis, metsik riis, Tuskaroora vesiriis, vesiriis
# 50                                                 inglite vili, papaia
# 51                                                           iva, seeme
# 52                                                                  NaN
# 53                                                           jahubanaan
# 54                                                             jahvatis
# 55                                                    joovikas, sinikas
# 56                                                                  NaN
# 57                                                           juurseller
# 58                                                             jääsalat
# 59                                                   jõhvikas, kuremari
# 60                                         kaarel, karumurakas, murakas
# 61                           kabatšokk, rullkõrvits, zucchini, tsukiini
# 62                                                           kadakamari
# 63                                                      kaer, kaeratera
# 64                                                                  NaN
# 65                                                 kahvrilaim, kombaava
# 66                                                           kaktusvili
# 67                                                                  NaN
# 68                                                                  NaN
# 69                                                     kapsapea, kapsas
# 70                                                 karamboola, tähtvili
# 71                                                    karella, kibekurk
# 72                                                             karulauk
# 73                                          karusmari, tikerber, tikker
# 74                                                             kaunvili
# 75                                 keerdkaelaline kõrvits, käändkõrvits
# 76                                                  kerimoia, suhkruõun
# 77                                                                kiivi
# 78                                        kikerhernes, nuut, põishernes
# 79                                      kinkan, kumkvaat, kääbusapelsin
# 80                                                        kirss, käsper
# 81                                                           kirsstomat
# 82                                                    kivaano, ogamelon
# 83                                                    kivivili, luuvili
# 84                                                              kišmišš
# 85                                         klaar, klaarõun, valge klaar
# 86                                                           klaaskirss
# 87                                                           klementiin
# 88                                                          klii, kliid
# 89                                               kokosell, pikk kõrvits
# 90                                                 kookos, kookospähkel
# 91                                                               korint
# 92                                                                kreek
# 93                                         kruubid, kruubitangud, kruup
# 94                                                      kuivatatud vili
# 95                                                           kuldrenett
# 96                                                                 kurk
# 97                                                              kuskuss
# 98                                                             kõlutera
# 99                                                              kõrvits
# 100                                                       kõrvitsaseeme
# 101                                                           köögivili
# 102                                                            küdoonia
# 103                                                     küüslauk, noblu
# 104                                                                laim
# 105                                                          lamevirsik
# 106                                                                lauk
# 107                                          lehtaedvili, lehtköögivili
# 108                                                          lehtseller
# 109                                                           lihatomat
# 110                                                            liimauba
# 111                                                          lillkapsas
# 112                                              linaseeme, linaseemned
# 113                                            litši, pulasan, rambutan
# 114                                                              longan
# 115                                                        loorberimari
# 116                                 maapirn, mugulpäevalill, topinambur
# 117                                                maasikas, maasikmari
# 118                                                         mage sõstar
# 119                                                     mais, maisitera
# 120                                                           maisitang
# 121                                        makadaamia, makadaamiapähkel
# 122                                                           mandariin
# 123                                                                 NaN
# 124                                                   mango, mangoploom
# 125                                                                mari
# 126                                                               melon
# 127                                             mesimurakas, soomurakas
# 128                                                 metsamari, metsmari
# 129                                                            metslauk
# 130                                                        metsmaasikas
# 131                                           metspähkel, sarapuupähkel
# 132                                                             metsõun
# 133                                                            mirabell
# 134                                                    moon, mooniseeme
# 135                                                                 NaN
# 136                                                                 NaN
# 137                                                  munakinkan, nagami
# 138                                                             munguba
# 139                                                               murel
# 140                                                            murulauk
# 141                                                      muskaatkõrvits
# 142                                              must sõstar, sitikmari
# 143                                                            must uba
# 144                                                mustikas, mustikmari
# 145                                               muulukamari, muulukas
# 146                                                          mõrumandel
# 147                                                              naeris
# 148                                                           nektariin
# 149                                                      nisu, nisutera
# 150                                                                 NaN
# 151                                                            nurmlauk
# 152                                                      oder, odratera
# 153                                                            odratang
# 154                                                               oliiv
# 155                                                       palukas, pohl
# 156                                                paprika, paprikakaun
# 157                                                        paradiisiõun
# 158                                            patisson, taldrikkõrvits
# 159                                                           peakapsas
# 160                                                        pekaanpähkel
# 161                                                      persik, virsik
# 162                                      pesasibul, šalott, šalottsibul
# 163                                               pihlakamari, pihlakas
# 164                                                            piimjuur
# 165                   piiniaseeme, seedermänni pähkel, seedermänniseeme
# 166                                                                pirn
# 167                                        pistaatsia, pistaatsiapähkel
# 168                                                               ploom
# 169                                                          ploomtomat
# 170                                                       pomel, pomelo
# 171                                                           pomerants
# 172                                        porru, porrulauk, porrusibul
# 173                                        porru, porrulauk, porrusibul
# 174                                                punagreip, verigreip
# 175                                                       punane kapsas
# 176                                                        punane sibul
# 177                                                          punane uba
# 178                                             päevalilleseeme, sihvka
# 179                                                              pähkel
# 180                                           pärlsibul, suvi-porrulauk
# 181                                               põldmari, põldmurakas
# 182                                                            rabarber
# 183                                                   renett, renettõun
# 184                                                            renklood
# 185                                              riivkapsas, särvkapsas
# 186                                                            rohulauk
# 187                                                         rooma salat
# 188                                                               rosin
# 189                                                    rukis, rukkitera
# 190                                                                 NaN
# 191                                                               salat
# 192                                                             satsuma
# 193                                                        seesamiseeme
# 194                                                   sibul, söögisibul
# 195                                                            sibulõun
# 196                                                              sidrun
# 197                                                         sinepiseeme
# 198                                                       soja, sojauba
# 199                                                      spagetikõrvits
# 200                                                              spinat
# 201                                                            suislepp
# 202                                               sultana, sultanarosin
# 203                                                         suvikõrvits
# 204                                                             suviõun
# 205                                                         säilitusõun
# 206                                                            sõrmlaim
# 207                                                  sõstar, sõstramari
# 208                                                                 NaN
# 209                                                            sügisõun
# 210                                                           talisibul
# 211                                                             taliõun
# 212                                                           tamarillo
# 213                                                                tang
# 214                                                           tangeriin
# 215                                                    tatar, tatratera
# 216                              tera, teravili, teris, vili, viljatera
# 217                                                               tomat
# 218                                                           toortatar
# 219                                  tsitrus, tsitruseline, tsitrusvili
# 220                                                             tuviõun
# 221                                                         tõrukõrvits
# 222                                                                 uba
# 223                                                           ubin, õun
# 224                                                              urjukk
# 225                                          vaarikas, vaarmari, vabarn
# 226                                                vaarikpampel, vampel
# 227                                                        valge sõstar
# 228                                                          varsseller
# 229                                                         veriapelsin
# 230                                                     viigimari, viik
# 231                                                           viinamari
# 232                                                               vilis
# 233                                                                viss
# 234                                                          õlikõrvits
#
#            most_popular  põhisõnad  palju_küsimusi vikipeedia  tähtsus
# 0         kreeka pähkel        NaN             1.0          1        2
# 1                  None        NaN             1.0       None        3
# 2          aed-moorputk        NaN             1.0          1        2
# 3                  None        NaN             1.0       None        3
# 4                  None        NaN             1.0       None        3
# 5           aedmaasikas        NaN             1.0          1        2
# 6                  None        NaN             1.0       None        3
# 7            aedmurakas        NaN             1.0          1        2
# 8             aedseller        NaN             1.0          1        2
# 9                aeduba        NaN             1.0          1        2
# 10              aedvili        1.0             NaN          1        1
# 11         india pähkel        NaN             2.0          1        2
# 12             avokaado        NaN             1.0          1        2
# 13                 None        NaN             1.0       None        3
# 14              ananass        1.0             1.0          1        1
# 15           antoonovka        NaN             1.0          1        2
# 16              apelsin        1.0             1.0          1        1
# 17             aprikoos        NaN             NaN          1        4
# 18              arahhis        NaN             1.0          1        2
# 19               arbuus        1.0             1.0          1        1
# 20         beetlipähkel        NaN             2.0          1        2
# 21             artišokk        NaN             1.0          1        2
# 22                aspar        NaN             1.0          1        2
# 23            astelpaju        NaN             1.0          1        2
# 24               baamia        NaN             1.0          1        2
# 25            baklažaan        NaN             1.0          1        2
# 26               banaan        1.0             1.0          1        1
# 27                 None        NaN             1.0       None        3
# 28               bataat        NaN             1.0          1        2
# 29            bergamott        NaN             1.0          1        2
# 30     brasiilia pähkel        NaN             2.0          1        2
# 31      brüsseli kapsas        NaN             1.0          1        2
# 32               bulgur        NaN             2.0          1        2
# 33                 None        NaN             1.0       None        3
# 34             diospüür        NaN             1.0          1        2
# 35                 None        NaN             1.0       None        3
# 36               durian        NaN             1.0          1        2
# 37              puuvili        1.0             1.0          1        1
# 38              granaat        NaN             1.0          1        2
# 39            granadill        NaN             NaN          1        4
# 40                greip        NaN             1.0          1        2
# 41              guajaav        NaN             1.0          1        2
# 42            hapukirss        NaN             NaN          1        4
# 43             hapukurk        1.0             1.0          1        1
# 44               hernes        1.0             1.0          1        1
# 45                 None        NaN             1.0       None        3
# 46                litši        NaN             1.0          1        2
# 47                 None        NaN             1.0       None        3
# 48        punane sõstar        NaN             1.0          1        2
# 49                 None        NaN             2.0       None        4
# 50               papaia        NaN             1.0          1        2
# 51                seeme        1.0             NaN          1        1
# 52                 None        NaN             NaN       None        0
# 53                 None        NaN             1.0       None        3
# 54                 None        NaN             2.0       None        4
# 55             joovikas        NaN             1.0          1        2
# 56             juurikas        NaN             1.0          1        2
# 57           juurseller        NaN             1.0          1        2
# 58                 None        NaN             1.0       None        3
# 59             jõhvikas        1.0             1.0          1        1
# 60               kaarel        NaN             1.0          1        2
# 61             zucchini        NaN             1.0          1        2
# 62           kadakamari        NaN             1.0          1        2
# 63                 kaer        1.0             1.0          1        1
# 64                 None        NaN             2.0       None        4
# 65                 None        NaN             1.0       None        3
# 66                 None        NaN             1.0       None        3
# 67                 None        NaN             NaN       None        0
# 68               kappar        NaN             NaN          1        4
# 69               kapsas        1.0             1.0          1        1
# 70           karamboola        NaN             1.0          1        2
# 71                 None        NaN             1.0       None        3
# 72             karulauk        NaN             1.0          1        2
# 73            karusmari        1.0             1.0          1        1
# 74             kaunvili        NaN             1.0          1        2
# 75                 None        NaN             1.0       None        3
# 76                 None        NaN             1.0       None        3
# 77                kiivi        NaN             1.0          1        2
# 78          kikerhernes        NaN             1.0          1        2
# 79                 None        NaN             1.0       None        3
# 80                kirss        1.0             2.0          1        1
# 81           kirsstomat        NaN             1.0          1        2
# 82                 None        NaN             1.0       None        3
# 83              luuvili        NaN             NaN          1        4
# 84                 None        NaN             1.0       None        3
# 85                klaar        NaN             1.0          1        2
# 86                 None        NaN             2.0       None        4
# 87           klementiin        NaN             1.0          1        2
# 88                 klii        NaN             2.0          1        2
# 89                 None        NaN             1.0       None        3
# 90               kookos        NaN             2.0          1        2
# 91               korint        NaN             2.0          1        2
# 92                kreek        NaN             1.0          1        2
# 93              kruubid        NaN             2.0          1        2
# 94                 None        NaN             NaN       None        0
# 95           kuldrenett        NaN             1.0          1        2
# 96                 kurk        1.0             1.0          1        1
# 97              kuskuss        NaN             1.0          1        2
# 98                 None        NaN             2.0       None        4
# 99              kõrvits        1.0             1.0          1        1
# 100                None        NaN             NaN       None        0
# 101           köögivili        1.0             1.0          1        1
# 102            küdoonia        NaN             1.0          1        2
# 103            küüslauk        1.0             NaN          1        1
# 104                laim        NaN             1.0          1        2
# 105          lamevirsik        NaN             1.0          1        2
# 106                lauk        NaN             1.0          1        2
# 107                None        NaN             NaN       None        0
# 108                None        NaN             1.0       None        3
# 109                None        NaN             1.0       None        3
# 110                None        NaN             1.0       None        3
# 111          lillkapsas        1.0             1.0          1        1
# 112         linaseemned        NaN             NaN          1        4
# 113               litši        NaN             1.0          1        2
# 114                None        NaN             1.0       None        3
# 115                None        NaN             NaN       None        0
# 116             maapirn        NaN             1.0          1        2
# 117            maasikas        1.0             1.0          1        1
# 118         mage sõstar        NaN             1.0          1        2
# 119                mais        NaN             1.0          1        2
# 120                None        NaN             1.0       None        3
# 121                None        NaN             2.0       None        4
# 122           mandariin        1.0             1.0          1        1
# 123              mandel        NaN             NaN          1        4
# 124               mango        NaN             NaN          1        4
# 125                mari        1.0             1.0          1        1
# 126               melon        NaN             1.0          1        2
# 127         mesimurakas        NaN             1.0          1        2
# 128                None        NaN             1.0       None        3
# 129            metslauk        NaN             1.0          1        2
# 130        metsmaasikas        NaN             1.0          1        2
# 131          metspähkel        NaN             2.0          1        2
# 132                None        NaN             1.0       None        3
# 133                None        NaN             NaN       None        0
# 134                moon        NaN             NaN          1        4
# 135               mugul        NaN             NaN          1        4
# 136                None        NaN             NaN       None        0
# 137                None        NaN             1.0       None        3
# 138             munguba        NaN             1.0          1        2
# 139               murel        NaN             NaN          1        4
# 140            murulauk        NaN             1.0          1        2
# 141                None        NaN             1.0       None        3
# 142         must sõstar        NaN             1.0          1        2
# 143                None        NaN             1.0       None        3
# 144            mustikas        1.0             1.0          1        1
# 145            muulukas        NaN             1.0          1        2
# 146                None        NaN             NaN       None        0
# 147              naeris        NaN             1.0          1        2
# 148           nektariin        NaN             1.0          1        2
# 149                nisu        1.0             2.0          1        1
# 150                None        NaN             2.0       None        4
# 151            nurmlauk        NaN             1.0          1        2
# 152                oder        1.0             NaN          1        1
# 153                None        NaN             1.0       None        3
# 154               oliiv        NaN             NaN          1        4
# 155             palukas        NaN             1.0          1        2
# 156             paprika        1.0             1.0          1        1
# 157                None        NaN             1.0       None        3
# 158                None        NaN             1.0       None        3
# 159           peakapsas        NaN             1.0          1        2
# 160                None        NaN             2.0       None        4
# 161              virsik        1.0             1.0          1        1
# 162                None        NaN             1.0       None        3
# 163            pihlakas        NaN             1.0          1        2
# 164            piimjuur        NaN             1.0          1        2
# 165  seedermänni pähkel        NaN             NaN          1        4
# 166                pirn        1.0             1.0          1        1
# 167          pistaatsia        NaN             1.0          1        2
# 168               ploom        1.0             1.0          1        1
# 169                None        NaN             1.0       None        3
# 170               pomel        NaN             1.0          1        2
# 171           pomerants        NaN             1.0          1        2
# 172           porrulauk        NaN             1.0          1        2
# 173           porrulauk        NaN             1.0          1        2
# 174                None        NaN             1.0       None        3
# 175                None        NaN             1.0       None        3
# 176        punane sibul        NaN             1.0          1        2
# 177                None        NaN             1.0       None        3
# 178                None        NaN             NaN       None        0
# 179              pähkel        1.0             2.0          1        1
# 180                None        NaN             1.0       None        3
# 181            põldmari        NaN             1.0          1        2
# 182            rabarber        NaN             1.0          1        2
# 183                None        NaN             1.0       None        3
# 184                None        NaN             1.0       None        3
# 185                None        NaN             1.0       None        3
# 186            rohulauk        NaN             1.0          1        2
# 187         rooma salat        NaN             1.0          1        2
# 188               rosin        NaN             2.0          1        2
# 189               rukis        1.0             NaN          1        1
# 190                None        NaN             2.0       None        4
# 191               salat        1.0             1.0          1        1
# 192                None        NaN             1.0       None        3
# 193        seesamiseeme        NaN             NaN          1        4
# 194               sibul        1.0             1.0          1        1
# 195                None        NaN             1.0       None        3
# 196              sidrun        1.0             1.0          1        1
# 197                None        NaN             NaN       None        0
# 198                soja        NaN             1.0          1        2
# 199                None        NaN             1.0       None        3
# 200              spinat        NaN             1.0          1        2
# 201            suislepp        NaN             1.0          1        2
# 202             sultana        NaN             2.0          1        2
# 203         suvikõrvits        NaN             1.0          1        2
# 204                None        NaN             1.0       None        3
# 205                None        NaN             1.0       None        3
# 206                None        NaN             1.0       None        3
# 207              sõstar        NaN             1.0          1        2
# 208                None        NaN             NaN       None        0
# 209                None        NaN             1.0       None        3
# 210           talisibul        NaN             1.0          1        2
# 211                None        NaN             1.0       None        3
# 212                None        NaN             1.0       None        3
# 213                tang        NaN             1.0          1        2
# 214           tangeriin        NaN             1.0          1        2
# 215               tatar        1.0             1.0          1        1
# 216                tera        1.0             2.0          1        1
# 217               tomat        1.0             1.0          1        1
# 218                None        NaN             1.0       None        3
# 219             tsitrus        NaN             1.0          1        2
# 220                None        NaN             1.0       None        3
# 221                None        NaN             1.0       None        3
# 222                 uba        1.0             1.0          1        1
# 223                 õun        1.0             1.0          1        1
# 224                None        NaN             NaN       None        0
# 225            vaarikas        1.0             1.0          1        1
# 226        vaarikpampel        NaN             1.0          1        2
# 227                None        NaN             1.0       None        3
# 228                None        NaN             1.0       None        3
# 229                None        NaN             1.0       None        3
# 230                viik        1.0             1.0          1        1
# 231           viinamari        1.0             1.0          1        1
# 232                None        NaN             2.0       None        4
# 233                None        NaN             1.0       None        3
# 234                None        NaN             1.0       None        3

# %%
df_kontroll[df_kontroll["tähtsus"] == 4].shape
# Out:
# (24, 7)

# %%
df_kontroll[df_kontroll["tähtsus"] == 0].shape # 13 rida kustutada ?
# Out:
# (13, 7)

# %%
df_kontroll[df_kontroll["tähtsus"] == 0]
# Out:
#                 Sõna                    Synonyms most_popular  põhisõnad  \
# 52         jaanikaun                         NaN         None        NaN
# 67       kanepiseeme                         NaN         None        NaN
# 94   kuivatatud vili             kuivatatud vili         None        NaN
# 100    kõrvitsaseeme               kõrvitsaseeme         None        NaN
# 107      lehtaedvili  lehtaedvili, lehtköögivili         None        NaN
# 115     loorberimari                loorberimari         None        NaN
# 133         mirabell                    mirabell         None        NaN
# 136        mugulvili                         NaN         None        NaN
# 146       mõrumandel                  mõrumandel         None        NaN
# 178  päevalilleseeme     päevalilleseeme, sihvka         None        NaN
# 197      sinepiseeme                 sinepiseeme         None        NaN
# 208      söödav vili                         NaN         None        NaN
# 224           urjukk                      urjukk         None        NaN
#
#      palju_küsimusi vikipeedia  tähtsus
# 52              NaN       None        0
# 67              NaN       None        0
# 94              NaN       None        0
# 100             NaN       None        0
# 107             NaN       None        0
# 115             NaN       None        0
# 133             NaN       None        0
# 136             NaN       None        0
# 146             NaN       None        0
# 178             NaN       None        0
# 197             NaN       None        0
# 208             NaN       None        0
# 224             NaN       None        0

# %%
# Lisame tähtsuse veeru vastavalt Looma väärtusele
result["tähtsus"] = result["Sõna"].apply(lambda x: df_kontroll.loc[df_kontroll["Sõna"] == x, "tähtsus"].max())

# %%
# Most_popular lisamine result tabelisse
result["most_popular"] = result["Sõna"].map(df_kontroll.groupby("Sõna")["most_popular"].first())
# Asendame "Loom" väärtuse "most_popular" väärtusega, kui need erinevad ja "most_popular" pole tühi
mask = (result["most_popular"].notna()) & (result["Sõna"] != result["most_popular"])
result.loc[mask, "Sõna"] = result.loc[mask, "most_popular"]

# Kustutame "most_popular" veeru
result = result.drop(columns=["most_popular"])

# %%
# Filtreerime välja read, kus tähtsus <= 0; eemaldasime u 332
result = result[result["tähtsus"] > 0]

# %%
result.shape
# Out:
# (222, 502)

# %%
# Eemaldame kõik veerud, kus kõik read on 0. ; eemaldasime u 368 küsimust
result = result.loc[:, (result != 0).any(axis=0)]

# %%
result.shape
# Out:
# (222, 484)

# %%
result["Sõna"].value_counts()[result["Sõna"].value_counts() > 1]
# Out:
# Sõna
# litši        2
# porrulauk    2
# Name: count, dtype: int64

# %%
result = result.drop_duplicates(subset=["Sõna"], keep="first")

# %%
result["Sõna"].nunique()
# Out:
# 220

# %%
result.to_csv('mängu_andmed_taimed2.csv', index=False) # andmed millel on 1155 sõna ja 1700 küsimust
